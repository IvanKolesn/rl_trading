# %%
import os
import sys
import warnings

sys.path.append("..")

# %%
# add to toml
# %pip install lz4

# %%
# python -m build --sdist
# %pip install rl_trading-0.0.1.tar.gz

# %%
from copy import deepcopy

import gymnasium as Env
import numpy as np
import pandas as pd
import ray
import torch
import matplotlib.pyplot as plt

from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.models import ModelCatalog
from ray.rllib.utils.metrics import ENV_RUNNER_RESULTS
from ray.tune.registry import register_env
from sklearn.preprocessing import RobustScaler
from tqdm import trange

# %%
# Comment next two lines to run in collab
# %load_ext autoreload
# %autoreload 2

from rl_trading.environments.fx_environment import FxTradingEnv
from rl_trading.models.fx_model import FXModel

# %% [markdown]
# ## Trading setup:
#
# 1. Algorithm starts with US dollars only
# 2. It trades minutely for one day
# 3. All transaction costs, slippage and fees are accounted in one trade fee: 1 bps per trade (can be changed)
# 4. We assume the market is liquid enough for our volume and disregard trading book structure

# %% [markdown]
# ## Todo

# %% [markdown]
# - Return portfolio history as info / custom metrics
# - Penalise excessive turnover (e.g., -0.5 * |action| per trade) to encourage smoother trading. Pass 0.5 as turnover penalty in trading params
# - Add slippage as separate metric. Maybe random normal to model reality better (ensure positivity by using abs though)
# - Increase the number of iterations in training
# - Save results and model for one trading pair
# - Add differential sharpe ratio as reward (Allow to choose in params)
# - Save results and model for one trading pair
# - Fix tests
# - Return to bigger number of currencies
# - Try SAC and DreamerV3
#
# `*` Use feature importance or PCA to reduce dimension → smaller network, faster forward/backward.

# %% [markdown]
# ### Historical data

# %%
# comment for collab
data_folder = "C:\\Users\\Ivan\\rl_trading\\data\\"
# data_folder = ""

# %%
historical_data = pd.read_parquet(f"{data_folder}FX_data.parquet.gzip")

# %%
for col in historical_data.columns:
    if col in ["ccy", "timestamp"]:
        continue
    historical_data[col] = historical_data[col].astype(float)

# %% [markdown]
# ## temp step for debug

# %%
historical_data = historical_data.loc[historical_data["ccy"] == "eurusd", :]

# %% [markdown]
# ## Remove above later

# %% [markdown]
# Scaling data

# %%
historical_data_scaler_train = historical_data.loc[
    historical_data["timestamp"] <= "2023-01-01 00:00:00", :
]

# %%
historical_data_to_use = historical_data.loc[
    historical_data["timestamp"] >= "2023-01-02 00:00:00", :
]

# %%
# todo: pass as long table to allow for OHLC format
historical_prices = pd.pivot_table(
    data=historical_data_to_use, index="timestamp", columns="ccy", values="close"
)

historical_prices = historical_prices.ffill().dropna()

# %%
# Transform outliers
transformer = RobustScaler().fit(
    historical_data_scaler_train.set_index(["timestamp", "ccy"])
)

# %%
features = transformer.transform(historical_data_to_use.set_index(["timestamp", "ccy"]))

# %%
multi_index = pd.MultiIndex.from_frame(historical_data_to_use[["timestamp", "ccy"]])
features = pd.DataFrame(features, index=multi_index)

# %%
historical_data_to_use = features.unstack("ccy").ffill()

# %%
del historical_data_scaler_train, historical_data, features

# %% [markdown]
# ### Trading config

# %%
current_porfolio = {
    "usd": 100_000,
}

# %%
env_config = {
    "historical_prices": historical_prices,
    "features_dataset": historical_data_to_use,
    "initial_portfolio": current_porfolio,
    "start_datetime": None,  # pd.Timestamp("2023-01-03 09:00:00"),
    "episode_length_days": 1,
}

# %%
# all([x in historical_data_to_use["timestamp"].values for x in historical_prices.index])

# %%
fx_env = FxTradingEnv(**env_config)
fx_env.preprocess_data()

# %%
fx_env._get_state_dim()
# Out:
# (24,)

# %%
# %%time

# # FOR DEBUG PURPOSES
max_w = fx_env.trading_params["max_delta_in_weights"]
done = False
state, info = fx_env.reset()
total_reward = [0]

while not done:

    action = np.random.uniform(
        low=max_w * -1, high=max_w, size=len(fx_env.current_portfolio)
    )
    state, reward, terminated, truncated, info = fx_env.step(action)
    done = terminated or truncated
    total_reward.append(reward)
# Out:
# CPU times: total: 516 ms
# Wall time: 492 ms

# %%
plt.plot(np.cumsum(total_reward))
plt.ylabel("Basis points")
plt.xlabel("Minutes")
plt.show()

# %%
# %%timeit
# fx_env._get_state()

# %%
# %%timeit
# fx_env.step(action)

# %%
def env_creator(env_config):
    """
    Create env
    """
    fx_env = FxTradingEnv(**env_config)
    fx_env.preprocess_data()
    return fx_env

# %%
register_env("fx_trading_env", env_creator)
ModelCatalog.register_custom_model("fx_model", FXModel)

# %%
ray.init(
    ignore_reinit_error=True,
    # # To work with cloned repository. Comment for Google collab
    runtime_env={
        "working_dir": os.path.dirname(os.path.abspath(".")),
        "py_modules": [os.path.abspath(".")],
        "excludes": [
            "*.pyc",
            "__pycache__",
            "*.parquet.gzip",
            "*data/",
            "notebooks/",
            ".git/",
        ],
    },
)
# Out:
# 2026-02-11 19:06:14,733	INFO worker.py:2023 -- Started a local Ray instance.
# 2026-02-11 19:06:14,787	INFO packaging.py:588 -- Creating a file package for local module 'C:\Users\Ivan\rl_trading\notebooks'.
# 2026-02-11 19:06:14,820	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_786bf32d740f7301.zip' (0.48MiB) to Ray cluster...
# 2026-02-11 19:06:14,836	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_786bf32d740f7301.zip'.
# 2026-02-11 19:06:14,982	INFO packaging.py:588 -- Creating a file package for local module 'C:\Users\Ivan\rl_trading'.
# 2026-02-11 19:06:15,055	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_9b2a1f8b2f8974df.zip' (0.03MiB) to Ray cluster...
# 2026-02-11 19:06:15,063	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_9b2a1f8b2f8974df.zip'.
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# RayContext(dashboard_url='', python_version='3.12.10', ray_version='2.52.1', ray_commit='4ebdc0abe5e5a551625fe7f87053c7e668a6ff74')
# (pid=gcs_server) [2026-02-11 19:06:40,946 E 9024 1772] (gcs_server.exe) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2026-02-11 19:06:48,709 E 12908 808] (raylet.exe) main.cc:979: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14

# %%
suggested_workers = max(os.cpu_count() - 1, 1)

if torch.cuda.is_available():
    num_gpus = torch.cuda.device_count()
else:
    num_gpus = 0

suggested_workers, num_gpus
# Out:
# (7, 0)

# %%
config = PPOConfig()

config = (
    config.environment(
        env="fx_trading_env",
        env_config=env_config,
    )
    .framework("torch")
    .training(
        model={"custom_model": "fx_model"},
        lr=3e-4,
        clip_param=0.1,
        grad_clip=0.5,
        vf_clip_param=10.0,
        entropy_coeff=0.001,
        gamma=0.99,
        lambda_=0.95,
        num_epochs=25,
        train_batch_size=8192,
    )
    # .debugging(log_level="ERROR")
    .resources(num_gpus=num_gpus)
    .env_runners(
        num_cpus_per_env_runner=1,
        num_env_runners=suggested_workers,
        num_envs_per_env_runner=4,
        rollout_fragment_length="auto",
    )
    .api_stack(
        enable_rl_module_and_learner=False, enable_env_runner_and_connector_v2=False
    )
)

# %%
trainer = config.build_algo()
# Out:
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm.py:525: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2026-02-11 19:07:19,243	INFO trainable.py:161 -- Trainable.setup took 42.080 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-11 19:07:19,243	WARNING util.py:61 -- Install gputil for GPU system monitoring.

# %%
# num_epochs = 1
num_epochs = 100

# %%
# warnings.filterwarnings('ignore')

episode_rewards = []

for i in trange(num_epochs):

    result = trainer.train()

    average_episode_reward = np.mean(
        result[ENV_RUNNER_RESULTS]["hist_stats"]["episode_reward"]
    )
    episode_rewards.append(average_episode_reward)

    if i % 5 == 0:
        print(f"Last 5 epochs reward: {np.mean(episode_rewards[-5:])}")
# Out:
#   0%|                                                                                          | 0/100 [00:00<?, ?it/s]2026-02-11 19:07:48,952	WARNING train_ops.py:114 -- DeprecationWarning: `ray.rllib.execution.train_ops.multi_gpu_train_one_step` has been deprecated. This will raise an error in the future!
#   1%|▊                                                                                 | 1/100 [00:35<58:28, 35.44s/it]
# Last 5 epochs reward: -47.92303135942538
#   6%|████▉                                                                             | 6/100 [03:30<54:50, 35.00s/it]
# Last 5 epochs reward: -83.77966493692865
#  11%|████████▉                                                                        | 11/100 [06:29<52:42, 35.53s/it]
# Last 5 epochs reward: -88.095504053104
#  16%|████████████▉                                                                    | 16/100 [09:15<48:17, 34.50s/it]
# Last 5 epochs reward: -91.92749660370745
#  21%|█████████████████                                                                | 21/100 [12:14<46:39, 35.44s/it]
# Last 5 epochs reward: -88.56346882248803
#  26%|█████████████████████                                                            | 26/100 [15:10<43:33, 35.31s/it]
# Last 5 epochs reward: -85.34102927588768
#  31%|█████████████████████████                                                        | 31/100 [18:08<40:45, 35.44s/it]
# Last 5 epochs reward: -79.19924144134002
#  36%|█████████████████████████████▏                                                   | 36/100 [21:05<37:37, 35.27s/it]
# Last 5 epochs reward: -78.77112501415601
#  41%|█████████████████████████████████▏                                               | 41/100 [23:01<21:49, 22.20s/it]
# Last 5 epochs reward: -78.22116089113226
#  46%|█████████████████████████████████████▎                                           | 46/100 [24:22<15:27, 17.18s/it]
# Last 5 epochs reward: -78.48258300452224
#  51%|█████████████████████████████████████████▎                                       | 51/100 [25:46<13:54, 17.03s/it]
# Last 5 epochs reward: -82.11019390864585
#  56%|█████████████████████████████████████████████▎                                   | 56/100 [27:11<12:30, 17.06s/it]
# Last 5 epochs reward: -78.06761462047307
#  61%|█████████████████████████████████████████████████▍                               | 61/100 [28:36<11:01, 16.95s/it]
# Last 5 epochs reward: -76.13698340031306
#  66%|█████████████████████████████████████████████████████▍                           | 66/100 [30:04<09:56, 17.54s/it]
# Last 5 epochs reward: -71.4780426507982
#  71%|█████████████████████████████████████████████████████████▌                       | 71/100 [31:33<08:34, 17.73s/it]
# Last 5 epochs reward: -66.24339555680031
#  76%|█████████████████████████████████████████████████████████████▌                   | 76/100 [33:03<07:15, 18.15s/it]
# Last 5 epochs reward: -64.69084328953943
#  81%|█████████████████████████████████████████████████████████████████▌               | 81/100 [34:38<05:54, 18.65s/it]
# Last 5 epochs reward: -62.626165458559115
#  86%|█████████████████████████████████████████████████████████████████████▋           | 86/100 [36:15<04:29, 19.23s/it]
# Last 5 epochs reward: -63.6639571959113
#  91%|█████████████████████████████████████████████████████████████████████████▋       | 91/100 [38:03<03:18, 22.08s/it]
# Last 5 epochs reward: -64.18745591373072
#  96%|█████████████████████████████████████████████████████████████████████████████▊   | 96/100 [40:28<01:59, 29.87s/it]
# Last 5 epochs reward: -61.94060490104387
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [42:21<00:00, 25.42s/it]

# %% [markdown]
# #### Plot results

# %%
rewards = pd.Series(episode_rewards)

# %%
rewards.rolling(5).mean().plot()
plt.title("Average total return per 5 iterations")
plt.xlabel("Iteration")
plt.ylabel("Total return (bps)")
plt.show()
