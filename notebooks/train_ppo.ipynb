# %%
import os
import sys
import warnings

sys.path.append("..")

# %%
# pip install ray

# %%
# pip install rl_trading.zip

# %%
import gymnasium as Env
import numpy as np
import pandas as pd
import ray
import torch

from tqdm import trange
from copy import deepcopy
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.models import ModelCatalog
from ray.rllib.utils.metrics import ENV_RUNNER_RESULTS
from ray.tune.registry import register_env

# %%
from sklearn.preprocessing import RobustScaler

# %%
# Comment next two lines to run in collab
# %load_ext autoreload
# %autoreload 2

from rl_trading.environments.fx_environment import FxTradingEnv
from rl_trading.models.fx_model import FXModel

# %% [markdown]
# ## Trading setup:
#
# 1. Algorithm starts with US dollars only
# 2. It trades minutely for one day to avoid leaving position overnight
# 3. All transaction costs, slippage and fees are accounted in one trade fee: 10 bps per trade (can be changed)
# 4. We assume the market is liquid enough for our volume and disregard trading book structure

# %%
current_porfolio = {
    "usd": 100_000,
}

# %%
data_folder = "C:\\Users\\Ivan\\rl_trading\\data\\"
# data_folder = ""
historical_data = pd.read_parquet(f"{data_folder}FX_data.parquet.gzip")

# %%
historical_data = historical_data.drop(columns=["volume", "hour", "weekday_hour"])

# %% [markdown]
# Scaling data

# %%
historical_data_scaler_train = historical_data.loc[
    historical_data["timestamp"] <= "2023-01-01 00:00:00",
    :
]

# %%
historical_data_to_use = historical_data.loc[
    historical_data["timestamp"] >= "2023-01-02 00:00:00",
    :
]

# %%
transformer = RobustScaler().fit(historical_data_scaler_train.iloc[:, 6:])

# %%
# todo: pass as long table to allow for OHLC format
historical_prices = pd.pivot_table(
    data=historical_data_to_use,
    index="timestamp",
    columns="ccy",
    values="close"
)

historical_prices = historical_prices.ffill().dropna()

# %%
historical_data_to_use.iloc[:, 6:] = transformer.transform(historical_data_to_use.iloc[:, 6:])
# Out:
# C:\Users\Ivan\AppData\Local\Temp\ipykernel_9920\4260471947.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.33333333  0.33333333  0.33333333 ... -0.33333333 -0.33333333
#  -0.33333333]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   historical_data_to_use.iloc[:, 6:] = transformer.transform(historical_data_to_use.iloc[:, 6:])
# C:\Users\Ivan\AppData\Local\Temp\ipykernel_9920\4260471947.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.5 -0.5 -0.5 ... -0.5 -0.5 -0.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   historical_data_to_use.iloc[:, 6:] = transformer.transform(historical_data_to_use.iloc[:, 6:])

# %%
pd.isna(historical_data_to_use.iloc[:, 6:]).any().any()
# Out:
# np.False_

# %%
np.isfinite(historical_data_to_use.iloc[:, 6:]).all().all()
# Out:
# np.True_

# %%
del historical_data_scaler_train, historical_data

# %%
env_config = {
    "historical_prices": historical_prices,
    "features_dataset": historical_data_to_use,
    "initial_portfolio": current_porfolio,
    "start_datetime": None,
    "episode_length_days": 1,
}

# %%
# all([x in historical_data_to_use["timestamp"].values for x in historical_prices.index])

# %%
fx_env = FxTradingEnv(**env_config)
fx_env.preprocess_data()

# %%
# %%time

# # FOR DEBUG PURPOSES
max_w = fx_env.trading_params["max_delta_in_weights"]
done = False
state, info = fx_env.reset()
total_reward = 0

while not done:

    action = np.random.uniform(
        low=max_w * -1, high=max_w, size=len(current_porfolio)
    )

    state, reward, terminated, truncated, info = fx_env.step(action)
    done = terminated or truncated
    total_reward += reward

# %%
# %%timeit
# fx_env._get_state()

# %%
# %%timeit
# fx_env.step(action)

# %%
def env_creator(env_config):
    """
    Create env
    """
    fx_env = FxTradingEnv(**env_config)
    fx_env.preprocess_data()
    return fx_env

# %%
register_env("fx_trading_env", env_creator)
ModelCatalog.register_custom_model("fx_model", FXModel)

# %%
ray.init(
    ignore_reinit_error=True,
    # # To work with cloned repository. Comment for Google collab
    runtime_env={
        "working_dir": os.path.dirname(os.path.abspath(".")),
        "py_modules": [os.path.abspath(".")],
        "excludes": [
            "*.pyc",
            "__pycache__",
            "*.parquet.gzip",
            "*data/",
            "notebooks/",
            ".git/"
        ],
    },
)

# %%
suggested_workers = 1 #os.cpu_count() - 1

if torch.cuda.is_available():
    num_gpus = torch.cuda.device_count()
else:
    num_gpus = 0

suggested_workers, num_gpus

# %%
config = PPOConfig()

config = (
    config.environment(
        env="fx_trading_env",
        env_config=env_config,
    )
    .framework("torch")
    .training(
        model={"custom_model": "fx_model"},
        lr=1e-4,
        clip_param=0.2,
        vf_clip_param=10.0,
        entropy_coeff=0.01,
        gamma=0.99,
        train_batch_size=1200,
    )
    # .debugging(log_level="ERROR")
    .resources(num_gpus=num_gpus)
    .env_runners(
        num_cpus_per_env_runner=1,
        num_env_runners=suggested_workers,
        rollout_fragment_length=600,
    )
    .api_stack(
        enable_rl_module_and_learner=False, enable_env_runner_and_connector_v2=False
    )
)

# %%
trainer = config.build_algo()
# Out:
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm.py:525: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2026-02-09 23:15:33,436	ERROR actor_manager.py:973 -- Ray error (The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=2504, ip=127.0.0.1, actor_id=2eda0e647b9e05655150684401000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001F9818C8380>)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\envs\registration.py", line 681, in make
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\envs\registration.py", line 526, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\envs\registration.py", line 392, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\envs\registration.py", line 369, in _check_name_exists
#     raise error.NameNotFound(
# gymnasium.error.NameNotFound: Environment `fx_trading_env` doesn't exist.
#
# During handling of the above exception, another exception occurred:
#
# ray::RolloutWorker.__init__() (pid=2504, ip=127.0.0.1, actor_id=2eda0e647b9e05655150684401000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001F9818C8380>)
#   File "python\\ray\\_raylet.pyx", line 1715, in ray._raylet.execute_task
#   File "python\\ray\\_raylet.pyx", line 1826, in ray._raylet.execute_task
#   File "python\\ray\\_raylet.pyx", line 1722, in ray._raylet.execute_task
#   File "python\\ray\\_raylet.pyx", line 1665, in ray._raylet.execute_task.function_executor
#   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\function_manager.py", line 693, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 461, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 396, in __init__
#     self.env = env_creator(copy.deepcopy(self.env_context))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\env\utils\__init__.py", line 112, in _gym_env_creator
#     raise EnvError(ERR_MSG_INVALID_ENV_DESCRIPTOR.format(env_descriptor))
# ray.rllib.utils.error.EnvError: The env string you provided ('fx_trading_env') is:
# a) Not a supported or an installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gymnasium[atari]` and prefix the environment name with `ale_py:`, for example, `"ale_py:ALE/Pong-v5"`.
# b) To register your custom env, do `from ray import tune; tune.register_env('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config.environment(env='[name]').
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.envs.classes.repeat_after_me_env.RepeatAfterMeEnv`), taking actor 1 out of service.
# 2026-02-09 23:15:33,438	ERROR env_runner_group.py:794 -- Validation of EnvRunner failed! Error=The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=2504, ip=127.0.0.1, actor_id=2eda0e647b9e05655150684401000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001F9818C8380>)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\envs\registration.py", line 681, in make
#     env_spec = _find_spec(id)
#                ^^^^^^^^^^^^^^
#   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\envs\registration.py", line 526, in _find_spec
#     _check_version_exists(ns, name, version)
#   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\envs\registration.py", line 392, in _check_version_exists
#     _check_name_exists(ns, name)
#   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\envs\registration.py", line 369, in _check_name_exists
#     raise error.NameNotFound(
# gymnasium.error.NameNotFound: Environment `fx_trading_env` doesn't exist.
#
# During handling of the above exception, another exception occurred:
#
# ray::RolloutWorker.__init__() (pid=2504, ip=127.0.0.1, actor_id=2eda0e647b9e05655150684401000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001F9818C8380>)
#   File "python\\ray\\_raylet.pyx", line 1715, in ray._raylet.execute_task
#   File "python\\ray\\_raylet.pyx", line 1826, in ray._raylet.execute_task
#   File "python\\ray\\_raylet.pyx", line 1722, in ray._raylet.execute_task
#   File "python\\ray\\_raylet.pyx", line 1665, in ray._raylet.execute_task.function_executor
#   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\function_manager.py", line 693, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 461, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 396, in __init__
#     self.env = env_creator(copy.deepcopy(self.env_context))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\env\utils\__init__.py", line 112, in _gym_env_creator
#     raise EnvError(ERR_MSG_INVALID_ENV_DESCRIPTOR.format(env_descriptor))
# ray.rllib.utils.error.EnvError: The env string you provided ('fx_trading_env') is:
# a) Not a supported or an installed environment.
# b) Not a tune-registered environment creator.
# c) Not a valid env class string.
#
# Try one of the following:
# a) For Atari support: `pip install gymnasium[atari]` and prefix the environment name with `ale_py:`, for example, `"ale_py:ALE/Pong-v5"`.
# b) To register your custom env, do `from ray import tune; tune.register_env('[name]', lambda cfg: [return env obj from here using cfg])`.
#    Then in your config, do `config.environment(env='[name]').
# c) Make sure you provide a fully qualified classpath, e.g.:
#    `ray.rllib.examples.envs.classes.repeat_after_me_env.RepeatAfterMeEnv`
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 trainer = config.build_algo()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm_config.py:1003, in AlgorithmConfig.build_algo(self, env, logger_creator, use_copy)
#    1000 if isinstance(self.algo_class, str):
#    1001     algo_class = get_trainable_cls(self.algo_class)
# -> 1003 return algo_class(
#    1004     config=self if not use_copy else copy.deepcopy(self),
#    1005     logger_creator=self.logger_creator,
#    1006 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm.py:577, in Algorithm.__init__(self, config, env, logger_creator, **kwargs)
#     574 self._metrics_impala_training_step_zero_input_batches: Optional[Counter] = None
#     575 self._metrics_impala_training_step_env_steps_dropped: Optional[Counter] = None
# --> 577 super().__init__(
#     578     config=config,
#     579     logger_creator=logger_creator,
#     580     **kwargs,
#     581 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\trainable.py:158, in Trainable.__init__(self, config, logger_creator, storage)
#     154     logger.debug(f"StorageContext on the TRAINABLE:\n{storage}")
#     156 self._open_logfiles(stdout_file, stderr_file)
# --> 158 self.setup(copy.deepcopy(self.config))
#     159 setup_time = time.time() - self._start_time
#     160 if setup_time > SETUP_TIME_THRESHOLD:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm.py:823, in Algorithm.setup(self, config)
#     819     self.offline_data = None
#     821 if self.config.is_online or not self.config.enable_env_runner_and_connector_v2:
#     822     # Create a set of env runner actors via a EnvRunnerGroup.
# --> 823     self.env_runner_group = EnvRunnerGroup(
#     824         env_creator=self.env_creator,
#     825         validate_env=self.validate_env,
#     826         default_policy_class=self.get_default_policy_class(self.config),
#     827         config=self.config,
#     828         # New API stack: User decides whether to create local env runner.
#     829         # Old API stack: Always create local EnvRunner.
#     830         local_env_runner=(
#     831             True
#     832             if not self.config.enable_env_runner_and_connector_v2
#     833             else self.config.create_local_env_runner
#     834         ),
#     835         logdir=self.logdir,
#     836         tune_trial_id=self.trial_id,
#     837     )
#     839 # Compile, validate, and freeze an evaluation config.
#     840 self.evaluation_config = self.config.get_evaluation_config_object()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\env\env_runner_group.py:197, in EnvRunnerGroup.__init__(self, env_creator, validate_env, default_policy_class, config, local_env_runner, logdir, _setup, tune_trial_id, pg_offset, num_env_runners, num_workers, local_worker)
#     195 if _setup:
#     196     try:
# --> 197         self._setup(
#     198             validate_env=validate_env,
#     199             config=config,
#     200             num_env_runners=(
#     201                 num_env_runners
#     202                 if num_env_runners is not None
#     203                 else config.num_env_runners
#     204             ),
#     205             local_env_runner=local_env_runner,
#     206         )
#     207     # EnvRunnerGroup creation possibly fails, if some (remote) workers cannot
#     208     # be initialized properly (due to some errors in the EnvRunners's
#     209     # constructor).
#     210     except RayActorError as e:
#     211         # In case of an actor (remote worker) init failure, the remote worker
#     212         # may still exist and will be accessible, however, e.g. calling
#     213         # its `sample.remote()` would result in strange "property not found"
#     214         # errors.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\env\env_runner_group.py:285, in EnvRunnerGroup._setup(self, validate_env, config, num_env_runners, local_env_runner)
#     276 # If num_env_runners > 0 and we don't have an env on the local worker,
#     277 # get the observation- and action spaces for each policy from
#     278 # the first remote worker (which does have an env).
#     279 if (
#     280     local_env_runner
#     281     and self._worker_manager.num_actors() > 0
#     282     and not config.create_env_on_local_worker
#     283     and (not config.observation_space or not config.action_space)
#     284 ):
# --> 285     spaces = self.get_spaces()
#     286 else:
#     287     spaces = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\env\env_runner_group.py:313, in EnvRunnerGroup.get_spaces(self)
#     306 # Get ID of the first remote worker.
#     307 remote_worker_ids = (
#     308     [self._worker_manager.actor_ids()[0]]
#     309     if self._worker_manager.actor_ids()
#     310     else []
#     311 )
# --> 313 spaces = self.foreach_env_runner(
#     314     lambda env_runner: env_runner.get_spaces(),
#     315     remote_worker_ids=remote_worker_ids,
#     316     local_env_runner=not remote_worker_ids,
#     317 )[0]
#     319 logger.info(
#     320     "Inferred observation/action spaces from remote "
#     321     f"worker (local worker has no env): {spaces}"
#     322 )
#     324 return spaces
#
# IndexError: list index out of range

# %%
num_epochs = 1
# num_epochs = 100

# %% [markdown]
# # todo: DEBUG check all states

# %%
# warnings.filterwarnings('ignore')

episode_rewards = []

for i in trange(num_epochs):

    result = trainer.train()

    average_episode_reward = np.mean(
        result[ENV_RUNNER_RESULTS]["hist_stats"]["episode_reward"]
    )
    episode_rewards.append(average_episode_reward)

    if i % 5 == 0:
        print(f"Last 5 epochs reward: {np.mean(episode_rewards[-5:])}")
# Out:
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]2026-02-09 23:06:06,859	WARNING rollout_ops.py:122 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2026-02-09 23:06:16,820	ERROR actor_manager.py:973 -- Ray error (The actor a23207f0ad308ce6cacea1c401000000 is unavailable: The actor is temporarily unavailable: IOError: The actor was restarted. The task may or may not have been executed on the actor.), taking actor 1 out of service.
# 2026-02-09 23:06:16,820	ERROR actor_manager.py:771 -- The actor a23207f0ad308ce6cacea1c401000000 is unavailable: The actor is temporarily unavailable: IOError: The actor was restarted. The task may or may not have been executed on the actor.
# NoneType: None
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [01:11<00:00, 71.31s/it]
# Last 5 epochs reward: nan

# %%
result[ENV_RUNNER_RESULTS]["hist_stats"]

# %% [markdown]
# Plot results + trailing sharpe ratio

# %%
result[ENV_RUNNER_RESULTS]["hist_stats"]
