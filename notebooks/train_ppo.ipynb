# %% [markdown]
# # PPO algorithm

# %% [markdown]
# ## Imports

# %%
1 + 1
# Out:
# 2

# %%
import os
import sys

sys.path.append("..")

# %%
# python -m build --sdist
# %pip install rl_trading-0.0.1.tar.gz

# %%
from copy import deepcopy

import dill
import numpy as np
import pandas as pd
import ray
import torch
import matplotlib.pyplot as plt

from pprint import pprint
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.models import ModelCatalog
from ray.rllib.utils.metrics import ENV_RUNNER_RESULTS
from ray.tune.registry import register_env
from tqdm import tqdm, trange

# %%
# Comment next two lines to run in collab
# %load_ext autoreload
# %autoreload 2

from rl_trading.environments.fx_environment import FxTradingEnv
from rl_trading.models.fx_model import FXModel
from rl_trading.environments.base_environment import (
    DEFAULT_TRADING_PARAMS,
)

# %% [markdown]
# ## Todo

# %% [markdown]
# - Increase number of trading days to 5
# - Try SAC and DreamerV3

# %% [markdown]
# ---
# ## Load and prepare historical data

# %%
# comment for collab
data_folder = "C:\\Users\\Ivan\\rl_trading\\data\\"
# data_folder = ""

# %%
with open(f"{data_folder}preprocessed_data.pkl", "rb") as f:
    historical_data = dill.load(f)

# %%
train_prices, train_data, _, _ = historical_data.values()

# %%
min(train_prices.keys()), max(train_prices.keys())
# Out:
# ('2022-06-01 09:00:00', '2024-05-31 16:59:00')

# %% [markdown]
# What to trade:

# %%
TICKER_SET = ('EURJPY', 'EURUSD', 'SGDJPY', 'USDJPY', 'USDSGD',)

# %%
del historical_data

# %% [markdown]
# ---
# ## Trading config

# %% [markdown]
# ### Trading setup:
#
# 1. Algorithm starts approx equal positions (10k of EUR, USD and SGD and 1m of JPY)
# 2. It trades minutely for set amount of days
# 3. The P&L is computed in US dollars
# 3. For more info on transaction costs and slippage see the README.md
# 4. We assume the market is liquid enough for our volume and disregard trading book structure

# %%
CURRENT_PORTFOLIO = {
    "USD": 10_000,
    "EUR": 10_000,
    "SGD": 10_000,
    "JPY": 1_000_000,
}

# %% [markdown]
# if all actions are 0.99 -> 0.05 * 0.99**2 -> 0.05

# %%
TRADING_PARAMS = DEFAULT_TRADING_PARAMS.copy()
TRADING_PARAMS["action_penalty"] = 0.05
TRADING_PARAMS["no_trade_penalty"] = 0.5
TRADING_PARAMS["max_delta_in_weights"] = 0.99  # Not 1 for algorithm stability
TRADING_PARAMS["reward"] = "total_profit"  # "diff_sharpe" or "total_profit"

# %%
ENV_CONFIG = {
    "historical_prices": train_prices,
    "features_dataset": train_data,
    "initial_portfolio": CURRENT_PORTFOLIO,
    "ticker_set": TICKER_SET,
    "start_datetime": None,  # pd.Timestamp("2023-01-03 09:00:00"),
    "episode_length_days": 1,
    "trading_params": TRADING_PARAMS,
}

# %%
VALIDATION_TRADING_PARAMS = TRADING_PARAMS.copy()
VALIDATION_TRADING_PARAMS["no_trade_penalty"] = 0
VALIDATION_TRADING_PARAMS["action_penalty"] = 0
VALIDATION_TRADING_PARAMS["reward"] = "total_profit"

# %%
ENV_VALIDATION_CONFIG = {
    "historical_prices": train_prices,
    "features_dataset": train_data,
    "initial_portfolio": CURRENT_PORTFOLIO,
    "ticker_set": TICKER_SET,
    "start_datetime": None,  # pd.Timestamp("2023-01-03 09:00:00"),
    "episode_length_days": ENV_CONFIG["episode_length_days"],
    "trading_params": VALIDATION_TRADING_PARAMS,
}

# %% [markdown]
# ---
# ## Trial runs
#
# Run trials on validation dataset with random actions to measure execution time and debug the algorithm
#
# (You can skip that part)

# %% [markdown]
# ## todo: turn into function

# %%
fx_env = FxTradingEnv(**ENV_VALIDATION_CONFIG)

# %%
fx_env.preprocess_data()

# %%
pprint(fx_env.trading_params)
# Out:
# {'action_penalty': 0,
#  'base_currency': 'USD',
#  'long_only': True,
#  'max_delta_in_weights': 0.99,
#  'no_trade_penalty': 0,
#  'reward': 'total_profit',
#  'sharpe_eta': 0.1,
#  'slippage': (0.0001, 0.0002),
#  'trade_fee': 0.0001}

# %%
execution_times = []
portfolio_pos = []
total_rewards = []
all_actions = []

for _ in trange(100):

    state, info = fx_env.reset()

    start_time = pd.Timestamp.now()
    done = False

    current_portfolio = []
    total_reward = []
    cur_actions = []

    while not done:

        action = np.random.uniform(
            low=-1, high=1, size=len(TICKER_SET)
        )
        state, reward, terminated, truncated, info = fx_env.step(action)
        done = terminated or truncated

        current_portfolio.append(deepcopy(info["portfolio"]))
        total_reward.append(reward)
        cur_actions.append(action)

    execution_times.append((pd.Timestamp.now() - start_time).total_seconds())
    total_rewards.append(deepcopy(total_reward))
    portfolio_pos.append(deepcopy(current_portfolio))
    all_actions.append(deepcopy(cur_actions))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:26<00:00,  3.71it/s]

# %%
# [np.isnan(x).any() for x in total_rewards]

# %%
np.quantile(execution_times, [0.01, 0.5, 0.99])
# Out:
# array([0.12044356, 0.174626  , 0.20415375])

# %%
total_rewards = [np.array(x) for x in total_rewards]

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))

axs[0].hist([np.exp(sum(x)) - 1 for x in total_rewards], bins=50)
axs[0].set_xlabel("percentage")
axs[0].set_title("Total return")

axs[1].hist([np.mean(x) / np.std(x) for x in total_rewards], bins=50)
axs[1].set_xlabel("")
axs[1].set_title("Sharpe ratio")

fig.suptitle("Validation results")
plt.tight_layout()
plt.show()

# %%
pd.DataFrame(all_actions[50], columns=TICKER_SET).plot()
plt.title("Portfolio positions")
plt.xlabel("Minute")
plt.ylabel("Units of respective ccy")
plt.show()

# %%
pd.DataFrame.from_dict(portfolio_pos[50]).plot()
plt.title("Portfolio positions")
plt.xlabel("Minute")
plt.ylabel("Units of respective ccy")
plt.show()

# %%
fx_env.close()

# %% [markdown]
# ---
# ## RLLib setup

# %%
def env_creator(env_config):
    """
    Create env
    """
    fx_env = FxTradingEnv(**env_config)
    fx_env.preprocess_data()
    return fx_env

# %%
register_env("fx_trading_env", env_creator)
ModelCatalog.register_custom_model("fx_model", FXModel)

# %%
ray.init(
    ignore_reinit_error=True,
    # # To work with cloned repository
    # # Comment for Google collab or if you use pip install
    runtime_env={
        "working_dir": os.path.dirname(os.path.abspath(".")),
        "py_modules": [os.path.abspath(".")],
        "excludes": [
            "*.pyc",
            "__pycache__",
            "*.parquet.gzip",
            "*data/",
            "notebooks/",
            ".git/",
        ],
    },
)
# Out:
# 2026-02-25 11:02:31,408	INFO worker.py:2023 -- Started a local Ray instance.
# 2026-02-25 11:02:31,462	INFO packaging.py:588 -- Creating a file package for local module 'C:\Users\Ivan\rl_trading\notebooks'.
# 2026-02-25 11:02:31,500	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_21baed35ea440f84.zip' (2.81MiB) to Ray cluster...
# 2026-02-25 11:02:31,515	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_21baed35ea440f84.zip'.
# 2026-02-25 11:02:31,638	INFO packaging.py:588 -- Creating a file package for local module 'C:\Users\Ivan\rl_trading'.
# 2026-02-25 11:02:31,701	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_a2b8993fa5a03493.zip' (0.68MiB) to Ray cluster...
# 2026-02-25 11:02:31,730	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_a2b8993fa5a03493.zip'.
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# RayContext(dashboard_url='', python_version='3.12.10', ray_version='2.52.1', ray_commit='4ebdc0abe5e5a551625fe7f87053c7e668a6ff74')
# (pid=gcs_server) [2026-02-25 11:02:59,618 E 2296 7912] (gcs_server.exe) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2026-02-25 11:03:06,019 E 13048 12892] (raylet.exe) main.cc:979: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14

# %%
# Use all available CPUs minus 1
# Use all GPUs if available
suggested_workers = max(os.cpu_count() - 1, 1)

if torch.cuda.is_available():
    num_gpus = torch.cuda.device_count()
else:
    num_gpus = 0

suggested_workers, num_gpus
# Out:
# (7, 0)

# %%
historical_prices_ref = ray.put(train_prices)
features_ref = ray.put(train_data)

# %%
ENV_CONFIG.update(
    {"historical_prices": historical_prices_ref, "features_dataset": features_ref}
)

# %%
pprint(ENV_CONFIG)
# Out:
# {'episode_length_days': 1,
#  'features_dataset': ObjectRef(00ffffffffffffffffffffffffffffffffffffff0100000002e1f505),
#  'historical_prices': ObjectRef(00ffffffffffffffffffffffffffffffffffffff0100000001e1f505),
#  'initial_portfolio': {'EUR': 10000,
#                        'JPY': 1000000,
#                        'SGD': 10000,
#                        'USD': 10000},
#  'start_datetime': None,
#  'ticker_set': ('EURJPY', 'EURUSD', 'SGDJPY', 'USDJPY', 'USDSGD'),
#  'trading_params': {'action_penalty': 0.05,
#                     'base_currency': 'USD',
#                     'long_only': True,
#                     'max_delta_in_weights': 0.99,
#                     'no_trade_penalty': 0.5,
#                     'reward': 'total_profit',
#                     'sharpe_eta': 0.1,
#                     'slippage': (0.0001, 0.0002),
#                     'trade_fee': 0.0001}}

# %% [markdown]
# In most PPO implementations (including RLlib), 3–10 epochs per batch is typical. Using more can actually increase the risk of getting stuck in local minima because the policy may overfit to the current batch of data, causing it to lose generalization and converge prematurely.

# %%
config = PPOConfig()

config = (
    config.environment(
        env="fx_trading_env",
        env_config=ENV_CONFIG,
    )
    .framework("torch")
    .training(
        model={"custom_model": "fx_model"},
        lr=3e-4,
        clip_param=0.2,
        grad_clip=0.5,
        vf_clip_param=10.0,
        entropy_coeff=0.01,
        gamma=0.99,
        lambda_=0.95,
        num_epochs=8,
        train_batch_size=int(16384 * ENV_CONFIG["episode_length_days"]),
    )
    .debugging(log_level="ERROR")  # DEBUG
    .resources(num_gpus=num_gpus)
    .env_runners(
        num_cpus_per_env_runner=1,
        num_env_runners=suggested_workers,
        num_envs_per_env_runner=4,
        rollout_fragment_length="auto",
        exploration_config={
            "type": "StochasticSampling",  # default
            "random_timesteps": 5_000,
        },
    )
    # .evaluation(
    #     evaluation_interval=5,
    #     evaluation_config={
    #         "explore": False,
    #     }
    # )
    .api_stack(
        enable_rl_module_and_learner=False, enable_env_runner_and_connector_v2=False
    )
)

# %%
trainer = config.build_algo()
# Out:
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm.py:525: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2026-02-25 11:04:53,033	INFO trainable.py:161 -- Trainable.setup took 115.585 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.

# %% [markdown]
# 25 features + 5 prices + 5 time features

# %%
trainer.get_policy().observation_space
# Out:
# Box(-1000000.0, 1000000.0, (36,), float32)

# %% [markdown]
# 5 ccys

# %%
trainer.get_policy().action_space
# Out:
# Box(-1.0, 1.0, (5,), float32)

# %% [markdown]
# ---
# ## Train the model

# %%
num_epochs = 200
# will not be applied for first 100
early_stopping_patience = 20
min_improvement = 0.01
best_reward = -np.inf

# %%
# warnings.filterwarnings('ignore')
episode_rewards = []
patience_counter = 0

for i in trange(num_epochs):

    result = trainer.train()

    average_episode_reward = np.mean(
        result[ENV_RUNNER_RESULTS]["hist_stats"]["episode_reward"]
    )
    episode_rewards.append(average_episode_reward)

    if np.mean(episode_rewards[-5:]) >= best_reward + min_improvement:
        best_reward = np.mean(episode_rewards[-5:])
        patience_counter = 0
    else:
        patience_counter += 1

    if (patience_counter > early_stopping_patience) and (i > 100):
        print(f"Early stopping! No improvements for {patience_counter} steps")
        break
    
    if i % 5 == 0:
        print(f"Last 5 epochs reward: {np.mean(episode_rewards[-5:])}")
# Out:
#   0%|                                                                                          | 0/200 [00:00<?, ?it/s]2026-02-25 11:09:05,155	WARNING train_ops.py:114 -- DeprecationWarning: `ray.rllib.execution.train_ops.multi_gpu_train_one_step` has been deprecated. This will raise an error in the future!
#   0%|▍                                                                               | 1/200 [00:36<1:59:30, 36.03s/it]
# Last 5 epochs reward: -8.018491466374357
#   3%|██▍                                                                             | 6/200 [03:29<1:52:51, 34.90s/it]
# Last 5 epochs reward: -14.810011208928117
#   6%|████▎                                                                          | 11/200 [06:31<1:54:44, 36.43s/it]
# Last 5 epochs reward: -15.706995661213451
#   8%|██████▎                                                                        | 16/200 [09:27<1:47:57, 35.20s/it]
# Last 5 epochs reward: -13.641443013151678
#  10%|████████▎                                                                      | 21/200 [12:22<1:45:06, 35.23s/it]
# Last 5 epochs reward: -11.037685086028318
#  13%|██████████▎                                                                    | 26/200 [15:18<1:42:03, 35.19s/it]
# Last 5 epochs reward: -8.764914388124394
#  16%|████████████▏                                                                  | 31/200 [18:11<1:37:44, 34.70s/it]
# Last 5 epochs reward: -6.702909730716085
#  18%|██████████████▏                                                                | 36/200 [21:05<1:35:04, 34.78s/it]
# Last 5 epochs reward: -4.997584573993518
#  20%|████████████████▏                                                              | 41/200 [23:58<1:31:42, 34.60s/it]
# Last 5 epochs reward: -3.7806884477581115
#  23%|██████████████████▏                                                            | 46/200 [26:43<1:21:38, 31.81s/it]
# Last 5 epochs reward: -2.8622999957134865
#  26%|████████████████████▋                                                            | 51/200 [28:10<49:24, 19.90s/it]
# Last 5 epochs reward: -2.2566781405929937
#  28%|██████████████████████▋                                                          | 56/200 [29:39<43:29, 18.12s/it]
# Last 5 epochs reward: -1.7136132326992617
#  30%|████████████████████████▋                                                        | 61/200 [31:09<41:46, 18.03s/it]
# Last 5 epochs reward: -1.3616282819179317
#  33%|██████████████████████████▋                                                      | 66/200 [32:43<41:20, 18.51s/it]
# Last 5 epochs reward: -1.0816606949647543
#  36%|████████████████████████████▊                                                    | 71/200 [34:15<39:50, 18.53s/it]
# Last 5 epochs reward: -0.8477863350329127
#  38%|██████████████████████████████▊                                                  | 76/200 [35:49<38:47, 18.77s/it]
# Last 5 epochs reward: -0.6590376093195168
#  40%|████████████████████████████████▊                                                | 81/200 [37:27<39:33, 19.95s/it]
# Last 5 epochs reward: -0.5080407203151365
#  43%|██████████████████████████████████▊                                              | 86/200 [39:18<41:41, 21.94s/it]
# Last 5 epochs reward: -0.3858856589908076
#  46%|████████████████████████████████████▊                                            | 91/200 [41:15<40:25, 22.25s/it]
# Last 5 epochs reward: -0.2899691946341692
#  48%|██████████████████████████████████████▉                                          | 96/200 [43:15<41:17, 23.82s/it]
# Last 5 epochs reward: -0.22614589011782335
#  50%|████████████████████████████████████████▍                                       | 101/200 [45:39<47:34, 28.84s/it]
# Last 5 epochs reward: -0.17533804607641396
#  53%|██████████████████████████████████████████▍                                     | 106/200 [48:34<50:29, 32.23s/it]
# Last 5 epochs reward: -0.1400640218258981
#  56%|████████████████████████████████████████████▍                                   | 111/200 [51:07<45:25, 30.63s/it]
# Last 5 epochs reward: -0.11472066152839741
#  58%|██████████████████████████████████████████████▍                                 | 116/200 [53:26<38:38, 27.61s/it]
# Last 5 epochs reward: -0.09398463459746723
#  60%|████████████████████████████████████████████████▍                               | 121/200 [55:47<37:56, 28.81s/it]
# Last 5 epochs reward: -0.08209008661968648
#  63%|██████████████████████████████████████████████████▍                             | 126/200 [58:17<37:05, 30.07s/it]
# Last 5 epochs reward: -0.07876689670302338
#  66%|███████████████████████████████████████████████████                           | 131/200 [1:00:46<34:28, 29.97s/it]
# Last 5 epochs reward: -0.07870201995112185
#  68%|█████████████████████████████████████████████████████                         | 136/200 [1:03:06<30:32, 28.64s/it]
# Last 5 epochs reward: -0.07954663355014004
#  70%|██████████████████████████████████████████████████████▉                       | 141/200 [1:05:50<31:57, 32.50s/it]
# Last 5 epochs reward: -0.07985633469155214
#  72%|███████████████████████████████████████████████████████▊                      | 143/200 [1:07:24<26:52, 28.28s/it]
# Early stopping! No improvements for 21 steps

# %% [markdown]
# ### Save pytorch model for later evaluation

# %% [markdown]
# We save only pytorch part to ensure latency and easier usage

# %%
policy = trainer.get_policy()

# %%
MODEL_NAME = "MODEL_WEIGHTS_1_MIN_1_DAY.pth"

# %%
torch.save(policy.model.state_dict(), f"../trained_models/{MODEL_NAME}")

# %% [markdown]
# ### Plot training results

# %% [markdown]
# Includes action penalty

# %%
rewards = pd.Series(episode_rewards)

# %%
rewards.rolling(10).mean().plot()
plt.title("Average total reward per 10 iterations")
plt.xlabel("Iteration")
plt.ylabel("Total reward")
plt.show()

# %%
rewards.rolling(10).mean().iloc[-50:].plot()
plt.title("Average total reward per 10 iterations (last 50)")
plt.xlabel("Iteration")
plt.ylabel("Total reward")
plt.show()
