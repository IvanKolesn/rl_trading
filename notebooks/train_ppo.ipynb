# %% [markdown]
# # PPO algorithm

# %% [markdown]
# ## Imports

# %%
1 + 1
# Out:
# 2

# %%
import os
import sys

sys.path.append("..")

# %%
# python -m build --sdist
# %pip install rl_trading-0.0.1.tar.gz

# %%
from copy import deepcopy

import dill
import numpy as np
import pandas as pd
import ray
import torch
import matplotlib.pyplot as plt

from pprint import pprint
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.models import ModelCatalog
from ray.rllib.utils.metrics import ENV_RUNNER_RESULTS
from ray.tune.registry import register_env
from tqdm import tqdm, trange

# %%
# Comment next two lines to run in collab
# %load_ext autoreload
# %autoreload 2

from rl_trading.environments.fx_environment import FxTradingEnv
from rl_trading.models.fx_model import FXModel
from rl_trading.environments.base_environment import (
    DEFAULT_TRADING_PARAMS,
)

# %% [markdown]
# ## Todo

# %% [markdown]
# - Increase number of trading days to 5
# - Try SAC and DreamerV3

# %% [markdown]
# ---
# ## Load and prepare historical data

# %%
# comment for collab
data_folder = "C:\\Users\\Ivan\\rl_trading\\data\\"
# data_folder = ""

# %%
with open(f"{data_folder}preprocessed_data.pkl", "rb") as f:
    historical_data = dill.load(f)

# %%
train_prices, train_data, _, _ = historical_data.values()

# %%
min(train_prices.keys()), max(train_prices.keys())
# Out:
# ('2022-06-01 09:00:00', '2024-05-31 16:59:00')

# %% [markdown]
# What to trade:

# %%
TICKER_SET = ('EURJPY', 'EURUSD', 'SGDJPY', 'USDJPY', 'USDSGD',)

# %%
del historical_data

# %% [markdown]
# ---
# ## Trading config

# %% [markdown]
# ### Trading setup:
#
# 1. Algorithm starts approx equal positions (10k of EUR, USD and SGD and 1m of JPY)
# 2. It trades minutely for set amount of days
# 3. The P&L is computed in US dollars
# 3. For more info on transaction costs and slippage see the README.md
# 4. We assume the market is liquid enough for our volume and disregard trading book structure

# %%
CURRENT_PORTFOLIO = {
    "USD": 10_000,
    "EUR": 10_000,
    "SGD": 10_000,
    "JPY": 1_000_000,
}

# %% [markdown]
# if all actions are 0.99 -> 0.05 * 0.99**2 -> 0.05

# %%
TRADING_PARAMS = DEFAULT_TRADING_PARAMS.copy()
TRADING_PARAMS["action_penalty"] = 0.05
TRADING_PARAMS["no_trade_penalty"] = 0.5
TRADING_PARAMS["max_delta_in_weights"] = 0.99  # Not 1 for algorithm stability
TRADING_PARAMS["reward"] = "total_profit"  # "diff_sharpe" or "total_profit"

# %%
ENV_CONFIG = {
    "historical_prices": train_prices,
    "features_dataset": train_data,
    "initial_portfolio": CURRENT_PORTFOLIO,
    "ticker_set": TICKER_SET,
    "start_datetime": None,  # pd.Timestamp("2023-01-03 09:00:00"),
    "episode_length_days": 10,
    "trading_params": TRADING_PARAMS,
}

# %%
VALIDATION_TRADING_PARAMS = TRADING_PARAMS.copy()
VALIDATION_TRADING_PARAMS["no_trade_penalty"] = 0
VALIDATION_TRADING_PARAMS["action_penalty"] = 0
VALIDATION_TRADING_PARAMS["reward"] = "total_profit"

# %%
ENV_VALIDATION_CONFIG = {
    "historical_prices": train_prices,
    "features_dataset": train_data,
    "initial_portfolio": CURRENT_PORTFOLIO,
    "ticker_set": TICKER_SET,
    "start_datetime": None,  # pd.Timestamp("2023-01-03 09:00:00"),
    "episode_length_days": ENV_CONFIG["episode_length_days"],
    "trading_params": VALIDATION_TRADING_PARAMS,
}

# %% [markdown]
# ---
# ## Trial runs
#
# Run trials on validation dataset with random actions to measure execution time and debug the algorithm
#
# (You can skip that part)

# %% [markdown]
# ## todo: turn into function

# %%
fx_env = FxTradingEnv(**ENV_VALIDATION_CONFIG)

# %%
fx_env.preprocess_data()

# %%
pprint(fx_env.trading_params)
# Out:
# {'action_penalty': 0,
#  'base_currency': 'USD',
#  'long_only': True,
#  'max_delta_in_weights': 0.99,
#  'no_trade_penalty': 0,
#  'reward': 'total_profit',
#  'sharpe_eta': 0.1,
#  'slippage': (0.0001, 0.0002),
#  'trade_fee': 0.0001}

# %%
execution_times = []
portfolio_pos = []
total_rewards = []
all_actions = []

for _ in trange(100):

    state, info = fx_env.reset()

    start_time = pd.Timestamp.now()
    done = False

    current_portfolio = []
    total_reward = []
    cur_actions = []

    while not done:

        action = np.random.uniform(
            low=-1, high=1, size=len(TICKER_SET)
        )
        state, reward, terminated, truncated, info = fx_env.step(action)
        done = terminated or truncated

        current_portfolio.append(deepcopy(info["portfolio"]))
        total_reward.append(reward)
        cur_actions.append(action)

    execution_times.append((pd.Timestamp.now() - start_time).total_seconds())
    total_rewards.append(deepcopy(total_reward))
    portfolio_pos.append(deepcopy(current_portfolio))
    all_actions.append(deepcopy(cur_actions))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:11<00:00,  8.43it/s]

# %%
# [np.isnan(x).any() for x in total_rewards]

# %%
np.quantile(execution_times, [0.01, 0.5, 0.99])
# Out:
# array([0.04559218, 0.0712945 , 0.10088289])

# %%
total_rewards = [np.array(x) for x in total_rewards]

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))

axs[0].hist([np.exp(sum(x)) - 1 for x in total_rewards], bins=50)
axs[0].set_xlabel("percentage")
axs[0].set_title("Total return")

axs[1].hist([np.mean(x) / np.std(x) for x in total_rewards], bins=50)
axs[1].set_xlabel("")
axs[1].set_title("Sharpe ratio")

fig.suptitle("Validation results")
plt.tight_layout()
plt.show()

# %%
pd.DataFrame(all_actions[50], columns=TICKER_SET).plot()
plt.title("Portfolio positions")
plt.xlabel("Minute")
plt.ylabel("Units of respective ccy")
plt.show()

# %%
pd.DataFrame.from_dict(portfolio_pos[50]).plot()
plt.title("Portfolio positions")
plt.xlabel("Minute")
plt.ylabel("Units of respective ccy")
plt.show()

# %%
fx_env.close()

# %% [markdown]
# ---
# ## RLLib setup

# %%
def env_creator(env_config):
    """
    Create env
    """
    fx_env = FxTradingEnv(**env_config)
    fx_env.preprocess_data()
    return fx_env

# %%
register_env("fx_trading_env", env_creator)
ModelCatalog.register_custom_model("fx_model", FXModel)

# %%
ray.init(
    ignore_reinit_error=True,
    # # To work with cloned repository
    # # Comment for Google collab or if you use pip install
    runtime_env={
        "working_dir": os.path.dirname(os.path.abspath(".")),
        "py_modules": [os.path.abspath(".")],
        "excludes": [
            "*.pyc",
            "__pycache__",
            "*.parquet.gzip",
            "*data/",
            "notebooks/",
            ".git/",
        ],
    },
)
# Out:
# 2026-02-25 12:56:31,075	INFO worker.py:2023 -- Started a local Ray instance.
# 2026-02-25 12:56:31,116	INFO packaging.py:588 -- Creating a file package for local module 'C:\Users\Ivan\rl_trading\notebooks'.
# 2026-02-25 12:56:31,162	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_bf84f019007ed68a.zip' (2.38MiB) to Ray cluster...
# 2026-02-25 12:56:31,172	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_bf84f019007ed68a.zip'.
# 2026-02-25 12:56:31,273	INFO packaging.py:588 -- Creating a file package for local module 'C:\Users\Ivan\rl_trading'.
# 2026-02-25 12:56:31,324	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_b1a9e30e46901ebc.zip' (0.90MiB) to Ray cluster...
# 2026-02-25 12:56:31,328	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_b1a9e30e46901ebc.zip'.
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# RayContext(dashboard_url='', python_version='3.12.10', ray_version='2.52.1', ray_commit='4ebdc0abe5e5a551625fe7f87053c7e668a6ff74')
# (pid=gcs_server) [2026-02-25 12:56:59,693 E 4124 15416] (gcs_server.exe) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2026-02-25 12:57:04,352 E 16536 15304] (raylet.exe) main.cc:979: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14

# %%
# Use all available CPUs minus 1
# Use all GPUs if available
suggested_workers = max(os.cpu_count() - 1, 1)

if torch.cuda.is_available():
    num_gpus = torch.cuda.device_count()
else:
    num_gpus = 0

suggested_workers, num_gpus
# Out:
# (7, 0)

# %%
historical_prices_ref = ray.put(train_prices)
features_ref = ray.put(train_data)

# %%
ENV_CONFIG.update(
    {"historical_prices": historical_prices_ref, "features_dataset": features_ref}
)

# %%
pprint(ENV_CONFIG)
# Out:
# {'episode_length_days': 1,
#  'features_dataset': ObjectRef(00ffffffffffffffffffffffffffffffffffffff0100000002e1f505),
#  'historical_prices': ObjectRef(00ffffffffffffffffffffffffffffffffffffff0100000001e1f505),
#  'initial_portfolio': {'EUR': 10000,
#                        'JPY': 1000000,
#                        'SGD': 10000,
#                        'USD': 10000},
#  'start_datetime': None,
#  'ticker_set': ('EURJPY', 'EURUSD', 'SGDJPY', 'USDJPY', 'USDSGD'),
#  'trading_params': {'action_penalty': 0.05,
#                     'base_currency': 'USD',
#                     'long_only': True,
#                     'max_delta_in_weights': 0.99,
#                     'no_trade_penalty': 0.5,
#                     'reward': 'total_profit',
#                     'sharpe_eta': 0.1,
#                     'slippage': (0.0001, 0.0002),
#                     'trade_fee': 0.0001}}

# %% [markdown]
# In most PPO implementations (including RLlib), 3–10 epochs per batch is typical. Using more can actually increase the risk of getting stuck in local minima because the policy may overfit to the current batch of data, causing it to lose generalization and converge prematurely.

# %%
config = PPOConfig()

config = (
    config.environment(
        env="fx_trading_env",
        env_config=ENV_CONFIG,
    )
    .framework("torch")
    .training(
        model={"custom_model": "fx_model"},
        lr=3e-4,
        clip_param=0.2,
        grad_clip=0.5,
        vf_clip_param=10.0,
        entropy_coeff=0.01,
        gamma=0.99,
        lambda_=0.95,
        num_epochs=8,
        train_batch_size=int(16384 * ENV_CONFIG["episode_length_days"]),
    )
    .debugging(log_level="ERROR")  # DEBUG
    .resources(num_gpus=num_gpus)
    .env_runners(
        num_cpus_per_env_runner=1,
        num_env_runners=suggested_workers,
        num_envs_per_env_runner=4,
        rollout_fragment_length="auto",
        exploration_config={
            "type": "StochasticSampling",  # default
            "random_timesteps": 5_000,
        },
    )
    # .evaluation(
    #     evaluation_interval=5,
    #     evaluation_config={
    #         "explore": False,
    #     }
    # )
    .api_stack(
        enable_rl_module_and_learner=False, enable_env_runner_and_connector_v2=False
    )
)

# %%
trainer = config.build_algo()
# Out:
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm.py:525: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2026-02-25 12:58:18,002	INFO trainable.py:161 -- Trainable.setup took 97.647 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.

# %% [markdown]
# 25 features + 5 prices + 5 time features

# %%
trainer.get_policy().observation_space
# Out:
# Box(-1000000.0, 1000000.0, (36,), float32)

# %% [markdown]
# 5 ccys

# %%
trainer.get_policy().action_space
# Out:
# Box(-1.0, 1.0, (5,), float32)

# %% [markdown]
# ---
# ## Train the model

# %%
num_epochs = 200
# will not be applied for first 100
early_stopping_patience = 20
min_improvement = 0.01
best_reward = -np.inf

# %%
# warnings.filterwarnings('ignore')
episode_rewards = []
patience_counter = 0

for i in trange(num_epochs):

    result = trainer.train()

    average_episode_reward = np.mean(
        result[ENV_RUNNER_RESULTS]["hist_stats"]["episode_reward"]
    )
    episode_rewards.append(average_episode_reward)

    if np.mean(episode_rewards[-5:]) >= best_reward + min_improvement:
        best_reward = np.mean(episode_rewards[-5:])
        patience_counter = 0
    else:
        patience_counter += 1

    if (patience_counter > early_stopping_patience) and (i > 100):
        print(f"Early stopping! No improvements for {patience_counter} steps")
        break
    
    if i % 5 == 0:
        print(f"Last 5 epochs reward: {np.mean(episode_rewards[-5:])}")
# Out:
#   0%|                                                                                          | 0/200 [00:00<?, ?it/s]2026-02-25 12:58:24,455	WARNING train_ops.py:114 -- DeprecationWarning: `ray.rllib.execution.train_ops.multi_gpu_train_one_step` has been deprecated. This will raise an error in the future!
#   0%|▍                                                                               | 1/200 [00:19<1:04:57, 19.58s/it]
# Last 5 epochs reward: -7.856750498562012
#   2%|██                                                                              | 5/200 [02:04<1:20:39, 24.82s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 7
#       3 patience_counter = 0
#       5 for i in trange(num_epochs):
# ----> 7     result = trainer.train()
#       9     average_episode_reward = np.mean(
#      10         result[ENV_RUNNER_RESULTS]["hist_stats"]["episode_reward"]
#      11     )
#      12     episode_rewards.append(average_episode_reward)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\trainable.py:328, in Trainable.train(self)
#     326 start = time.time()
#     327 try:
# --> 328     result = self.step()
#     329 except Exception as e:
#     330     skipped = skip_exceptions(e)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm.py:1245, in Algorithm.step(self)
#    1240         train_results, train_iter_ctx = self._run_one_training_iteration()
#    1241     else:
#    1242         (
#    1243             train_results,
#    1244             train_iter_ctx,
# -> 1245         ) = self._run_one_training_iteration_old_api_stack()
#    1247 # Sequential: Train (already done above), then evaluate.
#    1248 if evaluate_this_iter and not self.config.evaluation_parallel_to_training:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm.py:4330, in Algorithm._run_one_training_iteration_old_api_stack(self)
#    4323         self._make_on_env_runners_recreated_callbacks(
#    4324             config=self.config,
#    4325             env_runner_group=self.env_runner_group,
#    4326             restored_env_runner_indices=restored,
#    4327         )
#    4329 with self._timers[TRAINING_STEP_TIMER]:
# -> 4330     training_step_results = self.training_step()
#    4332 if training_step_results:
#    4333     results = training_step_results
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\ppo\ppo.py:393, in PPO.training_step(self)
#     389 @override(Algorithm)
#     390 def training_step(self) -> None:
#     391     # Old API stack (Policy, RolloutWorker, Connector).
#     392     if not self.config.enable_env_runner_and_connector_v2:
# --> 393         return self._training_step_old_api_stack()
#     395     # Collect batches from sample workers until we have a full batch.
#     396     with self.metrics.log_time((TIMERS, ENV_RUNNER_SAMPLING_TIMER)):
#     397         # Sample in parallel from the workers.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\ppo\ppo.py:489, in PPO._training_step_old_api_stack(self)
#     487     train_results = train_one_step(self, train_batch)
#     488 else:
# --> 489     train_results = multi_gpu_train_one_step(self, train_batch)
#     491 policies_to_update = list(train_results.keys())
#     493 global_vars = {
#     494     "timestep": self._counters[NUM_AGENT_STEPS_SAMPLED],
#     495     # TODO (sven): num_grad_updates per each policy should be
#    (...)
#     500     },
#     501 }
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\execution\train_ops.py:181, in multi_gpu_train_one_step(algorithm, train_batch)
#     176         permutation = np.random.permutation(num_batches)
#     177         for batch_index in range(num_batches):
#     178             # Learn on the pre-loaded data in the buffer.
#     179             # Note: For minibatch SGD, the data is an offset into
#     180             # the pre-loaded entire train batch.
# --> 181             results = policy.learn_on_loaded_batch(
#     182                 permutation[batch_index] * per_device_batch_size, buffer_index=0
#     183             )
#     185             learner_info_builder.add_learn_on_batch_results(results, policy_id)
#     187 # Tower reduce and finalize results.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\policy\torch_policy_v2.py:746, in TorchPolicyV2.learn_on_loaded_batch(self, offset, buffer_index)
#     743     else:
#     744         batch = self._loaded_batches[0][0][offset : offset + device_batch_size]
# --> 746     return self.learn_on_batch(batch)
#     748 if len(self.devices) > 1:
#     749     # Copy weights of main model (tower-0) to all other towers.
#     750     state_dict = self.model.state_dict()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\utils\threading.py:24, in with_lock.<locals>.wrapper(self, *a, **k)
#      22 try:
#      23     with self._lock:
# ---> 24         return func(self, *a, **k)
#      25 except AttributeError as e:
#      26     if "has no attribute '_lock'" in e.args[0]:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\policy\torch_policy_v2.py:627, in TorchPolicyV2.learn_on_batch(self, postprocessed_batch)
#     621 self.callbacks.on_learn_on_batch(
#     622     policy=self, train_batch=postprocessed_batch, result=learn_stats
#     623 )
#     625 # Compute gradients (will calculate all losses and `backward()`
#     626 # them to get the grads).
# --> 627 grads, fetches = self.compute_gradients(postprocessed_batch)
#     629 # Step the optimizers.
#     630 self.apply_gradients(_directStepOptimizerSingleton)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\utils\threading.py:24, in with_lock.<locals>.wrapper(self, *a, **k)
#      22 try:
#      23     with self._lock:
# ---> 24         return func(self, *a, **k)
#      25 except AttributeError as e:
#      26     if "has no attribute '_lock'" in e.args[0]:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\policy\torch_policy_v2.py:835, in TorchPolicyV2.compute_gradients(self, postprocessed_batch)
#     832 self._lazy_tensor_dict(postprocessed_batch, device=self.devices[0])
#     834 # Do the (maybe parallelized) gradient calculation step.
# --> 835 tower_outputs = self._multi_gpu_parallel_grad_calc([postprocessed_batch])
#     837 all_grads, grad_info = tower_outputs[0]
#     839 grad_info["allreduce_latency"] /= len(self._optimizers)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\policy\torch_policy_v2.py:1232, in TorchPolicyV2._multi_gpu_parallel_grad_calc(self, sample_batches)
#    1228 if len(self.devices) == 1 or self.config["_fake_gpus"]:
#    1229     for shard_idx, (model, sample_batch, device) in enumerate(
#    1230         zip(self.model_gpu_towers, sample_batches, self.devices)
#    1231     ):
# -> 1232         _worker(shard_idx, model, sample_batch, device)
#    1233         # Raise errors right away for better debugging.
#    1234         last_result = results[len(results) - 1]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\policy\torch_policy_v2.py:1151, in TorchPolicyV2._multi_gpu_parallel_grad_calc.<locals>._worker(shard_idx, model, sample_batch, device)
#    1146 try:
#    1147     with NullContextManager() if device.type == "cpu" else torch.cuda.device(  # noqa: E501
#    1148         device
#    1149     ):
#    1150         loss_out = force_list(
# -> 1151             self.loss(model, self.dist_class, sample_batch)
#    1152         )
#    1154         # Call Model's custom-loss with Policy loss outputs and
#    1155         # train_batch.
#    1156         if hasattr(model, "custom_loss"):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\ppo\ppo_torch_policy.py:84, in PPOTorchPolicy.loss(self, model, dist_class, train_batch)
#      66 @override(TorchPolicyV2)
#      67 def loss(
#      68     self,
#    (...)
#      71     train_batch: SampleBatch,
#      72 ) -> Union[TensorType, List[TensorType]]:
#      73     """Compute loss for Proximal Policy Objective.
#      74
#      75     Args:
#    (...)
#      81         The PPO loss tensor given the input batch.
#      82     """
# ---> 84     logits, state = model(train_batch)
#      85     curr_action_dist = dist_class(logits, model)
#      87     # RNN case: Mask away 0-padded chunks at end of time axis.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\models\modelv2.py:257, in ModelV2.__call__(self, input_dict, state, seq_lens)
#     254         restored["obs_flat"] = input_dict["obs"]
#     256 with self.context():
# --> 257     res = self.forward(restored, state or [], seq_lens)
#     259 if isinstance(input_dict, SampleBatch):
#     260     input_dict.accessed_keys = restored.accessed_keys - {"obs_flat"}
#
# File ~\rl_trading\notebooks\..\rl_trading\models\fx_model.py:58, in FXModel.forward(self, input_dict, state, seq_lens)
#      54 def forward(self, input_dict, state, seq_lens):
#      55     """
#      56     Forward pass
#      57     """
# ---> 58     x = self.main_net(input_dict["obs"].float())
#      59     self._value = self.value_net(x)
#      61     mean = self.mean_net(x)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\container.py:240, in Sequential.forward(self, input)
#     238 def forward(self, input):
#     239     for module in self:
# --> 240         input = module(input)
#     241     return input
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Save pytorch model for later evaluation

# %% [markdown]
# We save only pytorch part to ensure latency and easier usage

# %%
policy = trainer.get_policy()

# %%
MODEL_NAME = "MODEL_WEIGHTS_1_MIN_10_DAY.pth"

# %%
torch.save(policy.model.state_dict(), f"../trained_models/{MODEL_NAME}")

# %% [markdown]
# ### Plot training results

# %% [markdown]
# Includes action penalty

# %%
rewards = pd.Series(episode_rewards)

# %%
rewards.rolling(10).mean().plot()
plt.title("Average total reward per 10 iterations")
plt.xlabel("Iteration")
plt.ylabel("Total reward")
plt.show()

# %%
rewards.rolling(10).mean().iloc[-50:].plot()
plt.title("Average total reward per 10 iterations (last 50)")
plt.xlabel("Iteration")
plt.ylabel("Total reward")
plt.show()
