# %% [markdown]
# # PPO algorithm

# %% [markdown]
# ## Imports

# %%
1 + 1
# Out:
# 2

# %%
import os
import sys

sys.path.append("..")

# %%
# python -m build --sdist
# %pip install rl_trading-0.0.1.tar.gz

# %%
from copy import deepcopy

import dill
import gymnasium as Env
import numpy as np
import pandas as pd
import ray
import torch
import matplotlib.pyplot as plt

from pprint import pprint
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.models import ModelCatalog
from ray.rllib.utils.metrics import ENV_RUNNER_RESULTS
from ray.tune.registry import register_env
from tqdm import trange

# %%
# Comment next two lines to run in collab
# %load_ext autoreload
# %autoreload 2

from rl_trading.environments.fx_environment import FxTradingEnv
from rl_trading.models.fx_model import FXModel
from rl_trading.environments.base_environment import (
    DEFAULT_TRADING_PARAMS,
)

# %% [markdown]
# ## Todo

# %% [markdown]
# - Try more epochs, compare results
# - Increase number of trading days to 5
# - Try SAC and DreamerV3

# %% [markdown]
# ---
# ## Load and prepare historical data

# %%
# comment for collab
data_folder = "C:\\Users\\Ivan\\rl_trading\\data\\"
# data_folder = ""

# %%
with open(f"{data_folder}preprocessed_data.pkl", "rb") as f:
    historical_data = dill.load(f)

# %%
train_prices, train_data, validate_prices, validate_data = historical_data.values()

# %% [markdown]
# What to trade:

# %%
TICKER_SET = ('EURJPY', 'EURUSD', 'SGDJPY', 'USDJPY', 'USDSGD',)

# %%
del historical_data

# %% [markdown]
# ---
# ## Trading config

# %% [markdown]
# ### Trading setup:
#
# 1. Algorithm starts with US dollars only
# 2. It trades minutely for one day and then converts all positions to US dollars to avoid leaving open position during the night
# 3. All transaction costs, slippage and fees are accounted in one trade fee: 1 bps per trade (can be changed)
# 4. We assume the market is liquid enough for our volume and disregard trading book structure

# %%
CURRENT_PORTFOLIO = {
    "USD": 100_000,
}

# %%
TRAIN_TRADING_PARAMS = DEFAULT_TRADING_PARAMS.copy()
TRAIN_TRADING_PARAMS["action_penalty"] = 0.5
TRAIN_TRADING_PARAMS["no_trade_penalty"] = 0.5
TRAIN_TRADING_PARAMS["reward"] = "total_profit"  # "diff_sharpe" or "total_profit"

# %%
ENV_CONFIG = {
    "historical_prices": train_prices,
    "features_dataset": train_data,
    "initial_portfolio": CURRENT_PORTFOLIO,
    "ticker_set": TICKER_SET,
    "start_datetime": None,  # pd.Timestamp("2023-01-03 09:00:00"),
    "episode_length_days": 1,
    "trading_params": TRAIN_TRADING_PARAMS,
}

# %%
VALIDATION_TRADING_PARAMS = TRAIN_TRADING_PARAMS.copy()
VALIDATION_TRADING_PARAMS["no_trade_penalty"] = 0
VALIDATION_TRADING_PARAMS["action_penalty"] = 0
VALIDATION_TRADING_PARAMS["reward"] = "total_profit"

# %%
ENV_VALIDATION_CONFIG = {
    "historical_prices": validate_prices,
    "features_dataset": validate_data,
    "initial_portfolio": CURRENT_PORTFOLIO,
    "ticker_set": TICKER_SET,
    "start_datetime": None,  # pd.Timestamp("2023-01-03 09:00:00"),
    "episode_length_days": 1,
    "trading_params": VALIDATION_TRADING_PARAMS,
}

# %%
max(validate_prices.keys())
# Out:
# '2024-12-31 16:58:00'

# %% [markdown]
# ---
# ## Trial runs
#
# Run trials on validation dataset with random actions to measure execution time and debug the algorithm
#
# (You can skip that part)

# %% [markdown]
# ## todo: turn into function

# %%
fx_env = FxTradingEnv(**ENV_VALIDATION_CONFIG)

# %%
fx_env.preprocess_data()

# %%
pprint(fx_env.trading_params)
# Out:
# {'action_penalty': 0,
#  'base_currency': 'USD',
#  'long_only': True,
#  'max_delta_in_weights': 0.25,
#  'no_trade_penalty': 0,
#  'reward': 'total_profit',
#  'sharpe_eta': 0.1,
#  'slippage': (0.0001, 0.0002),
#  'trade_fee': 0.0001}

# %%
max_w = fx_env.trading_params["max_delta_in_weights"]

# %%
execution_times = []
portfolio_pos = []
total_rewards = []

for _ in trange(100):

    state, info = fx_env.reset()

    start_time = pd.Timestamp.now()
    done = False

    current_portfolio = []
    total_reward = []

    while not done:

        action = np.random.uniform(
            low=max_w * -1, high=max_w, size=len(fx_env.current_portfolio)
        )
        state, reward, terminated, truncated, info = fx_env.step(action)
        done = terminated or truncated

        current_portfolio.append(deepcopy(info["portfolio"]))
        total_reward.append(reward)

    execution_times.append((pd.Timestamp.now() - start_time).total_seconds())
    total_rewards.append(deepcopy(total_reward))
    portfolio_pos.append(deepcopy(current_portfolio))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:12<00:00,  8.19it/s]

# %%
np.quantile(execution_times, [0.01, 0.5, 0.99])
# Out:
# array([0.05895977, 0.086984  , 0.12600113])

# %%
total_rewards = [np.array(x) / 100 for x in total_rewards]

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))

axs[0].hist([np.exp(sum(x)) - 1 for x in total_rewards], bins=50)
axs[0].set_xlabel("percentage")
axs[0].set_title("Total return")

axs[1].hist([np.mean(x) / np.std(x) for x in total_rewards], bins=50)
axs[1].set_xlabel("")
axs[1].set_title("Sharpe ratio")

fig.suptitle("Validation results")
plt.tight_layout()
plt.show()

# %%
pd.DataFrame.from_dict(portfolio_pos[5]).plot()
plt.title("Portfolio positions")
plt.xlabel("Minute")
plt.ylabel("Units of respective ccy")
plt.show()

# %%
fx_env.close()

# %% [markdown]
# ---
# ## RLLib setup

# %%
def env_creator(env_config):
    """
    Create env
    """
    fx_env = FxTradingEnv(**env_config)
    fx_env.preprocess_data()
    return fx_env

# %%
register_env("fx_trading_env", env_creator)
ModelCatalog.register_custom_model("fx_model", FXModel)

# %%
ray.init(
    ignore_reinit_error=True,
    # # To work with cloned repository
    # # Comment for Google collab or if you use pip install
    runtime_env={
        "working_dir": os.path.dirname(os.path.abspath(".")),
        "py_modules": [os.path.abspath(".")],
        "excludes": [
            "*.pyc",
            "__pycache__",
            "*.parquet.gzip",
            "*data/",
            "notebooks/",
            ".git/",
        ],
    },
)
# Out:
# 2026-02-24 14:33:56,527	INFO worker.py:2023 -- Started a local Ray instance.
# 2026-02-24 14:33:56,585	INFO packaging.py:588 -- Creating a file package for local module 'C:\Users\Ivan\rl_trading\notebooks'.
# 2026-02-24 14:33:56,609	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_ce6342fa7efae7ad.zip' (0.79MiB) to Ray cluster...
# 2026-02-24 14:33:56,668	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_ce6342fa7efae7ad.zip'.
# 2026-02-24 14:33:56,780	INFO packaging.py:588 -- Creating a file package for local module 'C:\Users\Ivan\rl_trading'.
# 2026-02-24 14:33:56,837	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_bff5d55fbdd5b519.zip' (0.47MiB) to Ray cluster...
# 2026-02-24 14:33:56,841	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_bff5d55fbdd5b519.zip'.
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# RayContext(dashboard_url='', python_version='3.12.10', ray_version='2.52.1', ray_commit='4ebdc0abe5e5a551625fe7f87053c7e668a6ff74')
# (pid=gcs_server) [2026-02-24 14:34:28,684 E 13536 10860] (gcs_server.exe) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2026-02-24 14:34:30,781 E 14928 15844] (raylet.exe) main.cc:979: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (RolloutWorker pid=13600) 2026-02-24 14:57:24,784	ERROR actor_manager.py:186 -- Worker exception caught during `apply()`: Observation ([ 3.29395741e-01  2.24515334e-01  2.76706219e-01  1.69382691e-01
# (RolloutWorker pid=13600)   1.10381177e+03  1.09318762e+03 -3.23407593e+02  1.55321827e+01
# (RolloutWorker pid=13600)  -2.90861397e+01 -6.55809448e+02 -2.59290009e+02  1.75522354e+02
# (RolloutWorker pid=13600)   1.18397896e+02 -7.15852722e+02  1.96733557e+03 -2.30097388e+03
# (RolloutWorker pid=13600)   9.63167175e+02 -1.75131824e+03  5.11050659e+02  2.84329559e+02
# (RolloutWorker pid=13600)   1.37048279e+02  2.38348099e+02 -5.95302353e+01  1.31032135e+02
# (RolloutWorker pid=13600)  -9.26003456e+00 -6.36993408e+01 -1.43522615e+01  1.18556416e+00
# (RolloutWorker pid=13600)   8.56128082e+01  5.67943611e+01 -7.07106769e-01 -7.07106769e-01
# (RolloutWorker pid=13600)   0.00000000e+00  1.00000000e+00  3.00000000e+00] dtype=float32) outside given space (Box(-1000.0, 1000.0, (35,), float32))!
# (RolloutWorker pid=13600) Traceback (most recent call last):
# (RolloutWorker pid=13600)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\utils\actor_manager.py", line 182, in apply
# (RolloutWorker pid=13600)     return func(self, *args, **kwargs)
# (RolloutWorker pid=13600)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=13600)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\execution\rollout_ops.py", line 109, in <lambda>
# (RolloutWorker pid=13600)     (lambda w: w.sample(**random_action_kwargs))
# (RolloutWorker pid=13600)                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=13600)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 461, in _resume_span
# (RolloutWorker pid=13600)     return method(self, *_args, **_kwargs)
# (RolloutWorker pid=13600)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=13600)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 679, in sample
# (RolloutWorker pid=13600)     batches = [self.input_reader.next()]
# (RolloutWorker pid=13600)                ^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=13600)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\sampler.py", line 59, in next
# (RolloutWorker pid=13600)     batches = [self.get_data()]
# (RolloutWorker pid=13600)                ^^^^^^^^^^^^^^^
# (RolloutWorker pid=13600)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\sampler.py", line 225, in get_data
# (RolloutWorker pid=13600)     item = next(self._env_runner)
# (RolloutWorker pid=13600)            ^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=13600)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\env_runner_v2.py", line 330, in run
# (RolloutWorker pid=13600)     outputs = self.step()
# (RolloutWorker pid=13600)               ^^^^^^^^^^^
# (RolloutWorker pid=13600)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\env_runner_v2.py", line 356, in step
# (RolloutWorker pid=13600)     active_envs, to_eval, outputs = self._process_observations(
# (RolloutWorker pid=13600)                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=13600)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\env_runner_v2.py", line 623, in _process_observations
# (RolloutWorker pid=13600)     processed = policy.agent_connectors(acd_list)
# (RolloutWorker pid=13600)                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=13600)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\connectors\agent\pipeline.py", line 40, in __call__
# (RolloutWorker pid=13600)     ret = c(ret)
# (RolloutWorker pid=13600)           ^^^^^^
# (RolloutWorker pid=13600)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\connectors\connector.py", line 265, in __call__
# (RolloutWorker pid=13600)     return [self.transform(d) for d in acd_list]
# (RolloutWorker pid=13600)             ^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=13600)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\connectors\agent\obs_preproc.py", line 55, in transform
# (RolloutWorker pid=13600)     d[SampleBatch.NEXT_OBS] = self._preprocessor.transform(
# (RolloutWorker pid=13600)                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=13600)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\models\preprocessors.py", line 214, in transform
# (RolloutWorker pid=13600)     self.check_shape(observation)
# (RolloutWorker pid=13600)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\models\preprocessors.py", line 72, in check_shape
# (RolloutWorker pid=13600)     raise ValueError(
# (RolloutWorker pid=13600) ValueError: Observation ([ 3.29395741e-01  2.24515334e-01  2.76706219e-01  1.69382691e-01
# (RolloutWorker pid=13600)   1.10381177e+03  1.09318762e+03 -3.23407593e+02  1.55321827e+01
# (RolloutWorker pid=13600)  -2.90861397e+01 -6.55809448e+02 -2.59290009e+02  1.75522354e+02
# (RolloutWorker pid=13600)   1.18397896e+02 -7.15852722e+02  1.96733557e+03 -2.30097388e+03
# (RolloutWorker pid=13600)   9.63167175e+02 -1.75131824e+03  5.11050659e+02  2.84329559e+02
# (RolloutWorker pid=13600)   1.37048279e+02  2.38348099e+02 -5.95302353e+01  1.31032135e+02
# (RolloutWorker pid=13600)  -9.26003456e+00 -6.36993408e+01 -1.43522615e+01  1.18556416e+00
# (RolloutWorker pid=13600)   8.56128082e+01  5.67943611e+01 -7.07106769e-01 -7.07106769e-01
# (RolloutWorker pid=13600)   0.00000000e+00  1.00000000e+00  3.00000000e+00] dtype=float32) outside given space (Box(-1000.0, 1000.0, (35,), float32))!
# (raylet) A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. Lease ID: 0100000004660e9f92dce5e9ebb41ab451be6f2dcd1d1d395f20226c73f35e3f Worker ID: fb347ecded27a9f43264f389295e24f754186e33b0b456e23ede30a0 Node ID: 8691829fb90dda48be096732f9de4a29079ed1a2dfadd2b255865eef Worker IP address: 127.0.0.1 Worker port: 50997 Worker PID: 13600 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code 1.

# %%
# Use all available CPUs minus 1
# Use all GPUs if available
suggested_workers = max(os.cpu_count() - 1, 1)

if torch.cuda.is_available():
    num_gpus = torch.cuda.device_count()
else:
    num_gpus = 0

suggested_workers, num_gpus
# Out:
# (7, 0)

# %%
historical_prices_ref = ray.put(train_prices)
features_ref = ray.put(train_data)

# %%
ENV_CONFIG.update(
    {"historical_prices": historical_prices_ref, "features_dataset": features_ref}
)

# %%
pprint(ENV_CONFIG)
# Out:
# {'episode_length_days': 1,
#  'features_dataset': ObjectRef(00ffffffffffffffffffffffffffffffffffffff0100000002e1f505),
#  'historical_prices': ObjectRef(00ffffffffffffffffffffffffffffffffffffff0100000001e1f505),
#  'initial_portfolio': {'USD': 100000},
#  'start_datetime': None,
#  'ticker_set': ('EURJPY', 'EURUSD', 'SGDJPY', 'USDJPY', 'USDSGD'),
#  'trading_params': {'action_penalty': 0.5,
#                     'base_currency': 'USD',
#                     'long_only': True,
#                     'max_delta_in_weights': 0.25,
#                     'no_trade_penalty': 0.5,
#                     'reward': 'total_profit',
#                     'sharpe_eta': 0.1,
#                     'slippage': (0.0001, 0.0002),
#                     'trade_fee': 0.0001}}

# %% [markdown]
# In most PPO implementations (including RLlib), 3–10 epochs per batch is typical. Using more can actually increase the risk of getting stuck in local minima because the policy may overfit to the current batch of data, causing it to lose generalization and converge prematurely.

# %%
config = PPOConfig()

config = (
    config.environment(
        env="fx_trading_env",
        env_config=ENV_CONFIG,
    )
    .framework("torch")
    .training(
        model={"custom_model": "fx_model"},
        lr=3e-4,
        clip_param=0.2,
        grad_clip=0.5,
        vf_clip_param=10.0,
        entropy_coeff=0.01,
        gamma=0.99,
        lambda_=0.95,
        num_epochs=8,
        train_batch_size=16384,
    )
    .debugging(log_level="ERROR")
    .resources(num_gpus=num_gpus)
    .env_runners(
        num_cpus_per_env_runner=1,
        num_env_runners=suggested_workers,
        num_envs_per_env_runner=4,
        rollout_fragment_length="auto",
        exploration_config={
            "type": "StochasticSampling",  # default
            "random_timesteps": 5_000,
        },
    )
    # .evaluation(
    #     evaluation_interval=5,
    #     evaluation_config={
    #         "explore": False,
    #     }
    # )
    .api_stack(
        enable_rl_module_and_learner=False, enable_env_runner_and_connector_v2=False
    )
)

# %%
trainer = config.build_algo()
# Out:
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm.py:525: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2026-02-24 14:35:01,610	INFO trainable.py:161 -- Trainable.setup took 56.991 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.

# %% [markdown]
# 25 features + 5 prices + 5 time features

# %%
trainer.get_policy().observation_space
# Out:
# Box(-1000.0, 1000.0, (35,), float32)

# %% [markdown]
# 5 ccys

# %%
trainer.get_policy().action_space
# Out:
# Box(-1.0, 1.0, (5,), float32)

# %% [markdown]
# ---
# ## Train the model

# %%
num_epochs = 200
# will not be applied for first 100
early_stopping_patience = 20
min_improvement = 0.01
best_reward = -np.inf

# %%
# warnings.filterwarnings('ignore')
episode_rewards = []
patience_counter = 0

for i in trange(num_epochs):

    result = trainer.train()

    average_episode_reward = np.mean(
        result[ENV_RUNNER_RESULTS]["hist_stats"]["episode_reward"]
    )
    episode_rewards.append(average_episode_reward)

    if np.mean(episode_rewards[-5:]) >= best_reward + min_improvement:
        best_reward = np.mean(episode_rewards[-5:])
        patience_counter = 0
    else:
        patience_counter += 1

    if (patience_counter > early_stopping_patience) and (i > 100):
        print(f"Early stopping! No improvements for {patience_counter} steps")
        break
    
    if i % 5 == 0:
        print(f"Last 5 epochs reward: {np.mean(episode_rewards[-5:])}")
# Out:
#   0%|                                                                                          | 0/200 [00:00<?, ?it/s]2026-02-24 14:35:07,352	WARNING train_ops.py:114 -- DeprecationWarning: `ray.rllib.execution.train_ops.multi_gpu_train_one_step` has been deprecated. This will raise an error in the future!
#   0%|▍                                                                               | 1/200 [00:20<1:07:03, 20.22s/it]
# Last 5 epochs reward: -84.27984590014107
#   3%|██▍                                                                             | 6/200 [01:57<1:03:24, 19.61s/it]
# Last 5 epochs reward: -148.01937322903365
#   6%|████▎                                                                          | 11/200 [03:45<1:06:59, 21.27s/it]
# Last 5 epochs reward: -163.51837927020728
#   8%|██████▎                                                                        | 16/200 [05:38<1:07:21, 21.97s/it]
# Last 5 epochs reward: -139.6455785088909
#  10%|████████▎                                                                      | 21/200 [07:31<1:06:53, 22.42s/it]
# Last 5 epochs reward: -115.52024949907484
#  13%|██████████▎                                                                    | 26/200 [09:24<1:05:36, 22.63s/it]
# Last 5 epochs reward: -93.77025814752292
#  16%|████████████▏                                                                  | 31/200 [11:18<1:03:41, 22.61s/it]
# Last 5 epochs reward: -70.43484719937373
#  18%|██████████████▏                                                                | 36/200 [13:11<1:00:48, 22.25s/it]
# Last 5 epochs reward: -50.7306118834639
#  20%|████████████████▌                                                                | 41/200 [15:01<58:11, 21.96s/it]
# Last 5 epochs reward: -36.47504239502699
#  23%|██████████████████▋                                                              | 46/200 [16:52<58:31, 22.80s/it]
# Last 5 epochs reward: -25.72021661759503
#  26%|████████████████████▋                                                            | 51/200 [18:46<56:10, 22.62s/it]
# Last 5 epochs reward: -18.542665450218585
#  28%|██████████████████████▋                                                          | 56/200 [20:33<52:02, 21.69s/it]
# Last 5 epochs reward: -13.356153801656921
#  30%|████████████████████████▋                                                        | 61/200 [22:22<49:40, 21.44s/it]
# Last 5 epochs reward: -10.061654869033678
# 2026-02-24 14:58:30,609	ERROR actor_manager.py:973 -- Ray error (The actor 1e4d506058464090bfa209ad01000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or may not have been executed on the actor.), taking actor 2 out of service.
# 2026-02-24 14:58:30,653	ERROR actor_manager.py:771 -- The actor 1e4d506058464090bfa209ad01000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or may not have been executed on the actor.
# NoneType: None
#  33%|██████████████████████████▋                                                      | 66/200 [25:12<57:00, 25.53s/it]
# Last 5 epochs reward: -7.484607594525886
#  36%|████████████████████████████▊                                                    | 71/200 [26:52<45:19, 21.08s/it]
# Last 5 epochs reward: -6.027348304498815
#  38%|██████████████████████████████▊                                                  | 76/200 [28:39<44:05, 21.33s/it]
# Last 5 epochs reward: -4.7466374062427095
#  40%|████████████████████████████████▊                                                | 81/200 [30:31<44:43, 22.55s/it]
# Last 5 epochs reward: -3.9019951656626795
#  43%|██████████████████████████████████▊                                              | 86/200 [32:23<42:02, 22.13s/it]
# Last 5 epochs reward: -3.3427691613209825
#  46%|████████████████████████████████████▊                                            | 91/200 [34:16<41:21, 22.76s/it]
# Last 5 epochs reward: -2.9366892374894187
#  48%|██████████████████████████████████████▉                                          | 96/200 [36:04<37:40, 21.74s/it]
# Last 5 epochs reward: -2.653724254343257
#  50%|████████████████████████████████████████▍                                       | 101/200 [37:55<36:36, 22.19s/it]
# Last 5 epochs reward: -2.4561051255238686
#  53%|██████████████████████████████████████████▍                                     | 106/200 [39:47<35:18, 22.54s/it]
# Last 5 epochs reward: -2.1990428311614107
#  56%|████████████████████████████████████████████▍                                   | 111/200 [41:42<33:48, 22.80s/it]
# Last 5 epochs reward: -2.0320067239785833
#  58%|██████████████████████████████████████████████▍                                 | 116/200 [43:30<30:48, 22.01s/it]
# Last 5 epochs reward: -1.809070200477637
#  60%|████████████████████████████████████████████████▍                               | 121/200 [45:22<28:55, 21.97s/it]
# Last 5 epochs reward: -1.7086623918665929
#  63%|██████████████████████████████████████████████████▍                             | 126/200 [47:16<28:44, 23.31s/it]
# Last 5 epochs reward: -1.5840387569930432
#  66%|████████████████████████████████████████████████████▍                           | 131/200 [49:07<25:41, 22.34s/it]
# Last 5 epochs reward: -1.4798924098023636
#  68%|██████████████████████████████████████████████████████▍                         | 136/200 [50:57<23:21, 21.90s/it]
# Last 5 epochs reward: -1.3389225054982745
#  70%|████████████████████████████████████████████████████████▍                       | 141/200 [52:45<21:22, 21.74s/it]
# Last 5 epochs reward: -1.234340039380292
#  73%|██████████████████████████████████████████████████████████▍                     | 146/200 [54:43<20:24, 22.67s/it]
# Last 5 epochs reward: -1.1602448749267933
#  76%|████████████████████████████████████████████████████████████▍                   | 151/200 [56:38<18:52, 23.11s/it]
# Last 5 epochs reward: -1.1701893859929258
#  78%|██████████████████████████████████████████████████████████████▍                 | 156/200 [58:29<16:26, 22.43s/it]
# Last 5 epochs reward: -1.0813307455496797
#  80%|██████████████████████████████████████████████████████████████▊               | 161/200 [1:00:26<14:51, 22.86s/it]
# Last 5 epochs reward: -1.0121980659552177
#  83%|████████████████████████████████████████████████████████████████▋             | 166/200 [1:02:19<12:57, 22.87s/it]
# Last 5 epochs reward: -0.976283240130536
#  86%|██████████████████████████████████████████████████████████████████▋           | 171/200 [1:04:16<11:11, 23.14s/it]
# Last 5 epochs reward: -0.9533057627670125
#  88%|████████████████████████████████████████████████████████████████████▋         | 176/200 [1:06:12<09:24, 23.52s/it]
# Last 5 epochs reward: -0.8806237708363616
#  90%|██████████████████████████████████████████████████████████████████████▌       | 181/200 [1:08:04<07:06, 22.43s/it]
# Last 5 epochs reward: -0.8976055997629363
#  93%|████████████████████████████████████████████████████████████████████████▌     | 186/200 [1:10:08<05:46, 24.72s/it]
# Last 5 epochs reward: -0.9365645034744372
#  96%|██████████████████████████████████████████████████████████████████████████▍   | 191/200 [1:12:03<03:29, 23.29s/it]
# Last 5 epochs reward: -0.9043264506282338
#  98%|████████████████████████████████████████████████████████████████████████████▍ | 196/200 [1:14:00<01:33, 23.46s/it]
# Last 5 epochs reward: -0.9073382382474294
#  98%|████████████████████████████████████████████████████████████████████████████▍ | 196/200 [1:14:25<01:31, 22.78s/it]
# Early stopping! No improvements for 21 steps

# %% [markdown]
# ### Save pytorch model for later evaluation

# %% [markdown]
# We save only pytorch part to ensure latency and easier changes

# %%
policy = trainer.get_policy()

# %%
MODEL_NAME = "ALL_CCY_MODEL_WEIGHTS_1_MIN_1_DAY.pth"

# %%
torch.save(policy.model.state_dict(), f"../trained_models/{MODEL_NAME}")

# %% [markdown]
# ### Plot training results

# %% [markdown]
# Includes action penalty

# %%
rewards = pd.Series(episode_rewards)

# %%
rewards.rolling(10).mean().plot()
plt.title("Average total reward per 10 iterations")
plt.xlabel("Iteration")
plt.ylabel("Total reward")
plt.show()

# %%
rewards.rolling(10).mean().iloc[-50:].plot()
plt.title("Average total reward per 10 iterations")
plt.xlabel("Iteration")
plt.ylabel("Total reward")
plt.show()

# %% [markdown]
# ---
# ## Validate the model

# %%
MODEL_NAME = "ALL_CCY_MODEL_WEIGHTS_1_MIN_1_DAY.pth"

# %%
fx_env = FxTradingEnv(**ENV_VALIDATION_CONFIG)

# %%
fx_env.preprocess_data()

# %%
state_dict = torch.load(f"../trained_models/{MODEL_NAME}")

# %%
num_ccy = fx_env.action_space.shape[0]

# %%
trained_model = FXModel(
    obs_space=fx_env.observation_space,
    action_space=fx_env.action_space,
    num_outputs=num_ccy * 2,
    model_config={},
    name="FXModel",  # any name if fine
)

# %%
trained_model.load_state_dict(state_dict)
trained_model.eval()
# Out:
# FXModel(
#   (main_net): Sequential(
#     (0): Linear(in_features=35, out_features=256, bias=True)
#     (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (6): GELU(approximate='none')
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Linear(in_features=128, out_features=64, bias=True)
#     (9): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (10): GELU(approximate='none')
#     (11): Dropout(p=0.2, inplace=False)
#   )
#   (mean_net): Sequential(
#     (0): Linear(in_features=64, out_features=5, bias=True)
#     (1): Tanh()
#   )
#   (log_std_net): Sequential(
#     (0): Linear(in_features=64, out_features=5, bias=True)
#   )
#   (value_net): Sequential(
#     (0): Linear(in_features=64, out_features=32, bias=True)
#     (1): GELU(approximate='none')
#     (2): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
execution_times = []
portfolio_pos = []
total_rewards = []
all_actions = []

for _ in trange(100):

    state, info = fx_env.reset()

    start_time = pd.Timestamp.now()
    done = False

    current_portfolio = []
    total_reward = []
    this_time_actions = []

    while not done:

        torch_state = torch.from_numpy(state).type(torch.float32)

        with torch.no_grad():
            action, _ = trained_model(
                input_dict={"obs": torch_state}, state=[], seq_lens=None
            )

        action = action.detach().numpy()[:num_ccy]
        this_time_actions.append(action)

        state, reward, terminated, truncated, info = fx_env.step(action)
        done = terminated or truncated

        if not done:
            current_portfolio.append(deepcopy(info["portfolio"]))
            total_reward.append(reward)

    execution_times.append((pd.Timestamp.now() - start_time).total_seconds())
    total_rewards.append(deepcopy(total_reward))
    portfolio_pos.append(deepcopy(current_portfolio))
    all_actions.append(deepcopy(this_time_actions))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [01:15<00:00,  1.33it/s]

# %%
np.quantile(execution_times, [0.01, 0.5, 0.99])
# Out:
# array([0.41522452, 0.6903165 , 1.07976931])

# %%
total_rewards = [np.array(x) / 100 for x in total_rewards]

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))

axs[0].hist([np.exp(sum(x)) - 1 for x in total_rewards], bins=50)
axs[0].set_xlabel("percentage")
axs[0].set_title("Total return")

axs[1].hist([np.mean(x) / np.std(x) for x in total_rewards], bins=50)
axs[1].set_xlabel("")
axs[1].set_title("Sharpe ratio")

fig.suptitle("Validation results")
plt.tight_layout()
plt.show()

# %% [markdown]
# More stable positions in trading, some positive returns

# %%
pd.DataFrame.from_dict(portfolio_pos[50]).plot()
plt.title("Portfolio positions")
plt.xlabel("Minute")
plt.ylabel("Units of respective ccy")
plt.show()

# %%
pd.DataFrame(all_actions[50], columns=TICKER_SET).plot()
plt.title("Actions per currrency pair")
plt.xlabel("Minute")
plt.ylabel("Predicted flow")
plt.show()
