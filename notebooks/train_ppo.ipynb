# %%
import os
import sys
import warnings

sys.path.append("..")

# %%
# add to toml
# pip install lz4

# %%
# python -m build --sdist
# %pip install rl_trading-0.0.1.tar.gz

# %%
from copy import deepcopy

import gymnasium as Env
import numpy as np
import pandas as pd
import ray
import torch
import matplotlib.pyplot as plt

from tqdm import trange
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.models import ModelCatalog
from ray.rllib.utils.metrics import ENV_RUNNER_RESULTS
from ray.tune.registry import register_env

# %%
from sklearn.preprocessing import RobustScaler

# %%
# Comment next two lines to run in collab
# %load_ext autoreload
# %autoreload 2

from rl_trading.environments.fx_environment import FxTradingEnv
from rl_trading.models.fx_model import FXModel

# %% [markdown]
# ## Trading setup:
#
# 1. Algorithm starts with US dollars only
# 2. It trades minutely for one day to avoid leaving position overnight
# 3. All transaction costs, slippage and fees are accounted in one trade fee: 10 bps per trade (can be changed)
# 4. We assume the market is liquid enough for our volume and disregard trading book structure

# %% [markdown]
# ## Todo

# %% [markdown]
# - return latest portfolio to double check rewards
# - return portfolio history as info / custom metrics
# - add differential sharpe ratio as reward (Allow to choose in params)
# - fix tests
# - check hyperparams
# - try other algorithms

# %% [markdown]
# ### Historical data

# %%
# comment for collab
data_folder = "C:\\Users\\Ivan\\rl_trading\\data\\"
# data_folder = ""

# %%
historical_data = pd.read_parquet(f"{data_folder}FX_data.parquet.gzip")

# %%
for col in historical_data.columns:
    if col in ["ccy", "timestamp"]:
        continue
    historical_data[col] = historical_data[col].astype(float)

# %% [markdown]
# Scaling data

# %%
historical_data_scaler_train = historical_data.loc[
    historical_data["timestamp"] <= "2023-01-01 00:00:00", :
]

# %%
historical_data_to_use = historical_data.loc[
    historical_data["timestamp"] >= "2023-01-02 00:00:00", :
]

# %%
# todo: pass as long table to allow for OHLC format
historical_prices = pd.pivot_table(
    data=historical_data_to_use, index="timestamp", columns="ccy", values="close"
)

historical_prices = historical_prices.ffill().dropna()

# %%
# Transform outliers
transformer = RobustScaler().fit(
    historical_data_scaler_train.set_index(["timestamp", "ccy"])
)

# %%
features = transformer.transform(
    historical_data_to_use.set_index(["timestamp", "ccy"])
)

# %%
multi_index = pd.MultiIndex.from_frame(historical_data_to_use[["timestamp", "ccy"]])
features = pd.DataFrame(features, index=multi_index)

# %%
historical_data_to_use = features.unstack("ccy").ffill()

# %%
del historical_data_scaler_train, historical_data, features

# %% [markdown]
# ### Trading config

# %%
current_porfolio = {
    "usd": 100_000,
}

# %%
env_config = {
    "historical_prices": historical_prices,
    "features_dataset": historical_data_to_use,
    "initial_portfolio": current_porfolio,
    "start_datetime": None,
    "episode_length_days": 1,
}

# %%
# all([x in historical_data_to_use["timestamp"].values for x in historical_prices.index])

# %%
fx_env = FxTradingEnv(**env_config)
fx_env.preprocess_data()

# %%
# %%time

# # FOR DEBUG PURPOSES
max_w = fx_env.trading_params["max_delta_in_weights"]
done = False
state, info = fx_env.reset()
total_reward = [0]

while not done:

    action = np.random.uniform(
        low=max_w * -1, high=max_w, size=len(fx_env.current_portfolio)
    )

    state, reward, terminated, truncated, info = fx_env.step(action)
    done = terminated or truncated
    total_reward.append(reward)
# Out:
# CPU times: total: 1.53 s
# Wall time: 1.51 s

# %%
plt.plot(np.cumsum(total_reward))

# %%
# %%timeit
# fx_env._get_state()

# %%
# %%timeit
# fx_env.step(action)

# %%
def env_creator(env_config):
    """
    Create env
    """
    fx_env = FxTradingEnv(**env_config)
    fx_env.preprocess_data()
    return fx_env

# %%
register_env("fx_trading_env", env_creator)
ModelCatalog.register_custom_model("fx_model", FXModel)

# %%
ray.init(
    ignore_reinit_error=True,
    # # To work with cloned repository. Comment for Google collab
    runtime_env={
        "working_dir": os.path.dirname(os.path.abspath(".")),
        "py_modules": [os.path.abspath(".")],
        "excludes": [
            "*.pyc",
            "__pycache__",
            "*.parquet.gzip",
            "*data/",
            "notebooks/",
            ".git/",
        ],
    },
)
# Out:
# 2026-02-10 22:45:22,889	INFO worker.py:2023 -- Started a local Ray instance.
# 2026-02-10 22:45:22,927	INFO packaging.py:588 -- Creating a file package for local module 'C:\Users\Ivan\rl_trading\notebooks'.
# 2026-02-10 22:45:22,956	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_1816550721daf8f2.zip' (0.41MiB) to Ray cluster...
# 2026-02-10 22:45:23,042	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_1816550721daf8f2.zip'.
# 2026-02-10 22:45:23,144	INFO packaging.py:588 -- Creating a file package for local module 'C:\Users\Ivan\rl_trading'.
# 2026-02-10 22:45:23,198	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_afc8ce36cbd27d89.zip' (0.04MiB) to Ray cluster...
# 2026-02-10 22:45:23,202	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_afc8ce36cbd27d89.zip'.
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# RayContext(dashboard_url='', python_version='3.12.10', ray_version='2.52.1', ray_commit='4ebdc0abe5e5a551625fe7f87053c7e668a6ff74')

# %%
suggested_workers = 1  # os.cpu_count() - 1

if torch.cuda.is_available():
    num_gpus = torch.cuda.device_count()
else:
    num_gpus = 0

suggested_workers, num_gpus
# Out:
# (1, 0)

# %%
config = PPOConfig()

config = (
    config.environment(
        env="fx_trading_env",
        env_config=env_config,
    )
    .framework("torch")
    .training(
        model={"custom_model": "fx_model"},
        lr=1e-3, 
        clip_param=0.1,
        vf_clip_param=5.0,
        entropy_coeff=0.1,
        gamma=0.99,
        lambda_=0.95,
        num_epochs=10,
        train_batch_size=2048,
    )
    # .debugging(log_level="ERROR")
    .resources(num_gpus=num_gpus)
    .env_runners(
        num_cpus_per_env_runner=1,
        num_env_runners=suggested_workers,
        rollout_fragment_length="auto",
    )
    .api_stack(
        enable_rl_module_and_learner=False, enable_env_runner_and_connector_v2=False
    )
)
# Out:
# 2026-02-10 22:45:36,647	WARNING algorithm_config.py:2484 -- DeprecationWarning: `config.training(num_sgd_iter=..)` has been deprecated. Use `config.training(num_epochs=..)` instead. This will raise an error in the future!

# %%
trainer = config.build_algo()
# Out:
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm.py:525: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))

# %%
# num_epochs = 1
num_epochs = 100

# %%
# warnings.filterwarnings('ignore')

episode_rewards = []

for i in trange(num_epochs):

    result = trainer.train()

    average_episode_reward = np.mean(
        result[ENV_RUNNER_RESULTS]["hist_stats"]["episode_reward"]
    )
    episode_rewards.append(average_episode_reward)

    if i % 5 == 0:
        print(f"Last 5 epochs reward: {np.mean(episode_rewards[-5:])}")
# Out:
#   0%|                                                                                          | 0/100 [00:00<?, ?it/s]2026-02-10 22:21:10,147	WARNING train_ops.py:114 -- DeprecationWarning: `ray.rllib.execution.train_ops.multi_gpu_train_one_step` has been deprecated. This will raise an error in the future!
#   1%|▊                                                                                 | 1/100 [00:08<13:30,  8.18s/it]
# Last 5 epochs reward: -0.22990250645347896
#   6%|████▉                                                                             | 6/100 [00:54<13:51,  8.84s/it]
# Last 5 epochs reward: -0.23259701489616744
#  11%|████████▉                                                                        | 11/100 [01:34<12:02,  8.12s/it]
# Last 5 epochs reward: -0.2323466837038933
#  16%|████████████▉                                                                    | 16/100 [02:15<11:19,  8.09s/it]
# Last 5 epochs reward: -0.23274570264613606
#  21%|█████████████████                                                                | 21/100 [02:56<10:47,  8.20s/it]
# Last 5 epochs reward: -0.23324421253346556
#  26%|█████████████████████                                                            | 26/100 [03:40<11:04,  8.98s/it]
# Last 5 epochs reward: -0.23351385788598672
#  31%|█████████████████████████                                                        | 31/100 [04:26<10:24,  9.05s/it]
# Last 5 epochs reward: -0.23328758778157108
#  36%|█████████████████████████████▏                                                   | 36/100 [05:18<10:38,  9.98s/it]
# Last 5 epochs reward: -0.23434156558158112
#  41%|█████████████████████████████████▏                                               | 41/100 [06:05<09:12,  9.37s/it]
# Last 5 epochs reward: -0.23442180386835315
#  46%|█████████████████████████████████████▎                                           | 46/100 [06:53<08:28,  9.41s/it]
# Last 5 epochs reward: -0.23399711957523298
#  51%|█████████████████████████████████████████▎                                       | 51/100 [07:42<08:00,  9.82s/it]
# Last 5 epochs reward: -0.23437505799257882
#  56%|█████████████████████████████████████████████▎                                   | 56/100 [08:29<06:51,  9.36s/it]
# Last 5 epochs reward: -0.23469506253839495
#  61%|█████████████████████████████████████████████████▍                               | 61/100 [09:15<06:09,  9.47s/it]
# Last 5 epochs reward: -0.23456444265594417
#  66%|█████████████████████████████████████████████████████▍                           | 66/100 [10:09<05:48, 10.26s/it]
# Last 5 epochs reward: -0.23503092595393077
#  71%|█████████████████████████████████████████████████████████▌                       | 71/100 [10:57<04:35,  9.48s/it]
# Last 5 epochs reward: -0.23553357333944805
#  76%|█████████████████████████████████████████████████████████████▌                   | 76/100 [11:44<03:50,  9.61s/it]
# Last 5 epochs reward: -0.23646472248196854
#  81%|█████████████████████████████████████████████████████████████████▌               | 81/100 [12:30<02:53,  9.14s/it]
# Last 5 epochs reward: -0.23733562389002194
#  81%|█████████████████████████████████████████████████████████████████▌               | 81/100 [12:35<02:57,  9.33s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 7
#       3 episode_rewards = []
#       5 for i in trange(num_epochs):
# ----> 7     result = trainer.train()
#       9     average_episode_reward = np.mean(
#      10         result[ENV_RUNNER_RESULTS]["hist_stats"]["episode_reward"]
#      11     )
#      12     episode_rewards.append(average_episode_reward)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\trainable.py:328, in Trainable.train(self)
#     326 start = time.time()
#     327 try:
# --> 328     result = self.step()
#     329 except Exception as e:
#     330     skipped = skip_exceptions(e)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm.py:1245, in Algorithm.step(self)
#    1240         train_results, train_iter_ctx = self._run_one_training_iteration()
#    1241     else:
#    1242         (
#    1243             train_results,
#    1244             train_iter_ctx,
# -> 1245         ) = self._run_one_training_iteration_old_api_stack()
#    1247 # Sequential: Train (already done above), then evaluate.
#    1248 if evaluate_this_iter and not self.config.evaluation_parallel_to_training:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm.py:4330, in Algorithm._run_one_training_iteration_old_api_stack(self)
#    4323         self._make_on_env_runners_recreated_callbacks(
#    4324             config=self.config,
#    4325             env_runner_group=self.env_runner_group,
#    4326             restored_env_runner_indices=restored,
#    4327         )
#    4329 with self._timers[TRAINING_STEP_TIMER]:
# -> 4330     training_step_results = self.training_step()
#    4332 if training_step_results:
#    4333     results = training_step_results
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\ppo\ppo.py:393, in PPO.training_step(self)
#     389 @override(Algorithm)
#     390 def training_step(self) -> None:
#     391     # Old API stack (Policy, RolloutWorker, Connector).
#     392     if not self.config.enable_env_runner_and_connector_v2:
# --> 393         return self._training_step_old_api_stack()
#     395     # Collect batches from sample workers until we have a full batch.
#     396     with self.metrics.log_time((TIMERS, ENV_RUNNER_SAMPLING_TIMER)):
#     397         # Sample in parallel from the workers.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\ppo\ppo.py:472, in PPO._training_step_old_api_stack(self)
#     466     train_batch = synchronous_parallel_sample(
#     467         worker_set=self.env_runner_group,
#     468         max_agent_steps=self.config.total_train_batch_size,
#     469         sample_timeout_s=self.config.sample_timeout_s,
#     470     )
#     471 else:
# --> 472     train_batch = synchronous_parallel_sample(
#     473         worker_set=self.env_runner_group,
#     474         max_env_steps=self.config.total_train_batch_size,
#     475         sample_timeout_s=self.config.sample_timeout_s,
#     476     )
#     477 # Return early if all our workers failed.
#     478 if not train_batch:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\execution\rollout_ops.py:107, in synchronous_parallel_sample(worker_set, max_agent_steps, max_env_steps, concat, sample_timeout_s, random_actions, _uses_new_env_runners, _return_metrics)
#     104         stats_dicts = [worker_set.local_env_runner.get_metrics()]
#     105 # Loop over remote workers' `sample()` method in parallel.
#     106 else:
# --> 107     sampled_data = worker_set.foreach_env_runner(
#     108         (
#     109             (lambda w: w.sample(**random_action_kwargs))
#     110             if not _return_metrics
#     111             else (lambda w: (w.sample(**random_action_kwargs), w.get_metrics()))
#     112         ),
#     113         local_env_runner=False,
#     114         timeout_seconds=sample_timeout_s,
#     115     )
#     116     # Nothing was returned (maybe all workers are stalling) or no healthy
#     117     # remote workers left: Break.
#     118     # There is no point staying in this loop, since we will not be able to
#     119     # get any new samples if we don't have any healthy remote workers left.
#     120     if not sampled_data or worker_set.num_healthy_remote_workers() <= 0:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\env\env_runner_group.py:879, in EnvRunnerGroup.foreach_env_runner(self, func, kwargs, local_env_runner, healthy_only, remote_worker_ids, timeout_seconds, return_obj_refs, mark_healthy)
#     876 if not self._worker_manager.actor_ids():
#     877     return local_result
# --> 879 remote_results = self._worker_manager.foreach_actor(
#     880     func,
#     881     kwargs=kwargs,
#     882     healthy_only=healthy_only,
#     883     remote_actor_ids=remote_worker_ids,
#     884     timeout_seconds=timeout_seconds,
#     885     return_obj_refs=return_obj_refs,
#     886     mark_healthy=mark_healthy,
#     887 )
#     889 FaultTolerantActorManager.handle_remote_call_result_errors(
#     890     remote_results, ignore_ray_errors=self._ignore_ray_errors_on_env_runners
#     891 )
#     893 # With application errors handled, return good results.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\utils\actor_manager.py:484, in FaultTolerantActorManager.foreach_actor(self, func, kwargs, healthy_only, remote_actor_ids, timeout_seconds, return_obj_refs, mark_healthy)
#     477 remote_calls = self._call_actors(
#     478     func=func,
#     479     kwargs=kwargs,
#     480     remote_actor_ids=remote_actor_ids,
#     481 )
#     483 # Collect remote request results (if available given timeout and/or errors).
# --> 484 _, remote_results = self._fetch_result(
#     485     remote_actor_ids=remote_actor_ids,
#     486     remote_calls=remote_calls,
#     487     tags=[None] * len(remote_calls),
#     488     timeout_seconds=timeout_seconds,
#     489     return_obj_refs=return_obj_refs,
#     490     mark_healthy=mark_healthy,
#     491 )
#     493 return remote_results
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\utils\actor_manager.py:939, in FaultTolerantActorManager._fetch_result(self, remote_actor_ids, remote_calls, tags, timeout_seconds, return_obj_refs, mark_healthy)
#     936 if not remote_calls:
#     937     return [], RemoteCallResults()
# --> 939 readies, _ = ray.wait(
#     940     remote_calls,
#     941     num_returns=len(remote_calls),
#     942     timeout=timeout,
#     943     # Make sure remote results are fetched locally in parallel.
#     944     fetch_local=not return_obj_refs,
#     945 )
#     947 # Remote data should already be fetched to local object store at this point.
#     948 remote_results = RemoteCallResults()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\auto_init_hook.py:22, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      19 @wraps(fn)
#      20 def auto_init_wrapper(*args, **kwargs):
#      21     auto_init_ray()
# ---> 22     return fn(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\client_mode_hook.py:104, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     102     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     103         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 104 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py:3213, in wait(ray_waitables, num_returns, timeout, fetch_local)
#    3211 timeout = timeout if timeout is not None else 10**6
#    3212 timeout_milliseconds = int(timeout * 1000)
# -> 3213 ready_ids, remaining_ids = worker.core_worker.wait(
#    3214     ray_waitables,
#    3215     num_returns,
#    3216     timeout_milliseconds,
#    3217     fetch_local,
#    3218 )
#    3219 return ready_ids, remaining_ids
#
# File python\\ray\\_raylet.pyx:3172, in ray._raylet.CoreWorker.wait()
#
# File python\\ray\\includes/common.pxi:98, in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %% [markdown]
# Plot results + trailing sharpe ratio

# %%
result[ENV_RUNNER_RESULTS]["hist_stats"]
