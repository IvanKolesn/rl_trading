# %%
import os
import sys
import warnings

sys.path.append("..")

# %%
# pip install ray

# %%
# pip install rl_trading.zip

# %%
import gymnasium as Env
import numpy as np
import pandas as pd
import ray
import torch

from tqdm import trange
from copy import deepcopy
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.models import ModelCatalog
from ray.rllib.utils.metrics import ENV_RUNNER_RESULTS
from ray.tune.registry import register_env
# Out:
# 2026-02-06 09:46:39,129	WARNING compression.py:17 -- lz4 not available, disabling sample compression. This will significantly impact RLlib performance. To install lz4, run `pip install lz4`.

# %%
# %load_ext autoreload
# %autoreload 2

from rl_trading.environments.fx_environment import FxTradingEnv
from rl_trading.models.fx_model import FXModel

# %% [markdown]
# Todo
#
# - Select hourly, minutely or daily data
# - Truncation in days
# - Debug code
# - Add features
#
# - Write tests:
#
# 1. Unknown currency in initial portfolio
# 2. Missing currency in initial portfolio
# 3. Portfolio value in base
# 4. Portfolio weights == 1
# 5. reset works
# 6. etc

# %%
current_porfolio = {
    "usd": 100_000,
    "eur": 100_000,
    "jpy": 100_000,
    # "sgd": 100_000,
}

# %%
historical_data = pd.read_parquet("data/FX_data.parquet.gzip")

# %%
env_config = {
    "historical_prices": historical_data[["eurjpy", "eurusd", "usdjpy"]],
    "initial_portfolio": current_porfolio,
    "start_datetime": pd.Timestamp("2011-01-03 09:00:00"),
}

# %%
def env_creator(env_config):
    """
    Create env
    """
    fx_env = FxTradingEnv(**env_config)
    fx_env.preprocess_data()
    return fx_env

# %%
register_env("fx_trading_env", env_creator)
ModelCatalog.register_custom_model("fx_model", FXModel)

# %%
ray.init(
    ignore_reinit_error=True,
    # To work with cloned repository
    # runtime_env={
    #     "working_dir": os.path.dirname(os.path.abspath(".")),
    #     "py_modules": [os.path.abspath(".")],
    #     "excludes": [
    #         "*.pyc", "__pycache__", "*.parquet.gzip",
    #         "data/", "notebooks/", "sample_data/"],
    # },
)
# Out:
# 2026-02-06 09:48:03,500	INFO worker.py:2023 -- Started a local Ray instance.
# /usr/local/lib/python3.12/dist-packages/ray/_private/worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# RayContext(dashboard_url='', python_version='3.12.12', ray_version='2.52.1', ray_commit='4ebdc0abe5e5a551625fe7f87053c7e668a6ff74')

# %%
suggested_workers = 1

if torch.cuda.is_available():
    num_gpus = torch.cuda.device_count()
else:
    num_gpus = 0

suggested_workers, num_gpus
# Out:
# (1, 1)

# %%
config = PPOConfig()

config = (
    config.environment(
        env="fx_trading_env",
        env_config=env_config,
    )
    .framework("torch")
    .training(
        model={"custom_model": "fx_model"},
        lr=1e-3,
        train_batch_size=2048,
    )
    # .debugging(log_level="ERROR")
    .resources(num_gpus=num_gpus)
    .env_runners(
        num_cpus_per_env_runner=1,
        num_env_runners=suggested_workers,
        rollout_fragment_length="auto",
    )
    .api_stack(
        enable_rl_module_and_learner=False, enable_env_runner_and_connector_v2=False
    )
)

# %%
trainer = config.build_algo()
# Out:
# 2026-02-06 09:50:16,689	INFO tensorboardx.py:45 -- pip install "ray[tune]" to see TensorBoard files.
# 2026-02-06 09:50:16,690	WARNING unified.py:56 -- Could not instantiate TBXLogger: No module named 'tensorboardX'.
# (pid=12838) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (pid=12838) E0000 00:00:1770371417.475755   12838 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=12838) E0000 00:00:1770371417.481867   12838 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=12838) W0000 00:00:1770371417.498636   12838 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (pid=12838) W0000 00:00:1770371417.498679   12838 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (pid=12838) W0000 00:00:1770371417.498686   12838 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (pid=12838) W0000 00:00:1770371417.498690   12838 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (pid=12838) lz4 not available, disabling sample compression. This will significantly impact RLlib performance. To install lz4, run `pip install lz4`.
# 2026-02-06 09:50:36,884	INFO trainable.py:161 -- Trainable.setup took 20.192 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-06 09:50:36,890	WARNING util.py:61 -- Install gputil for GPU system monitoring.

# %%
num_episodes = 100

# %%
# warnings.filterwarnings('ignore')
episode_lengths = []
episode_rewards = []

for i in trange(num_episodes):

    result = trainer.train()

    average_episode_reward = np.mean(
        result[ENV_RUNNER_RESULTS]["hist_stats"]["episode_reward"]
    )
    average_episode_length = np.mean(
        result[ENV_RUNNER_RESULTS]["hist_stats"]["episode_lengths"]
    )

    episode_lengths.append(average_episode_length)
    episode_rewards.append(average_episode_reward)

    if i % 5 == 0:
        print(f"Reward: {average_episode_reward}, Length: {average_episode_length}")
# Out:
#   1%|          | 1/100 [00:15<25:33, 15.49s/it]
# Reward: -1.0004267313999937, Length: 1.3298701298701299
#   6%|▌         | 6/100 [01:29<23:15, 14.85s/it]
# Reward: -1.000229489810596, Length: 1.3411918795022921
#  11%|█         | 11/100 [02:41<21:34, 14.55s/it]
# Reward: -1.0002818789840107, Length: 1.3553937789543349
#  16%|█▌        | 16/100 [03:53<20:11, 14.42s/it]
# Reward: -1.0002237132410234, Length: 1.313662604233483
#  21%|██        | 21/100 [05:04<18:57, 14.40s/it]
# Reward: -1.0002976141625557, Length: 1.3473684210526315
#  22%|██▏       | 22/100 [05:29<19:26, 14.96s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2007562717.py in <cell line: 0>()
#       5 for i in trange(num_episodes):
#       6
# ----> 7     result = trainer.train()
#       8
#       9     average_episode_reward = np.mean(
#
# /usr/local/lib/python3.12/dist-packages/ray/tune/trainable/trainable.py in train(self)
#     326         start = time.time()
#     327         try:
# --> 328             result = self.step()
#     329         except Exception as e:
#     330             skipped = skip_exceptions(e)
#
# /usr/local/lib/python3.12/dist-packages/ray/rllib/algorithms/algorithm.py in step(self)
#    1243                         train_results,
#    1244                         train_iter_ctx,
# -> 1245                     ) = self._run_one_training_iteration_old_api_stack()
#    1246
#    1247             # Sequential: Train (already done above), then evaluate.
#
# /usr/local/lib/python3.12/dist-packages/ray/rllib/algorithms/algorithm.py in _run_one_training_iteration_old_api_stack(self)
#    4328
#    4329                     with self._timers[TRAINING_STEP_TIMER]:
# -> 4330                         training_step_results = self.training_step()
#    4331
#    4332                     if training_step_results:
#
# /usr/local/lib/python3.12/dist-packages/ray/rllib/algorithms/ppo/ppo.py in training_step(self)
#     391         # Old API stack (Policy, RolloutWorker, Connector).
#     392         if not self.config.enable_env_runner_and_connector_v2:
# --> 393             return self._training_step_old_api_stack()
#     394
#     395         # Collect batches from sample workers until we have a full batch.
#
# /usr/local/lib/python3.12/dist-packages/ray/rllib/algorithms/ppo/ppo.py in _training_step_old_api_stack(self)
#     470                 )
#     471             else:
# --> 472                 train_batch = synchronous_parallel_sample(
#     473                     worker_set=self.env_runner_group,
#     474                     max_env_steps=self.config.total_train_batch_size,
#
# /usr/local/lib/python3.12/dist-packages/ray/rllib/execution/rollout_ops.py in synchronous_parallel_sample(worker_set, max_agent_steps, max_env_steps, concat, sample_timeout_s, random_actions, _uses_new_env_runners, _return_metrics)
#     105         # Loop over remote workers' `sample()` method in parallel.
#     106         else:
# --> 107             sampled_data = worker_set.foreach_env_runner(
#     108                 (
#     109                     (lambda w: w.sample(**random_action_kwargs))
#
# /usr/local/lib/python3.12/dist-packages/ray/rllib/env/env_runner_group.py in foreach_env_runner(self, func, kwargs, local_env_runner, healthy_only, remote_worker_ids, timeout_seconds, return_obj_refs, mark_healthy)
#     877             return local_result
#     878
# --> 879         remote_results = self._worker_manager.foreach_actor(
#     880             func,
#     881             kwargs=kwargs,
#
# /usr/local/lib/python3.12/dist-packages/ray/rllib/utils/actor_manager.py in foreach_actor(self, func, kwargs, healthy_only, remote_actor_ids, timeout_seconds, return_obj_refs, mark_healthy)
#     482
#     483         # Collect remote request results (if available given timeout and/or errors).
# --> 484         _, remote_results = self._fetch_result(
#     485             remote_actor_ids=remote_actor_ids,
#     486             remote_calls=remote_calls,
#
# /usr/local/lib/python3.12/dist-packages/ray/rllib/utils/actor_manager.py in _fetch_result(self, remote_actor_ids, remote_calls, tags, timeout_seconds, return_obj_refs, mark_healthy)
#     937             return [], RemoteCallResults()
#     938
# --> 939         readies, _ = ray.wait(
#     940             remote_calls,
#     941             num_returns=len(remote_calls),
#
# /usr/local/lib/python3.12/dist-packages/ray/_private/auto_init_hook.py in auto_init_wrapper(*args, **kwargs)
#      20     def auto_init_wrapper(*args, **kwargs):
#      21         auto_init_ray()
# ---> 22         return fn(*args, **kwargs)
#      23
#      24     return auto_init_wrapper
#
# /usr/local/lib/python3.12/dist-packages/ray/_private/client_mode_hook.py in wrapper(*args, **kwargs)
#     102             if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     103                 return getattr(ray, func.__name__)(*args, **kwargs)
# --> 104         return func(*args, **kwargs)
#     105
#     106     return wrapper
#
# /usr/local/lib/python3.12/dist-packages/ray/_private/worker.py in wait(ray_waitables, num_returns, timeout, fetch_local)
#    3211         timeout = timeout if timeout is not None else 10**6
#    3212         timeout_milliseconds = int(timeout * 1000)
# -> 3213         ready_ids, remaining_ids = worker.core_worker.wait(
#    3214             ray_waitables,
#    3215             num_returns,
#
# python/ray/_raylet.pyx in ray._raylet.CoreWorker.wait()
#
# python/ray/includes/common.pxi in ray._raylet.check_status()
#
# KeyboardInterrupt:
