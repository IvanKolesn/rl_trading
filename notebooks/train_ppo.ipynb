# %% [markdown]
# # PPO algorithm

# %% [markdown]
# ## Imports

# %%
1 + 1
# Out:
# 2

# %%
import os
import sys

sys.path.append("..")

# %%
# python -m build --sdist
# %pip install rl_trading-0.0.1.tar.gz

# %%
from copy import deepcopy

import gymnasium as Env
import numpy as np
import pandas as pd
import ray
import torch
import matplotlib.pyplot as plt

from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.models import ModelCatalog
from ray.rllib.utils.metrics import ENV_RUNNER_RESULTS
from ray.tune.registry import register_env
from sklearn.preprocessing import StandardScaler
from tqdm import trange

# %%
# Comment next two lines to run in collab
# %load_ext autoreload
# %autoreload 2

from rl_trading.environments.fx_environment import FxTradingEnv
from rl_trading.models.fx_model import FXModel

# %% [markdown]
# ## Todo

# %% [markdown]
# - Return portfolio history as info / custom metrics
# - Penalise excessive turnover (e.g., -0.5 * |action| per trade) to encourage smoother trading. Pass 0.5 as turnover penalty in trading params
# - Increase the number of iterations in training
# - Save results and model for one trading pair
# - Add differential sharpe ratio as reward (Allow to choose in params)
# - Save results and model for one trading pair
# - Return to bigger number of currencies
# - Try SAC and DreamerV3
#
# `*` Use feature importance or PCA to reduce dimension → smaller network, faster forward/backward.

# %% [markdown]
# ---
# ## Load and prepare historical data

# %%
# comment for collab
data_folder = "C:\\Users\\Ivan\\rl_trading\\data\\"
# data_folder = ""

# %%
historical_data = pd.read_parquet(f"{data_folder}FX_data.parquet.gzip")

# %%
for col in historical_data.columns:
    if col in ["ccy", "timestamp"]:
        continue
    historical_data[col] = historical_data[col].astype(float)

# %%
historical_data["ccy"] = historical_data["ccy"].str.upper()

# %% [markdown]
# ## temp step for debug
#
# ## Please ensure that historical data has no reverse currencies.  For example, EURUSD and USDEUR simulataneously

# %%
historical_data = historical_data.loc[historical_data["ccy"].isin(["EURUSD"]), :]

# %%
historical_data["ccy"].unique()
# Out:
# array(['EURUSD'], dtype=object)

# %% [markdown]
# ### Split data into 3 parts

# %% [markdown]
# Leave first 3 years to train scaler

# %%
historical_data_scaler_train = historical_data.loc[
    historical_data["timestamp"] <= "2023-01-01 00:00:00", :
]

# %% [markdown]
# Take next 2 years for training

# %%
historical_data_train = historical_data.loc[
    (historical_data["timestamp"] >= "2023-01-02 00:00:00")
    & (historical_data["timestamp"] < "2023-12-01 00:00:00"), 
    :
]

# %% [markdown]
# Leave last month as validation set

# %%
historical_data_validate = historical_data.loc[
    (historical_data["timestamp"] >= "2023-12-01 00:00:00"), 
    :
]

# %% [markdown]
# ### Set close prices aside for state

# %%
historical_prices_train = pd.pivot_table(
    data=historical_data_train, index="timestamp", columns="ccy", values="close"
).ffill().dropna()

# %%
historical_prices_validate = pd.pivot_table(
    data=historical_data_validate, index="timestamp", columns="ccy", values="close"
).ffill().dropna()

# %% [markdown]
# ### Train and apply scaler

# %%
# Transform outliers
transformer = StandardScaler().fit(
    historical_data_scaler_train.set_index(["timestamp", "ccy"])
)

# %%
features = transformer.transform(historical_data_train.set_index(["timestamp", "ccy"]))
multi_index = pd.MultiIndex.from_frame(historical_data_train[["timestamp", "ccy"]])
features = pd.DataFrame(features, index=multi_index)
historical_data_train = features.unstack("ccy").ffill().copy()

# %%
features = transformer.transform(historical_data_validate.set_index(["timestamp", "ccy"]))
multi_index = pd.MultiIndex.from_frame(historical_data_validate[["timestamp", "ccy"]])
features = pd.DataFrame(features, index=multi_index)
historical_data_validate = features.unstack("ccy").ffill().copy()

# %% [markdown]
# ### Remove unnessary variables to clear memory

# %%
del historical_data_scaler_train, historical_data, features

# %% [markdown]
# ---
# ## Trading config

# %% [markdown]
# ### Trading setup:
#
# 1. Algorithm starts with US dollars only
# 2. It trades minutely for one day and then converts all positions to US dollars to avoid leaving open position during the night
# 3. All transaction costs, slippage and fees are accounted in one trade fee: 1 bps per trade (can be changed)
# 4. We assume the market is liquid enough for our volume and disregard trading book structure

# %%
CURRENT_PORTFOLIO = {
    "USD": 100_000,
}

# %%
ENV_CONFIG = {
    "historical_prices": historical_prices_train,
    "features_dataset": historical_data_train,
    "initial_portfolio": CURRENT_PORTFOLIO,
    "start_datetime": None,  # pd.Timestamp("2023-01-03 09:00:00"),
    "episode_length_days": 1,
}

# %%
ENV_VALIDATION_CONFIG = {
    "historical_prices": historical_prices_validate,
    "features_dataset": historical_data_validate,
    "initial_portfolio": CURRENT_PORTFOLIO,
    "start_datetime": None,  # pd.Timestamp("2023-01-03 09:00:00"),
    "episode_length_days": 1,
}

# %% [markdown]
# ---
# ## Trial runs
#
# Run trials on validation dataset with random actions to measure execution time and debug the algorithm
#
# (You can skip that part)

# %% [markdown]
# ## todo: turn into function

# %%
fx_env = FxTradingEnv(**ENV_VALIDATION_CONFIG)

# %%
max_w = fx_env.trading_params["max_delta_in_weights"]

# %%
execution_times = []
portfolio_pos = []
total_rewards = []

for _ in trange(100):

    state, info = fx_env.reset()

    start_time = pd.Timestamp.now()
    done = False

    current_portfolio = []
    total_reward = []
    
    while not done:
    
        action = np.random.uniform(
            low=max_w * -1, high=max_w, size=len(fx_env.current_portfolio)
        )
        state, reward, terminated, truncated, info = fx_env.step(action)
        done = terminated or truncated

        current_portfolio.append(deepcopy(info["portfolio"]))
        total_reward.append(reward)

    execution_times.append((pd.Timestamp.now() - start_time).total_seconds())
    total_rewards.append(deepcopy(total_reward))
    portfolio_pos.append(deepcopy(current_portfolio))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:05<00:00, 17.55it/s]

# %%
np.quantile(execution_times, [0.01, 0.5, 0.99])
# Out:
# array([0.01354103, 0.031471  , 0.05664667])

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))

axs[0].hist([sum(x) for x in total_rewards], bins=50)
axs[0].set_xlabel("%")
axs[0].set_title("Total return")

axs[1].hist([np.mean(x) / np.std(x) for x in total_rewards], bins=50)
axs[1].set_xlabel("")
axs[1].set_title("Sharpe ratio")

fig.suptitle("Validation results")
plt.tight_layout()
plt.show()

# %%
pd.DataFrame.from_dict(portfolio_pos[5]).plot()
plt.title("Portfolio positions")
plt.xlabel("Minute")
plt.ylabel("Units of respective ccy")
plt.show()

# %%
fx_env.close()

# %% [markdown]
# ---
# ## RLLib setup

# %%
def env_creator(env_config):
    """
    Create env
    """
    fx_env = FxTradingEnv(**env_config)
    return fx_env

# %%
register_env("fx_trading_env", env_creator)
ModelCatalog.register_custom_model("fx_model", FXModel)

# %%
ray.init(
    ignore_reinit_error=True,
    # # To work with cloned repository
    # # Comment for Google collab or if you use pip install
    runtime_env={
        "working_dir": os.path.dirname(os.path.abspath(".")),
        "py_modules": [os.path.abspath(".")],
        "excludes": [
            "*.pyc",
            "__pycache__",
            "*.parquet.gzip",
            "*data/",
            "notebooks/",
            ".git/",
        ],
    },
)
# Out:
# 2026-02-18 16:34:01,203	INFO worker.py:2023 -- Started a local Ray instance.
# 2026-02-18 16:34:01,240	INFO packaging.py:588 -- Creating a file package for local module 'C:\Users\Ivan\rl_trading\notebooks'.
# 2026-02-18 16:34:01,279	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_fb4fcef31fef3e28.zip' (0.52MiB) to Ray cluster...
# 2026-02-18 16:34:01,282	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_fb4fcef31fef3e28.zip'.
# 2026-02-18 16:34:01,357	INFO packaging.py:588 -- Creating a file package for local module 'C:\Users\Ivan\rl_trading'.
# 2026-02-18 16:34:01,411	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_4b41630900c76979.zip' (0.24MiB) to Ray cluster...
# 2026-02-18 16:34:01,414	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_4b41630900c76979.zip'.
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# RayContext(dashboard_url='', python_version='3.12.10', ray_version='2.52.1', ray_commit='4ebdc0abe5e5a551625fe7f87053c7e668a6ff74')
# (pid=gcs_server) [2026-02-18 16:34:31,129 E 11784 6512] (gcs_server.exe) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2026-02-18 16:34:34,874 E 13188 3008] (raylet.exe) main.cc:979: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (RolloutWorker pid=17732) 2026-02-18 16:36:01,731	ERROR actor_manager.py:186 -- Worker exception caught during `apply()`: output array is read-only
# (RolloutWorker pid=17732) Traceback (most recent call last):
# (RolloutWorker pid=17732)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\utils\actor_manager.py", line 182, in apply
# (RolloutWorker pid=17732)     return func(self, *args, **kwargs)
# (RolloutWorker pid=17732)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17732)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\execution\rollout_ops.py", line 109, in <lambda>
# (RolloutWorker pid=17732)     (lambda w: w.sample(**random_action_kwargs))
# (RolloutWorker pid=17732)                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17732)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 461, in _resume_span
# (RolloutWorker pid=17732)     return method(self, *_args, **_kwargs)
# (RolloutWorker pid=17732)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17732)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 679, in sample
# (RolloutWorker pid=17732)     batches = [self.input_reader.next()]
# (RolloutWorker pid=17732)                ^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17732)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\sampler.py", line 59, in next
# (RolloutWorker pid=17732)     batches = [self.get_data()]
# (RolloutWorker pid=17732)                ^^^^^^^^^^^^^^^
# (RolloutWorker pid=17732)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\sampler.py", line 225, in get_data
# (RolloutWorker pid=17732)     item = next(self._env_runner)
# (RolloutWorker pid=17732)            ^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17732)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\env_runner_v2.py", line 330, in run
# (RolloutWorker pid=17732)     outputs = self.step()
# (RolloutWorker pid=17732)               ^^^^^^^^^^^
# (RolloutWorker pid=17732)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\env_runner_v2.py", line 386, in step
# (RolloutWorker pid=17732)     self._base_env.send_actions(actions_to_send)
# (RolloutWorker pid=17732)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\env\vector_env.py", line 463, in send_actions
# (RolloutWorker pid=17732)     ) = self.vector_env.vector_step(action_vector)
# (RolloutWorker pid=17732)         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17732)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\env\vector_env.py", line 359, in vector_step
# (RolloutWorker pid=17732)     raise e
# (RolloutWorker pid=17732)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\env\vector_env.py", line 352, in vector_step
# (RolloutWorker pid=17732)     results = self.envs[i].step(actions[i])
# (RolloutWorker pid=17732)               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17732)   File "C:\Users\Ivan\AppData\Local\Temp\ray\session_2026-02-18_16-33-56_712165_16524\runtime_resources\working_dir_files\_ray_pkg_4b41630900c76979\rl_trading\environments\fx_environment.py", line 125, in step
# (RolloutWorker pid=17732)     action *= self.trading_params["max_delta_in_weights"]
# (RolloutWorker pid=17732) ValueError: output array is read-only
# (raylet) A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. Lease ID: 02000000e7e710b05a8c7331bd049feb45802ab5c3d77187610b24cac940982f Worker ID: f8f9942698f7a2de549edea305397cb977142db7d1a73ece63bc2bf5 Node ID: 8b93d3b9d408a67404e02de3571ddd923bca2dc1fb9275d7d233442c Worker IP address: 127.0.0.1 Worker port: 50367 Worker PID: 13784 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code 1.

# %%
# Use all available CPUs minus 1
# Use all GPUs if available

suggested_workers = max(os.cpu_count() - 1, 1)

if torch.cuda.is_available():
    num_gpus = torch.cuda.device_count()
else:
    num_gpus = 0

suggested_workers, num_gpus
# Out:
# (7, 0)

# %%
config = PPOConfig()

config = (
    config.environment(
        env="fx_trading_env",
        env_config=ENV_CONFIG,
    )
    .framework("torch")
    .training(
        model={"custom_model": "fx_model"},
        lr=3e-4,
        clip_param=0.1,
        grad_clip=0.5,
        vf_clip_param=10.0,
        entropy_coeff=0.001,
        gamma=0.99,
        lambda_=0.95,
        num_epochs=25,
        train_batch_size=8192,
    )
    # .debugging(log_level="ERROR")
    .resources(num_gpus=num_gpus)
    .env_runners(
        num_cpus_per_env_runner=1,
        num_env_runners=suggested_workers,
        num_envs_per_env_runner=4,
        rollout_fragment_length="auto",
    )
    .api_stack(
        enable_rl_module_and_learner=False, enable_env_runner_and_connector_v2=False
    )
)

# %%
trainer = config.build_algo()
# Out:
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm.py:525: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2026-02-18 16:35:23,052	INFO trainable.py:161 -- Trainable.setup took 77.135 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.

# %%
trainer.get_policy().model.action_space
# Out:
# Box(-1.0, 1.0, (1,), float32)

# %%
trainer.get_policy().model.num_outputs  # (2 times action space: mu and log sigma)
# Out:
# np.int32(2)

# %% [markdown]
# ---
# ## Train the model

# %%
num_epochs = 5
# num_epochs = 100

# %%
# warnings.filterwarnings('ignore')

episode_rewards = []

for i in trange(num_epochs):

    result = trainer.train()

    average_episode_reward = np.mean(
        result[ENV_RUNNER_RESULTS]["hist_stats"]["episode_reward"]
    )
    episode_rewards.append(average_episode_reward)

    if i % 5 == 0:
        print(f"Last 5 epochs reward: {np.mean(episode_rewards[-5:])}")
# Out:
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]2026-02-18 16:37:01,959	WARNING rollout_ops.py:122 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2026-02-18 16:37:04,171	ERROR actor_manager.py:973 -- Ray error (The actor 5a0038600d54b0ac23166d1701000000 is unavailable: The actor is temporarily unavailable: IOError: The actor was restarted. The task may or may not have been executed on the actor.), taking actor 1 out of service.
# 2026-02-18 16:37:04,173	ERROR actor_manager.py:973 -- Ray error (The actor 19f9ad02e14b8d25568da87401000000 is unavailable: The actor is temporarily unavailable: RpcError: RPC error: Connection aborted rpc_code: 14. The task may or may not have been executed on the actor.), taking actor 2 out of service.
# 2026-02-18 16:37:04,179	ERROR actor_manager.py:973 -- Ray error (The actor 8bbe7798a58249344ab8f8df01000000 is unavailable: The actor is temporarily unavailable: IOError: The actor was restarted. The task may or may not have been executed on the actor.), taking actor 3 out of service.
# 2026-02-18 16:37:04,179	ERROR actor_manager.py:973 -- Ray error (The actor 32426c86aa2b96856e79036c01000000 is unavailable: The actor is temporarily unavailable: RpcError: RPC error: Connection aborted rpc_code: 14. The task may or may not have been executed on the actor.), taking actor 4 out of service.
# 2026-02-18 16:37:04,186	ERROR actor_manager.py:973 -- Ray error (The actor fa79956f01e3d22fd0dbb1d101000000 is unavailable: The actor is temporarily unavailable: RpcError: RPC error: Connection aborted rpc_code: 14. The task may or may not have been executed on the actor.), taking actor 5 out of service.
# 2026-02-18 16:37:04,246	ERROR actor_manager.py:973 -- Ray error (The actor e2b512ea7707078de0cb6b1d01000000 is unavailable: The actor is temporarily unavailable: IOError: The actor was restarted. The task may or may not have been executed on the actor.), taking actor 6 out of service.
# 2026-02-18 16:37:04,295	ERROR actor_manager.py:973 -- Ray error (The actor ef2dfd0e1176bdffc76f803701000000 is unavailable: The actor is temporarily unavailable: RpcError: RPC error: Connection aborted rpc_code: 14. The task may or may not have been executed on the actor.), taking actor 7 out of service.
# 2026-02-18 16:37:04,297	ERROR actor_manager.py:771 -- The actor 5a0038600d54b0ac23166d1701000000 is unavailable: The actor is temporarily unavailable: IOError: The actor was restarted. The task may or may not have been executed on the actor.
# NoneType: None
# 2026-02-18 16:37:04,353	ERROR actor_manager.py:771 -- The actor 19f9ad02e14b8d25568da87401000000 is unavailable: The actor is temporarily unavailable: RpcError: RPC error: Connection aborted rpc_code: 14. The task may or may not have been executed on the actor.
# NoneType: None
# 2026-02-18 16:37:04,400	ERROR actor_manager.py:771 -- The actor 8bbe7798a58249344ab8f8df01000000 is unavailable: The actor is temporarily unavailable: IOError: The actor was restarted. The task may or may not have been executed on the actor.
# NoneType: None
# 2026-02-18 16:37:04,402	ERROR actor_manager.py:771 -- The actor 32426c86aa2b96856e79036c01000000 is unavailable: The actor is temporarily unavailable: RpcError: RPC error: Connection aborted rpc_code: 14. The task may or may not have been executed on the actor.
# NoneType: None
# 2026-02-18 16:37:04,402	ERROR actor_manager.py:771 -- The actor fa79956f01e3d22fd0dbb1d101000000 is unavailable: The actor is temporarily unavailable: RpcError: RPC error: Connection aborted rpc_code: 14. The task may or may not have been executed on the actor.
# NoneType: None
# 2026-02-18 16:37:04,403	ERROR actor_manager.py:771 -- The actor e2b512ea7707078de0cb6b1d01000000 is unavailable: The actor is temporarily unavailable: IOError: The actor was restarted. The task may or may not have been executed on the actor.
# NoneType: None
# 2026-02-18 16:37:04,447	ERROR actor_manager.py:771 -- The actor ef2dfd0e1176bdffc76f803701000000 is unavailable: The actor is temporarily unavailable: RpcError: RPC error: Connection aborted rpc_code: 14. The task may or may not have been executed on the actor.
# NoneType: None
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  20%|████████████████▊                                                                   | 1/5 [01:03<04:12, 63.15s/it]
# Last 5 epochs reward: nan
# 2026-02-18 16:37:06,151	WARNING rollout_ops.py:122 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  40%|█████████████████████████████████▌                                                  | 2/5 [01:04<01:20, 26.93s/it]2026-02-18 16:37:08,201	WARNING rollout_ops.py:122 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [01:06<00:31, 15.60s/it]2026-02-18 16:37:10,490	WARNING rollout_ops.py:122 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [01:10<00:17, 17.68s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 7
#       3 episode_rewards = []
#       5 for i in trange(num_epochs):
# ----> 7     result = trainer.train()
#       9     average_episode_reward = np.mean(
#      10         result[ENV_RUNNER_RESULTS]["hist_stats"]["episode_reward"]
#      11     )
#      12     episode_rewards.append(average_episode_reward)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\trainable\trainable.py:328, in Trainable.train(self)
#     326 start = time.time()
#     327 try:
# --> 328     result = self.step()
#     329 except Exception as e:
#     330     skipped = skip_exceptions(e)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm.py:1245, in Algorithm.step(self)
#    1240         train_results, train_iter_ctx = self._run_one_training_iteration()
#    1241     else:
#    1242         (
#    1243             train_results,
#    1244             train_iter_ctx,
# -> 1245         ) = self._run_one_training_iteration_old_api_stack()
#    1247 # Sequential: Train (already done above), then evaluate.
#    1248 if evaluate_this_iter and not self.config.evaluation_parallel_to_training:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm.py:4320, in Algorithm._run_one_training_iteration_old_api_stack(self)
#    4318 while not train_iter_ctx.should_stop(training_step_results):
#    4319     with self._timers["restore_workers"]:
# -> 4320         restored = self.restore_env_runners(self.env_runner_group)
#    4321         # Fire the callback for re-created EnvRunners.
#    4322         if restored:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm.py:2143, in Algorithm.restore_env_runners(self, env_runner_group)
#    2141 restored = None
#    2142 if self.config.is_online:
# -> 2143     restored = env_runner_group.probe_unhealthy_env_runners()
#    2145 if not restored:
#    2146     return []
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\env\env_runner_group.py:1041, in EnvRunnerGroup.probe_unhealthy_env_runners(self)
#    1035 def probe_unhealthy_env_runners(self) -> List[int]:
#    1036     """Checks for unhealthy workers and tries restoring their states.
#    1037
#    1038     Returns:
#    1039         List of IDs of the workers that were restored.
#    1040     """
# -> 1041     return self._worker_manager.probe_unhealthy_actors(
#    1042         timeout_seconds=self._remote_config.env_runner_health_probe_timeout_s,
#    1043         mark_healthy=True,
#    1044     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\utils\actor_manager.py:817, in FaultTolerantActorManager.probe_unhealthy_actors(self, timeout_seconds, mark_healthy)
#     815 just_restored_actors = []
#     816 if unhealthy_actor_ids:
# --> 817     remote_results = self.foreach_actor(
#     818         func=lambda actor: actor.ping(),
#     819         remote_actor_ids=unhealthy_actor_ids,
#     820         healthy_only=False,  # We specifically want to ping unhealthy actors.
#     821         timeout_seconds=timeout_seconds,
#     822         return_obj_refs=False,
#     823         mark_healthy=mark_healthy,
#     824     )
#     825     just_restored_actors = [
#     826         result.actor_id for result in remote_results if result.ok
#     827     ]
#     829 # Clear out previously restored actors (b/c of other successful request
#     830 # responses, outside of this method).
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\utils\actor_manager.py:484, in FaultTolerantActorManager.foreach_actor(self, func, kwargs, healthy_only, remote_actor_ids, timeout_seconds, return_obj_refs, mark_healthy)
#     477 remote_calls = self._call_actors(
#     478     func=func,
#     479     kwargs=kwargs,
#     480     remote_actor_ids=remote_actor_ids,
#     481 )
#     483 # Collect remote request results (if available given timeout and/or errors).
# --> 484 _, remote_results = self._fetch_result(
#     485     remote_actor_ids=remote_actor_ids,
#     486     remote_calls=remote_calls,
#     487     tags=[None] * len(remote_calls),
#     488     timeout_seconds=timeout_seconds,
#     489     return_obj_refs=return_obj_refs,
#     490     mark_healthy=mark_healthy,
#     491 )
#     493 return remote_results
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\utils\actor_manager.py:939, in FaultTolerantActorManager._fetch_result(self, remote_actor_ids, remote_calls, tags, timeout_seconds, return_obj_refs, mark_healthy)
#     936 if not remote_calls:
#     937     return [], RemoteCallResults()
# --> 939 readies, _ = ray.wait(
#     940     remote_calls,
#     941     num_returns=len(remote_calls),
#     942     timeout=timeout,
#     943     # Make sure remote results are fetched locally in parallel.
#     944     fetch_local=not return_obj_refs,
#     945 )
#     947 # Remote data should already be fetched to local object store at this point.
#     948 remote_results = RemoteCallResults()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\auto_init_hook.py:22, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      19 @wraps(fn)
#      20 def auto_init_wrapper(*args, **kwargs):
#      21     auto_init_ray()
# ---> 22     return fn(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\client_mode_hook.py:104, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     102     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     103         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 104 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py:3213, in wait(ray_waitables, num_returns, timeout, fetch_local)
#    3211 timeout = timeout if timeout is not None else 10**6
#    3212 timeout_milliseconds = int(timeout * 1000)
# -> 3213 ready_ids, remaining_ids = worker.core_worker.wait(
#    3214     ray_waitables,
#    3215     num_returns,
#    3216     timeout_milliseconds,
#    3217     fetch_local,
#    3218 )
#    3219 return ready_ids, remaining_ids
#
# KeyboardInterrupt:

# %% [markdown]
# ### Save pytorch model for later evaluation

# %%
policy = trainer.get_policy()

# %%
MODEL_NAME = "USDEUR_MODEL_WEIGHTS_1_MIN_1_DAY.pth"

# %%
torch.save(policy.model.state_dict(), f"../trained_models/{MODEL_NAME}")

# %% [markdown]
# ### Plot training results

# %%
rewards = pd.Series(episode_rewards)

# %%
rewards = np.exp(rewards / 10000) - 1

# %%
rewards.rolling(5).mean().plot()
plt.title("Average total return per 5 iterations")
plt.xlabel("Iteration")
plt.ylabel("Total return (percentage)")
plt.show()

# %% [markdown]
# ---
# ## Validate the model

# %%
MODEL_NAME = "USDEUR_MODEL_WEIGHTS_1_MIN_1_DAY.pth"

# %%
fx_env = FxTradingEnv(**ENV_VALIDATION_CONFIG)

# %%
state_dict = torch.load(f"../trained_models/{MODEL_NAME}")

# %%
max_w = float(fx_env.action_space.high)
# Out:
# C:\Users\Ivan\AppData\Local\Temp\ipykernel_11940\545278240.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   max_w = float(fx_env.action_space.high)

# %%
trained_model = FXModel(
    obs_space=fx_env.observation_space,
    action_space=fx_env.action_space,
    num_outputs=fx_env.action_space.shape[0] * 2,
    model_config={},
    name="FXModel",  # any name if fine
)

# %%
trained_model.load_state_dict(state_dict)
trained_model.eval()
# Out:
# FXModel(
#   (main_net): Sequential(
#     (0): Linear(in_features=24, out_features=256, bias=True)
#     (1): GELU(approximate='none')
#     (2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (3): Linear(in_features=256, out_features=128, bias=True)
#     (4): GELU(approximate='none')
#     (5): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (6): Linear(in_features=128, out_features=64, bias=True)
#     (7): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (8): ReLU()
#   )
#   (action_net): Sequential(
#     (0): Linear(in_features=64, out_features=2, bias=True)
#     (1): Tanh()
#   )
#   (value_net): Sequential(
#     (0): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %%
# execution_times = []
# portfolio_pos = []
# total_rewards = []

# for _ in trange(1000):

#     state, info = fx_env.reset()

#     start_time = pd.Timestamp.now()
#     done = False

#     current_portfolio = []
#     total_reward = []
    
#     while not done:
    
#         action = np.random.uniform(
#             low=max_w * -1, high=max_w, size=len(fx_env.current_portfolio)
#         )
#         state, reward, terminated, truncated, info = fx_env.step(action)
#         done = terminated or truncated

#         current_portfolio.append(deepcopy(info["portfolio"]))
#         total_reward.append(reward)

#     execution_times.append((pd.Timestamp.now() - start_time).total_seconds())
#     total_rewards.append(deepcopy(total_reward))
#     portfolio_pos.append(deepcopy(current_portfolio))
#     break

# %%
# torch_state = torch.from_numpy(state).type(torch.float32)

# with torch.no_grad():
#     action, _ = trained_model(
#         input_dict={"obs": torch_state}, 
#         state=[],
#         seq_lens=None
#     )

# # action = np.maximum(np.minimum(action.detach().numpy(), max_w), -max_w)
