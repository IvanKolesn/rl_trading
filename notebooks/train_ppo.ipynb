# %%
import os
import sys
import warnings

sys.path.append("..")

# %%
# pip install ray

# %%
# pip install rl_trading.zip

# %%
import gymnasium as Env
import numpy as np
import pandas as pd
import ray
import torch

from tqdm import trange
from copy import deepcopy
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.models import ModelCatalog
from ray.rllib.utils.metrics import ENV_RUNNER_RESULTS
from ray.tune.registry import register_env

# %%
# Comment next two lines to run in collab
# %load_ext autoreload
# %autoreload 2

from rl_trading.environments.fx_environment import FxTradingEnv
from rl_trading.models.fx_model import FXModel

# %% [markdown]
# ## Trading setup:
#
# 1. Algorithm starts with US dollars only
# 2. It trades minutely for one day to avoid leaving position overnight
# 3. All transaction costs, slippage and fees are accounted in one trade fee: 10 bps per trade (can be changed)
# 4. We assume the market is liquid enough for our volume and disregard trading book structure

# %%
current_porfolio = {
    "usd": 100_000,
}

# %%
data_folder = "C:\\Users\\Ivan\\rl_trading\\data\\"
# data_folder = ""
historical_data = pd.read_parquet(f"{data_folder}FX_data.parquet.gzip")

# %%
historical_data = historical_data.loc[
    historical_data["timestamp"] >= "2020-01-02 00:00:00",
    :
]

# %%
# todo: pass as long table to allow for OHLC format
historical_prices = pd.pivot_table(
    data=historical_data,
    index="timestamp",
    columns="ccy",
    values="close"
)

historical_prices = historical_prices.ffill().dropna()

# %%
env_config = {
    "historical_prices": historical_prices,
    "features_dataset": historical_data, ## should we trasform it?
    "initial_portfolio": current_porfolio,
    "start_datetime": None,
    "episode_length_days": 5,
}

# %%
# fx_env = FxTradingEnv(**env_config)
# fx_env.preprocess_data()

# %%
# # FOR DEBUG PURPOSES
# max_w = fx_env.trading_params["max_delta_in_weights"]
# done = False
# step, info = fx_env.reset()
# total_reward = 0

# while not done:

#     action = np.random.uniform(
#         low=max_w * -1, high=max_w, size=len(current_porfolio)
#     )

#     state, reward, terminated, truncated, info = fx_env.step(action)
#     done = terminated or truncated
#     total_reward += reward

# %%
def env_creator(env_config):
    """
    Create env
    """
    fx_env = FxTradingEnv(**env_config)
    fx_env.preprocess_data()
    return fx_env

# %%
register_env("fx_trading_env", env_creator)
ModelCatalog.register_custom_model("fx_model", FXModel)

# %%
ray.init(
    ignore_reinit_error=True,
    # # To work with cloned repository. Comment for Google collab
    runtime_env={
        "working_dir": os.path.dirname(os.path.abspath(".")),
        "py_modules": [os.path.abspath(".")],
        "excludes": [
            "*.pyc",
            "__pycache__",
            "*.parquet.gzip",
            "*data/",
            "notebooks/",
        ],
    },
)
# Out:
# 2026-02-09 21:10:44,782	INFO worker.py:2023 -- Started a local Ray instance.
# 2026-02-09 21:10:44,810	INFO packaging.py:588 -- Creating a file package for local module 'C:\Users\Ivan\rl_trading\notebooks'.
# 2026-02-09 21:10:44,830	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_5b490fc0b47dec76.zip' (0.32MiB) to Ray cluster...
# 2026-02-09 21:10:44,832	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_5b490fc0b47dec76.zip'.
# 2026-02-09 21:10:46,415	INFO packaging.py:588 -- Creating a file package for local module 'C:\Users\Ivan\rl_trading'.
# 2026-02-09 21:10:46,495	WARNING packaging.py:430 -- File C:\Users\Ivan\rl_trading\.git\objects\0d\7064840b0e7c5fc2a794c6fa3aa6a16799e72f is very large (33.29MiB). Consider adding this file to the 'excludes' list to skip uploading it: `ray.init(..., runtime_env={'excludes': ['C:\Users\Ivan\rl_trading\.git\objects\0d\7064840b0e7c5fc2a794c6fa3aa6a16799e72f']})`
# 2026-02-09 21:10:46,995	WARNING packaging.py:430 -- File C:\Users\Ivan\rl_trading\.git\objects\ce\0f444171a8eded08fdd9eb1a497548b9b7059e is very large (27.86MiB). Consider adding this file to the 'excludes' list to skip uploading it: `ray.init(..., runtime_env={'excludes': ['C:\Users\Ivan\rl_trading\.git\objects\ce\0f444171a8eded08fdd9eb1a497548b9b7059e']})`
# 2026-02-09 21:10:47,280	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_36e433a908cec4c6.zip' (131.19MiB) to Ray cluster...
# 2026-02-09 21:10:47,707	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_36e433a908cec4c6.zip'.
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# RayContext(dashboard_url='', python_version='3.12.10', ray_version='2.52.1', ray_commit='4ebdc0abe5e5a551625fe7f87053c7e668a6ff74')
# (pid=gcs_server) [2026-02-09 21:11:14,673 E 10940 2252] (gcs_server.exe) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2026-02-09 21:11:20,329 E 7456 12668] (raylet.exe) main.cc:979: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (RolloutWorker pid=5680) Exception raised in creation task: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=5680, ip=127.0.0.1, actor_id=5546d2684d40b2b27a0b0f5d01000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x00000201C15B8590>)
# (RolloutWorker pid=5680)   File "python\\ray\\_raylet.pyx", line 1722, in ray._raylet.execute_task
# (RolloutWorker pid=5680)   File "python\\ray\\_raylet.pyx", line 1665, in ray._raylet.execute_task.function_executor
# (RolloutWorker pid=5680)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\function_manager.py", line 693, in actor_method_executor
# (RolloutWorker pid=5680)     return method(__ray_actor, *args, **kwargs)
# (RolloutWorker pid=5680)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=5680)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 461, in _resume_span
# (RolloutWorker pid=5680)     return method(self, *_args, **_kwargs)
# (RolloutWorker pid=5680)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=5680)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 284, in __init__
# (RolloutWorker pid=5680)     EnvRunner.__init__(self, config=config)
# (RolloutWorker pid=5680)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\env\env_runner.py", line 60, in __init__
# (RolloutWorker pid=5680)     self.config: AlgorithmConfig = config.copy(copy_frozen=False)
# (RolloutWorker pid=5680)                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=5680)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm_config.py", line 922, in copy
# (RolloutWorker pid=5680)     cp = copy.deepcopy(self)
# (RolloutWorker pid=5680)          ^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=5680)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\copy.py", line 162, in deepcopy
# (RolloutWorker pid=5680)     y = _reconstruct(x, memo, *rv)
# (RolloutWorker pid=5680)         ^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=5680)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\copy.py", line 259, in _reconstruct
# (RolloutWorker pid=5680)     state = deepcopy(state, memo)
# (RolloutWorker pid=5680)             ^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=5680)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\copy.py", line 136, in deepcopy
# (RolloutWorker pid=5680)     y = copier(x, memo)
# (RolloutWorker pid=5680)         ^^^^^^^^^^^^^^^
# (RolloutWorker pid=5680)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\copy.py", line 221, in _deepcopy_dict
# (RolloutWorker pid=5680)     y[deepcopy(key, memo)] = deepcopy(value, memo)
# (RolloutWorker pid=5680)                              ^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=5680)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\copy.py", line 136, in deepcopy
# (RolloutWorker pid=5680)     y = copier(x, memo)
# (RolloutWorker pid=5680)         ^^^^^^^^^^^^^^^
# (RolloutWorker pid=5680)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\copy.py", line 221, in _deepcopy_dict
# (RolloutWorker pid=5680)     y[deepcopy(key, memo)] = deepcopy(value, memo)
# (RolloutWorker pid=5680)                              ^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=5680)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\copy.py", line 143, in deepcopy
# (RolloutWorker pid=5680)     y = copier(memo)
# (RolloutWorker pid=5680)         ^^^^^^^^^^^^
# (RolloutWorker pid=5680)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py", line 6851, in __deepcopy__
# (RolloutWorker pid=5680)     return self.copy(deep=True)
# (RolloutWorker pid=5680)            ^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=5680)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py", line 6833, in copy
# (RolloutWorker pid=5680)     data = self._mgr.copy(deep=deep)
# (RolloutWorker pid=5680)            ^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=5680)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py", line 612, in copy
# (RolloutWorker pid=5680)     res = self.apply("copy", deep=deep)
# (RolloutWorker pid=5680)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=5680)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py", line 363, in apply
# (RolloutWorker pid=5680)     applied = getattr(b, f)(**kwargs)
# (RolloutWorker pid=5680)               ^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=5680)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py", line 822, in copy
# (RolloutWorker pid=5680)     values = values.copy()
# (RolloutWorker pid=5680)              ^^^^^^^^^^^^^
# (RolloutWorker pid=5680) numpy._core._exceptions._ArrayMemoryError: Unable to allocate 1.02 GiB for an array with shape (39, 3498740) and data type float64
# (RolloutWorker pid=10180)     self.env = env_creator(copy.deepcopy(self.env_context))
# (RolloutWorker pid=10180)                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=10180)   File "C:\Users\Ivan\AppData\Local\Temp\ipykernel_10776\3746045202.py", line 6, in env_creator
# (RolloutWorker pid=10180)   File "C:\Users\Ivan\rl_trading\notebooks\..\rl_trading\environments\fx_environment.py", line 67, in preprocess_data
# (RolloutWorker pid=10180)     low=-np.inf, high=np.inf, shape=self._get_state_dim(), dtype=np.float32
# (RolloutWorker pid=10180)   File "C:\Users\Ivan\rl_trading\notebooks\..\rl_trading\environments\base_environment.py", line 106, in _get_state_dim
# (RolloutWorker pid=10180)     return self._get_state().shape
# (RolloutWorker pid=10180)            ^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=10180)   File "C:\Users\Ivan\rl_trading\notebooks\..\rl_trading\environments\fx_environment.py", line 223, in _get_state
# (RolloutWorker pid=10180)     for _, data in temp_dataset.groupby("ccy"):
# (RolloutWorker pid=10180)                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=10180)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py", line 629, in get_iterator
# (RolloutWorker pid=10180)     yield from zip(keys, splitter)
# (RolloutWorker pid=10180)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py", line 1159, in __iter__
# (RolloutWorker pid=10180)     sdata = self._sorted_data
# (RolloutWorker pid=10180)             ^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=10180)   File "pandas/_libs/properties.pyx", line 36, in pandas._libs.properties.CachedProperty.__get__
# (RolloutWorker pid=10180)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py", line 1173, in _sorted_data
# (RolloutWorker pid=10180)     return self.data.take(self._sort_idx, axis=self.axis)
# (RolloutWorker pid=10180)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=10180)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py", line 4155, in take
# (RolloutWorker pid=10180)     new_data = self._mgr.take(
# (RolloutWorker pid=10180)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py", line 913, in take
# (RolloutWorker pid=10180)     return self.reindex_indexer(
# (RolloutWorker pid=10180)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py", line 707, in reindex_indexer
# (RolloutWorker pid=10180)     blk.take_nd(
# (RolloutWorker pid=10180)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py", line 1373, in take_nd
# (RolloutWorker pid=10180)     new_values = algos.take_nd(
# (RolloutWorker pid=10180)                  ^^^^^^^^^^^^^^
# (RolloutWorker pid=10180)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\array_algos\take.py", line 117, in take_nd
# (RolloutWorker pid=10180)     return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
# (RolloutWorker pid=10180)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=10180)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\array_algos\take.py", line 157, in _take_nd_ndarray
# (RolloutWorker pid=10180)     out = np.empty(out_shape, dtype=dtype)
# (RolloutWorker pid=10180)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=10180) numpy._core._exceptions._ArrayMemoryError: Unable to allocate 353. MiB for an array with shape (39, 1186742) and data type float64
# (RolloutWorker pid=10180) Exception raised in creation task: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=10180, ip=127.0.0.1, actor_id=2e391850cffa717201710c6301000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000024D5C69F4D0>) [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (RolloutWorker pid=10180)   File "python\\ray\\_raylet.pyx", line 1722, in ray._raylet.execute_task [repeated 2x across cluster]
# (RolloutWorker pid=10180)   File "python\\ray\\_raylet.pyx", line 1665, in ray._raylet.execute_task.function_executor [repeated 2x across cluster]
# (RolloutWorker pid=10180)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\function_manager.py", line 693, in actor_method_executor [repeated 2x across cluster]
# (RolloutWorker pid=10180)     return method(__ray_actor, *args, **kwargs) [repeated 2x across cluster]
# (RolloutWorker pid=10180)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 2x across cluster]
# (RolloutWorker pid=10180)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 461, in _resume_span [repeated 2x across cluster]
# (RolloutWorker pid=10180)     return method(self, *_args, **_kwargs) [repeated 2x across cluster]
# (RolloutWorker pid=10180)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ [repeated 2x across cluster]
# (RolloutWorker pid=10180)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 396, in __init__ [repeated 3x across cluster]
# (RolloutWorker pid=17276)     EnvRunner.__init__(self, config=config)
# (RolloutWorker pid=17276)     self.config: AlgorithmConfig = config.copy(copy_frozen=False)
# (RolloutWorker pid=17276)                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17276)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py", line 822, in copy [repeated 4x across cluster]
# (RolloutWorker pid=17276)     cp = copy.deepcopy(self)
# (RolloutWorker pid=17276)          ^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17276)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\copy.py", line 143, in deepcopy [repeated 4x across cluster]
# (RolloutWorker pid=17276)     y = _reconstruct(x, memo, *rv)
# (RolloutWorker pid=17276)         ^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17276)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\copy.py", line 259, in _reconstruct
# (RolloutWorker pid=17276)     state = deepcopy(state, memo)
# (RolloutWorker pid=10180)            ^^^^^^^^^^^^^^^^^^^^^ [repeated 5x across cluster]
# (RolloutWorker pid=17276)     y = copier(x, memo) [repeated 2x across cluster]
# (RolloutWorker pid=10180)                ^^^^^^^^^^^^^^^ [repeated 3x across cluster]
# (RolloutWorker pid=17276)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\copy.py", line 221, in _deepcopy_dict [repeated 2x across cluster]
# (RolloutWorker pid=17276)     y[deepcopy(key, memo)] = deepcopy(value, memo) [repeated 2x across cluster]
# (RolloutWorker pid=17276)     y = copier(memo)
# (RolloutWorker pid=17276)         ^^^^^^^^^^^^
# (RolloutWorker pid=17276)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py", line 6851, in __deepcopy__
# (RolloutWorker pid=17276)     return self.copy(deep=True)
# (RolloutWorker pid=17276)            ^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17276)     data = self._mgr.copy(deep=deep)
# (RolloutWorker pid=17276)            ^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17276)     res = self.apply("copy", deep=deep)
# (RolloutWorker pid=17276)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17276)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py", line 363, in apply
# (RolloutWorker pid=17276)     applied = getattr(b, f)(**kwargs)
# (RolloutWorker pid=17276)               ^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17276)     values = values.copy()
# (RolloutWorker pid=17276)              ^^^^^^^^^^^^^
# (RolloutWorker pid=17276) numpy._core._exceptions._ArrayMemoryError: Unable to allocate 1.02 GiB for an array with shape (39, 3498740) and data type float64
# (RolloutWorker pid=17884)     self.policy_dict, self.is_policy_to_train = self.config.get_multi_agent_setup(
# (RolloutWorker pid=17884)                                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17884)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm_config.py", line 5800, in get_multi_agent_setup
# (RolloutWorker pid=17884)     policies[pid].config = self.copy(copy_frozen=False).update_from_dict(
# (RolloutWorker pid=17884)                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17884)     cp = copy.deepcopy(self)
# (RolloutWorker pid=17884)          ^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17884)     y = _reconstruct(x, memo, *rv)
# (RolloutWorker pid=17884)         ^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17884)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\copy.py", line 259, in _reconstruct
# (RolloutWorker pid=17884)     state = deepcopy(state, memo)
# (RolloutWorker pid=17884)     y = copier(memo)
# (RolloutWorker pid=17884)         ^^^^^^^^^^^^
# (RolloutWorker pid=17884)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py", line 6851, in __deepcopy__
# (RolloutWorker pid=17884)     return self.copy(deep=True)
# (RolloutWorker pid=17884)            ^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17884)     data = self._mgr.copy(deep=deep)
# (RolloutWorker pid=17884)            ^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17884)     res = self.apply("copy", deep=deep)
# (RolloutWorker pid=17884)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17884)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py", line 363, in apply
# (RolloutWorker pid=17884)     applied = getattr(b, f)(**kwargs)
# (RolloutWorker pid=17884)               ^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17884)     values = values.copy()
# (RolloutWorker pid=17884)              ^^^^^^^^^^^^^
# (RolloutWorker pid=17884) numpy._core._exceptions._ArrayMemoryError: Unable to allocate 187. MiB for an array with shape (7, 3498740) and data type int64
# (RolloutWorker pid=17884) Exception raised in creation task: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=17884, ip=127.0.0.1, actor_id=4488603c6d1111cfa0b3031501000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001E85A74FD10>)
# (RolloutWorker pid=17884)   File "python\\ray\\_raylet.pyx", line 1722, in ray._raylet.execute_task
# (RolloutWorker pid=17884)   File "python\\ray\\_raylet.pyx", line 1665, in ray._raylet.execute_task.function_executor
# (RolloutWorker pid=17884)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\function_manager.py", line 693, in actor_method_executor
# (RolloutWorker pid=17884)     return method(__ray_actor, *args, **kwargs)
# (RolloutWorker pid=17884)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17884)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 461, in _resume_span
# (RolloutWorker pid=17884)     return method(self, *_args, **_kwargs)
# (RolloutWorker pid=17884)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=17884)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 466, in __init__
# (RolloutWorker pid=17884)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py", line 822, in copy [repeated 4x across cluster]
# (RolloutWorker pid=17884)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\copy.py", line 143, in deepcopy [repeated 4x across cluster]
# (RolloutWorker pid=17884)                              ^^^^^^^^^^^^^^^^^^^^^ [repeated 3x across cluster]
# (RolloutWorker pid=17884)     y = copier(x, memo) [repeated 2x across cluster]
# (RolloutWorker pid=17884)         ^^^^^^^^^^^^^^^ [repeated 2x across cluster]
# (RolloutWorker pid=17884)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\copy.py", line 221, in _deepcopy_dict [repeated 2x across cluster]
# (RolloutWorker pid=17884)     y[deepcopy(key, memo)] = deepcopy(value, memo) [repeated 2x across cluster]
# (RolloutWorker pid=15340) Exception raised in creation task: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=15340, ip=127.0.0.1, actor_id=f0eb22fbb6bf3273e1aefe3101000000, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001E3C848BB00>)
# (RolloutWorker pid=15340)   File "python\\ray\\_raylet.pyx", line 1722, in ray._raylet.execute_task
# (RolloutWorker pid=15340)   File "python\\ray\\_raylet.pyx", line 1665, in ray._raylet.execute_task.function_executor
# (RolloutWorker pid=15340)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\function_manager.py", line 693, in actor_method_executor
# (RolloutWorker pid=15340)     return method(__ray_actor, *args, **kwargs)
# (RolloutWorker pid=15340)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=15340)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 461, in _resume_span
# (RolloutWorker pid=15340)     return method(self, *_args, **_kwargs)
# (RolloutWorker pid=15340)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=15340)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 466, in __init__
# (RolloutWorker pid=15340) numpy._core._exceptions._ArrayMemoryError: Unable to allocate 187. MiB for an array with shape (7, 3498740) and data type int64

# %%
suggested_workers = os.cpu_count() - 1

if torch.cuda.is_available():
    num_gpus = torch.cuda.device_count()
else:
    num_gpus = 0

suggested_workers, num_gpus
# Out:
# (7, 0)

# %%
config = PPOConfig()

config = (
    config.environment(
        env="fx_trading_env",
        env_config=env_config,
    )
    .framework("torch")
    .training(
        model={"custom_model": "fx_model"},
        lr=1e-4,
        clip_param=0.2,
        vf_clip_param=10.0,
        entropy_coeff=0.01,
        gamma=0.99,
        train_batch_size=2048,
    )
    # .debugging(log_level="ERROR")
    .resources(num_gpus=num_gpus)
    .env_runners(
        num_cpus_per_env_runner=1,
        num_env_runners=suggested_workers,
        rollout_fragment_length="auto",
    )
    .api_stack(
        enable_rl_module_and_learner=False, enable_env_runner_and_connector_v2=False
    )
)

# %%
trainer = config.build_algo()
# Out:
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm.py:525: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))

# %%
num_epochs = 1
# num_epochs = 100

# %%
# warnings.filterwarnings('ignore')

episode_rewards = []

for i in trange(num_epochs):

    result = trainer.train()

    average_episode_reward = np.mean(
        result[ENV_RUNNER_RESULTS]["hist_stats"]["episode_reward"]
    )
    episode_rewards.append(average_episode_reward)

    if i % 5 == 0:
        print(f"Last 5 epochs reward: {np.mean(episode_rewards[-5:])}")

# %% [markdown]
# Plot results + trailing sharpe ratio

# %%
result[ENV_RUNNER_RESULTS]["hist_stats"]
