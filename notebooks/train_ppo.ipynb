# %% [markdown]
# # PPO algorithm

# %% [markdown]
# ## Imports

# %%
1 + 1
# Out:
# 2

# %%
import os
import sys

sys.path.append("..")

# %%
# python -m build --sdist
# %pip install rl_trading-0.0.1.tar.gz

# %%
from copy import deepcopy

import dill
import gymnasium as Env
import numpy as np
import pandas as pd
import ray
import torch
import matplotlib.pyplot as plt

from pprint import pprint
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.models import ModelCatalog
from ray.rllib.utils.metrics import ENV_RUNNER_RESULTS
from ray.tune.registry import register_env
from tqdm import trange

# %%
# Comment next two lines to run in collab
# %load_ext autoreload
# %autoreload 2

from rl_trading.environments.fx_environment import FxTradingEnv
from rl_trading.models.fx_model import FXModel
from rl_trading.environments.base_environment import (
    DEFAULT_TRADING_PARAMS,
)

# %% [markdown]
# ## Todo

# %% [markdown]
# - Try more epochs, compare results
# - Increase number of trading days to 5
# - Try SAC and DreamerV3

# %% [markdown]
# ---
# ## Load and prepare historical data

# %%
# comment for collab
data_folder = "C:\\Users\\Ivan\\rl_trading\\data\\"
# data_folder = ""

# %%
with open(f"{data_folder}preprocessed_data.pkl", "rb") as f:
    historical_data = dill.load(f)

# %%
train_prices, train_data, validate_prices, validate_data = historical_data.values()

# %% [markdown]
# What to trade:

# %%
TICKER_SET = ('EURJPY', 'EURUSD', 'SGDJPY', 'USDJPY', 'USDSGD',)

# %%
del historical_data

# %% [markdown]
# ---
# ## Trading config

# %% [markdown]
# ### Trading setup:
#
# 1. Algorithm starts with US dollars only
# 2. It trades minutely for one day and then converts all positions to US dollars to avoid leaving open position during the night
# 3. All transaction costs, slippage and fees are accounted in one trade fee: 1 bps per trade (can be changed)
# 4. We assume the market is liquid enough for our volume and disregard trading book structure

# %%
CURRENT_PORTFOLIO = {
    "USD": 100_000,
}

# %% [markdown]
# if all actions are 0.99 -> 0.05 * 0.99**2 -> 0.05

# %%
TRAIN_TRADING_PARAMS = DEFAULT_TRADING_PARAMS.copy()
TRAIN_TRADING_PARAMS["action_penalty"] = 0.05
TRAIN_TRADING_PARAMS["no_trade_penalty"] = 0.5
TRAIN_TRADING_PARAMS["reward"] = "total_profit"  # "diff_sharpe" or "total_profit"

# %%
ENV_CONFIG = {
    "historical_prices": train_prices,
    "features_dataset": train_data,
    "initial_portfolio": CURRENT_PORTFOLIO,
    "ticker_set": TICKER_SET,
    "start_datetime": None,  # pd.Timestamp("2023-01-03 09:00:00"),
    "episode_length_days": 1,
    "trading_params": TRAIN_TRADING_PARAMS,
}

# %%
VALIDATION_TRADING_PARAMS = TRAIN_TRADING_PARAMS.copy()
VALIDATION_TRADING_PARAMS["no_trade_penalty"] = 0
VALIDATION_TRADING_PARAMS["action_penalty"] = 0
VALIDATION_TRADING_PARAMS["reward"] = "total_profit"

# %%
ENV_VALIDATION_CONFIG = {
    "historical_prices": validate_prices,
    "features_dataset": validate_data,
    "initial_portfolio": CURRENT_PORTFOLIO,
    "ticker_set": TICKER_SET,
    "start_datetime": None,  # pd.Timestamp("2023-01-03 09:00:00"),
    "episode_length_days": 1,
    "trading_params": VALIDATION_TRADING_PARAMS,
}

# %%
max(validate_prices.keys())
# Out:
# '2024-12-31 16:58:00'

# %% [markdown]
# ---
# ## Trial runs
#
# Run trials on validation dataset with random actions to measure execution time and debug the algorithm
#
# (You can skip that part)

# %% [markdown]
# ## todo: turn into function

# %%
fx_env = FxTradingEnv(**ENV_VALIDATION_CONFIG)

# %%
fx_env.preprocess_data()

# %%
pprint(fx_env.trading_params)
# Out:
# {'action_penalty': 0,
#  'base_currency': 'USD',
#  'long_only': True,
#  'max_delta_in_weights': 0.25,
#  'no_trade_penalty': 0,
#  'reward': 'total_profit',
#  'sharpe_eta': 0.1,
#  'slippage': (0.0001, 0.0002),
#  'trade_fee': 0.0001}

# %%
max_w = fx_env.trading_params["max_delta_in_weights"]

# %%
execution_times = []
portfolio_pos = []
total_rewards = []

for _ in trange(100):

    state, info = fx_env.reset()

    start_time = pd.Timestamp.now()
    done = False

    current_portfolio = []
    total_reward = []

    while not done:

        action = np.random.uniform(
            low=max_w * -1, high=max_w, size=len(fx_env.current_portfolio)
        )
        state, reward, terminated, truncated, info = fx_env.step(action)
        done = terminated or truncated

        current_portfolio.append(deepcopy(info["portfolio"]))
        total_reward.append(reward)

    execution_times.append((pd.Timestamp.now() - start_time).total_seconds())
    total_rewards.append(deepcopy(total_reward))
    portfolio_pos.append(deepcopy(current_portfolio))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.93it/s]

# %%
np.quantile(execution_times, [0.01, 0.5, 0.99])
# Out:
# array([0.03932112, 0.067734  , 0.10478118])

# %%
total_rewards = [np.array(x) / 100 for x in total_rewards]

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))

axs[0].hist([np.exp(sum(x)) - 1 for x in total_rewards], bins=50)
axs[0].set_xlabel("percentage")
axs[0].set_title("Total return")

axs[1].hist([np.mean(x) / np.std(x) for x in total_rewards], bins=50)
axs[1].set_xlabel("")
axs[1].set_title("Sharpe ratio")

fig.suptitle("Validation results")
plt.tight_layout()
plt.show()

# %%
pd.DataFrame.from_dict(portfolio_pos[5]).plot()
plt.title("Portfolio positions")
plt.xlabel("Minute")
plt.ylabel("Units of respective ccy")
plt.show()

# %%
fx_env.close()

# %% [markdown]
# ---
# ## RLLib setup

# %%
def env_creator(env_config):
    """
    Create env
    """
    fx_env = FxTradingEnv(**env_config)
    fx_env.preprocess_data()
    return fx_env

# %%
register_env("fx_trading_env", env_creator)
ModelCatalog.register_custom_model("fx_model", FXModel)

# %%
ray.init(
    ignore_reinit_error=True,
    # # To work with cloned repository
    # # Comment for Google collab or if you use pip install
    runtime_env={
        "working_dir": os.path.dirname(os.path.abspath(".")),
        "py_modules": [os.path.abspath(".")],
        "excludes": [
            "*.pyc",
            "__pycache__",
            "*.parquet.gzip",
            "*data/",
            "notebooks/",
            ".git/",
        ],
    },
)
# Out:
# 2026-02-24 15:59:43,406	INFO worker.py:2023 -- Started a local Ray instance.
# 2026-02-24 15:59:43,444	INFO packaging.py:588 -- Creating a file package for local module 'C:\Users\Ivan\rl_trading\notebooks'.
# 2026-02-24 15:59:43,464	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_cf2ea240404f69b4.zip' (1.14MiB) to Ray cluster...
# 2026-02-24 15:59:43,470	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_cf2ea240404f69b4.zip'.
# 2026-02-24 15:59:43,532	INFO packaging.py:588 -- Creating a file package for local module 'C:\Users\Ivan\rl_trading'.
# 2026-02-24 15:59:43,584	INFO packaging.py:380 -- Pushing file package 'gcs://_ray_pkg_f3c5834901c757c0.zip' (0.47MiB) to Ray cluster...
# 2026-02-24 15:59:43,587	INFO packaging.py:393 -- Successfully pushed file package 'gcs://_ray_pkg_f3c5834901c757c0.zip'.
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\_private\worker.py:2062: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# RayContext(dashboard_url='', python_version='3.12.10', ray_version='2.52.1', ray_commit='4ebdc0abe5e5a551625fe7f87053c7e668a6ff74')
# (pid=gcs_server) [2026-02-24 16:00:13,159 E 1372 9200] (gcs_server.exe) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2026-02-24 16:00:16,835 E 8544 12972] (raylet.exe) main.cc:979: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (RolloutWorker pid=8148) 2026-02-24 17:09:55,274	ERROR actor_manager.py:186 -- Worker exception caught during `apply()`: Observation ([ 1.4508741e-01  1.4403501e-01  5.3562510e-01  1.7525250e-01
# (RolloutWorker pid=8148)   1.1573640e+03  9.6795233e+02 -1.9409071e+02  1.6031271e+02
# (RolloutWorker pid=8148)  -2.7541569e+01  1.6154639e+03  3.7144385e+02 -3.6713080e+02
# (RolloutWorker pid=8148)   7.3284149e+00  8.9436127e+02  2.1229651e+02 -3.5587866e+02
# (RolloutWorker pid=8148)  -9.5786980e+01  9.1509821e+02 -8.5681580e+01 -2.5980463e+02
# (RolloutWorker pid=8148)  -5.2919666e+01  1.4765807e+02  7.9127140e+00  5.0179134e+01
# (RolloutWorker pid=8148)   2.6185135e+01 -1.8244473e+01  5.3076725e+00 -9.3684418e+01
# (RolloutWorker pid=8148)  -2.3720499e+01  3.1965050e+01 -5.0000000e-01 -8.6602539e-01
# (RolloutWorker pid=8148)   0.0000000e+00  1.0000000e+00  3.0000000e+00] dtype=float32) outside given space (Box(-1000.0, 1000.0, (35,), float32))!
# (RolloutWorker pid=8148) Traceback (most recent call last):
# (RolloutWorker pid=8148)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\utils\actor_manager.py", line 182, in apply
# (RolloutWorker pid=8148)     return func(self, *args, **kwargs)
# (RolloutWorker pid=8148)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=8148)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\execution\rollout_ops.py", line 109, in <lambda>
# (RolloutWorker pid=8148)     (lambda w: w.sample(**random_action_kwargs))
# (RolloutWorker pid=8148)                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=8148)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 461, in _resume_span
# (RolloutWorker pid=8148)     return method(self, *_args, **_kwargs)
# (RolloutWorker pid=8148)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=8148)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 679, in sample
# (RolloutWorker pid=8148)     batches = [self.input_reader.next()]
# (RolloutWorker pid=8148)                ^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=8148)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\sampler.py", line 59, in next
# (RolloutWorker pid=8148)     batches = [self.get_data()]
# (RolloutWorker pid=8148)                ^^^^^^^^^^^^^^^
# (RolloutWorker pid=8148)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\sampler.py", line 225, in get_data
# (RolloutWorker pid=8148)     item = next(self._env_runner)
# (RolloutWorker pid=8148)            ^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=8148)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\env_runner_v2.py", line 330, in run
# (RolloutWorker pid=8148)     outputs = self.step()
# (RolloutWorker pid=8148)               ^^^^^^^^^^^
# (RolloutWorker pid=8148)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\env_runner_v2.py", line 356, in step
# (RolloutWorker pid=8148)     active_envs, to_eval, outputs = self._process_observations(
# (RolloutWorker pid=8148)                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=8148)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\evaluation\env_runner_v2.py", line 623, in _process_observations
# (RolloutWorker pid=8148)     processed = policy.agent_connectors(acd_list)
# (RolloutWorker pid=8148)                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=8148)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\connectors\agent\pipeline.py", line 40, in __call__
# (RolloutWorker pid=8148)     ret = c(ret)
# (RolloutWorker pid=8148)           ^^^^^^
# (RolloutWorker pid=8148)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\connectors\connector.py", line 265, in __call__
# (RolloutWorker pid=8148)     return [self.transform(d) for d in acd_list]
# (RolloutWorker pid=8148)             ^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=8148)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\connectors\agent\obs_preproc.py", line 55, in transform
# (RolloutWorker pid=8148)     d[SampleBatch.NEXT_OBS] = self._preprocessor.transform(
# (RolloutWorker pid=8148)                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=8148)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\models\preprocessors.py", line 214, in transform
# (RolloutWorker pid=8148)     self.check_shape(observation)
# (RolloutWorker pid=8148)   File "C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\models\preprocessors.py", line 72, in check_shape
# (RolloutWorker pid=8148)     raise ValueError(
# (RolloutWorker pid=8148) ValueError: Observation ([ 1.4508741e-01  1.4403501e-01  5.3562510e-01  1.7525250e-01
# (RolloutWorker pid=8148)   1.1573640e+03  9.6795233e+02 -1.9409071e+02  1.6031271e+02
# (RolloutWorker pid=8148)  -2.7541569e+01  1.6154639e+03  3.7144385e+02 -3.6713080e+02
# (RolloutWorker pid=8148)   7.3284149e+00  8.9436127e+02  2.1229651e+02 -3.5587866e+02
# (RolloutWorker pid=8148)  -9.5786980e+01  9.1509821e+02 -8.5681580e+01 -2.5980463e+02
# (RolloutWorker pid=8148)  -5.2919666e+01  1.4765807e+02  7.9127140e+00  5.0179134e+01
# (RolloutWorker pid=8148)   2.6185135e+01 -1.8244473e+01  5.3076725e+00 -9.3684418e+01
# (RolloutWorker pid=8148)  -2.3720499e+01  3.1965050e+01 -5.0000000e-01 -8.6602539e-01
# (RolloutWorker pid=8148)   0.0000000e+00  1.0000000e+00  3.0000000e+00] dtype=float32) outside given space (Box(-1000.0, 1000.0, (35,), float32))!
# (raylet) A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. Lease ID: 000000003b893aa88de71764bf917555f6727956696f3d7c80fb637f366b17d7 Worker ID: 271e20e99a54938791dd22d9bd21afbbbd1e88888560ead2f702c30b Node ID: b15f59f281b646aa0f28217478a74f23404b892816072909085c5acd Worker IP address: 127.0.0.1 Worker port: 53917 Worker PID: 8148 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code 1.

# %%
# Use all available CPUs minus 1
# Use all GPUs if available
suggested_workers = max(os.cpu_count() - 1, 1)

if torch.cuda.is_available():
    num_gpus = torch.cuda.device_count()
else:
    num_gpus = 0

suggested_workers, num_gpus
# Out:
# (7, 0)

# %%
historical_prices_ref = ray.put(train_prices)
features_ref = ray.put(train_data)

# %%
ENV_CONFIG.update(
    {"historical_prices": historical_prices_ref, "features_dataset": features_ref}
)

# %%
pprint(ENV_CONFIG)
# Out:
# {'episode_length_days': 1,
#  'features_dataset': ObjectRef(00ffffffffffffffffffffffffffffffffffffff0100000002e1f505),
#  'historical_prices': ObjectRef(00ffffffffffffffffffffffffffffffffffffff0100000001e1f505),
#  'initial_portfolio': {'USD': 100000},
#  'start_datetime': None,
#  'ticker_set': ('EURJPY', 'EURUSD', 'SGDJPY', 'USDJPY', 'USDSGD'),
#  'trading_params': {'action_penalty': 0.05,
#                     'base_currency': 'USD',
#                     'long_only': True,
#                     'max_delta_in_weights': 0.25,
#                     'no_trade_penalty': 0.5,
#                     'reward': 'total_profit',
#                     'sharpe_eta': 0.1,
#                     'slippage': (0.0001, 0.0002),
#                     'trade_fee': 0.0001}}

# %% [markdown]
# In most PPO implementations (including RLlib), 3–10 epochs per batch is typical. Using more can actually increase the risk of getting stuck in local minima because the policy may overfit to the current batch of data, causing it to lose generalization and converge prematurely.

# %%
config = PPOConfig()

config = (
    config.environment(
        env="fx_trading_env",
        env_config=ENV_CONFIG,
    )
    .framework("torch")
    .training(
        model={"custom_model": "fx_model"},
        lr=3e-4,
        clip_param=0.2,
        grad_clip=0.5,
        vf_clip_param=10.0,
        entropy_coeff=0.01,
        gamma=0.99,
        lambda_=0.95,
        num_epochs=8,
        train_batch_size=16384,
    )
    .debugging(log_level="ERROR")
    .resources(num_gpus=num_gpus)
    .env_runners(
        num_cpus_per_env_runner=1,
        num_env_runners=suggested_workers,
        num_envs_per_env_runner=4,
        rollout_fragment_length="auto",
        exploration_config={
            "type": "StochasticSampling",  # default
            "random_timesteps": 5_000,
        },
    )
    # .evaluation(
    #     evaluation_interval=5,
    #     evaluation_config={
    #         "explore": False,
    #     }
    # )
    .api_stack(
        enable_rl_module_and_learner=False, enable_env_runner_and_connector_v2=False
    )
)

# %%
trainer = config.build_algo()
# Out:
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\rllib\algorithms\algorithm.py:525: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# C:\Users\Ivan\AppData\Local\Programs\Python\Python312\Lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2026-02-24 16:00:37,044	INFO trainable.py:161 -- Trainable.setup took 47.442 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.

# %% [markdown]
# 25 features + 5 prices + 5 time features

# %%
trainer.get_policy().observation_space
# Out:
# Box(-1000.0, 1000.0, (35,), float32)

# %% [markdown]
# 5 ccys

# %%
trainer.get_policy().action_space
# Out:
# Box(-1.0, 1.0, (5,), float32)

# %% [markdown]
# ---
# ## Train the model

# %%
num_epochs = 200
# will not be applied for first 100
early_stopping_patience = 20
min_improvement = 0.01
best_reward = -np.inf

# %%
# warnings.filterwarnings('ignore')
episode_rewards = []
patience_counter = 0

for i in trange(num_epochs):

    result = trainer.train()

    average_episode_reward = np.mean(
        result[ENV_RUNNER_RESULTS]["hist_stats"]["episode_reward"]
    )
    episode_rewards.append(average_episode_reward)

    if np.mean(episode_rewards[-5:]) >= best_reward + min_improvement:
        best_reward = np.mean(episode_rewards[-5:])
        patience_counter = 0
    else:
        patience_counter += 1

    if (patience_counter > early_stopping_patience) and (i > 100):
        print(f"Early stopping! No improvements for {patience_counter} steps")
        break
    
    if i % 5 == 0:
        print(f"Last 5 epochs reward: {np.mean(episode_rewards[-5:])}")
# Out:
#   0%|                                                                                          | 0/200 [00:00<?, ?it/s]2026-02-24 16:02:39,976	WARNING train_ops.py:114 -- DeprecationWarning: `ray.rllib.execution.train_ops.multi_gpu_train_one_step` has been deprecated. This will raise an error in the future!
#   0%|▍                                                                                 | 1/200 [00:15<51:42, 15.59s/it]
# Last 5 epochs reward: -10.886281701321467
#   3%|██▍                                                                               | 6/200 [01:42<57:40, 17.84s/it]
# Last 5 epochs reward: -17.881908336624424
#   6%|████▎                                                                          | 11/200 [03:19<1:00:35, 19.23s/it]
# Last 5 epochs reward: -19.184900771220356
#   8%|██████▍                                                                          | 16/200 [04:50<56:39, 18.47s/it]
# Last 5 epochs reward: -17.69793635927017
#  10%|████████▌                                                                        | 21/200 [06:24<56:15, 18.86s/it]
# Last 5 epochs reward: -15.44877202787335
#  13%|██████████▌                                                                      | 26/200 [07:58<54:30, 18.79s/it]
# Last 5 epochs reward: -13.609608724281879
#  16%|████████████▌                                                                    | 31/200 [09:34<53:57, 19.16s/it]
# Last 5 epochs reward: -11.826539956928386
#  18%|██████████████▌                                                                  | 36/200 [11:13<54:07, 19.80s/it]
# Last 5 epochs reward: -9.85845133810048
#  20%|████████████████▌                                                                | 41/200 [12:54<53:44, 20.28s/it]
# Last 5 epochs reward: -8.696004772058057
#  23%|██████████████████▋                                                              | 46/200 [14:39<54:00, 21.05s/it]
# Last 5 epochs reward: -7.560078505384624
#  26%|████████████████████▋                                                            | 51/200 [16:31<55:25, 22.32s/it]
# Last 5 epochs reward: -6.62705146038613
#  28%|██████████████████████▋                                                          | 56/200 [18:28<56:30, 23.55s/it]
# Last 5 epochs reward: -5.715509084276736
#  30%|████████████████████████                                                       | 61/200 [20:41<1:01:01, 26.34s/it]
# Last 5 epochs reward: -5.245029695914061
#  33%|██████████████████████████▋                                                      | 66/200 [22:48<56:34, 25.33s/it]
# Last 5 epochs reward: -4.6777625302328705
#  36%|████████████████████████████▊                                                    | 71/200 [24:51<52:57, 24.63s/it]
# Last 5 epochs reward: -4.038147348639843
#  38%|██████████████████████████████▊                                                  | 76/200 [26:52<50:24, 24.39s/it]
# Last 5 epochs reward: -3.522477100825435
#  40%|████████████████████████████████▊                                                | 81/200 [28:54<48:27, 24.44s/it]
# Last 5 epochs reward: -3.05996192647184
#  43%|██████████████████████████████████▊                                              | 86/200 [30:52<44:37, 23.49s/it]
# Last 5 epochs reward: -2.779703326325747
#  46%|████████████████████████████████████▊                                            | 91/200 [32:55<45:17, 24.93s/it]
# Last 5 epochs reward: -2.5354969065265633
#  48%|██████████████████████████████████████▉                                          | 96/200 [34:53<40:49, 23.55s/it]
# Last 5 epochs reward: -2.3499658623288857
#  50%|████████████████████████████████████████▍                                       | 101/200 [36:52<39:46, 24.10s/it]
# Last 5 epochs reward: -2.251229559238742
#  53%|██████████████████████████████████████████▍                                     | 106/200 [38:54<38:02, 24.28s/it]
# Last 5 epochs reward: -2.0948735770298264
#  56%|████████████████████████████████████████████▍                                   | 111/200 [41:11<39:33, 26.67s/it]
# Last 5 epochs reward: -1.9728935055614087
#  58%|██████████████████████████████████████████████▍                                 | 116/200 [43:06<33:31, 23.94s/it]
# Last 5 epochs reward: -1.8530734008601073
#  60%|████████████████████████████████████████████████▍                               | 121/200 [45:12<32:18, 24.53s/it]
# Last 5 epochs reward: -1.7242400403677856
#  63%|██████████████████████████████████████████████████▍                             | 126/200 [47:06<28:46, 23.33s/it]
# Last 5 epochs reward: -1.6163404606358207
#  66%|████████████████████████████████████████████████████▍                           | 131/200 [49:03<26:29, 23.04s/it]
# Last 5 epochs reward: -1.542399814323806
#  68%|██████████████████████████████████████████████████████▍                         | 136/200 [51:01<24:33, 23.02s/it]
# Last 5 epochs reward: -1.448681952299381
#  70%|████████████████████████████████████████████████████████▍                       | 141/200 [52:59<23:05, 23.49s/it]
# Last 5 epochs reward: -1.3818908994439596
#  73%|██████████████████████████████████████████████████████████▍                     | 146/200 [54:59<21:05, 23.44s/it]
# Last 5 epochs reward: -1.3477579257044048
#  76%|████████████████████████████████████████████████████████████▍                   | 151/200 [57:00<19:55, 24.40s/it]
# Last 5 epochs reward: -1.2547293892588827
#  78%|██████████████████████████████████████████████████████████████▍                 | 156/200 [58:54<17:00, 23.19s/it]
# Last 5 epochs reward: -1.2164004793351517
#  80%|██████████████████████████████████████████████████████████████▊               | 161/200 [1:00:46<14:37, 22.50s/it]
# Last 5 epochs reward: -1.1916451251349787
#  83%|████████████████████████████████████████████████████████████████▋             | 166/200 [1:02:39<12:44, 22.50s/it]
# Last 5 epochs reward: -1.15990546494458
#  86%|██████████████████████████████████████████████████████████████████▋           | 171/200 [1:04:32<10:56, 22.63s/it]
# Last 5 epochs reward: -1.053467804783666
#  88%|████████████████████████████████████████████████████████████████████▋         | 176/200 [1:06:29<09:18, 23.29s/it]
# Last 5 epochs reward: -1.088535516570317
#  89%|█████████████████████████████████████████████████████████████████████▍        | 178/200 [1:07:14<08:20, 22.75s/it]2026-02-24 17:10:57,007	ERROR actor_manager.py:973 -- Ray error (The actor 9eb86dee3251919544409fa801000000 is unavailable: The actor is temporarily unavailable: IOError: The actor was restarted. The task may or may not have been executed on the actor.), taking actor 1 out of service.
# 2026-02-24 17:10:57,111	ERROR actor_manager.py:771 -- The actor 9eb86dee3251919544409fa801000000 is unavailable: The actor is temporarily unavailable: IOError: The actor was restarted. The task may or may not have been executed on the actor.
# NoneType: None
#  90%|██████████████████████████████████████████████████████████████████████▌       | 181/200 [1:09:59<12:01, 37.98s/it]
# Last 5 epochs reward: -1.0324296928901575
#  93%|████████████████████████████████████████████████████████████████████████▌     | 186/200 [1:11:48<05:43, 24.55s/it]
# Last 5 epochs reward: -0.9982337476997261
#  96%|██████████████████████████████████████████████████████████████████████████▍   | 191/200 [1:13:45<03:34, 23.79s/it]
# Last 5 epochs reward: -0.9502919009018473
#  98%|████████████████████████████████████████████████████████████████████████████▍ | 196/200 [1:15:47<01:37, 24.46s/it]
# Last 5 epochs reward: -0.9448919038839106
# 100%|██████████████████████████████████████████████████████████████████████████████| 200/200 [1:17:19<00:00, 23.20s/it]

# %% [markdown]
# ### Save pytorch model for later evaluation

# %% [markdown]
# We save only pytorch part to ensure latency and easier changes

# %%
policy = trainer.get_policy()

# %%
MODEL_NAME = "ALL_CCY_MODEL_WEIGHTS_1_MIN_1_DAY.pth"

# %%
torch.save(policy.model.state_dict(), f"../trained_models/{MODEL_NAME}")

# %% [markdown]
# ### Plot training results

# %% [markdown]
# Includes action penalty

# %%
rewards = pd.Series(episode_rewards)

# %%
rewards.rolling(10).mean().plot()
plt.title("Average total reward per 10 iterations")
plt.xlabel("Iteration")
plt.ylabel("Total reward")
plt.show()

# %%
rewards.rolling(10).mean().iloc[-50:].plot()
plt.title("Average total reward per 10 iterations (last 50)")
plt.xlabel("Iteration")
plt.ylabel("Total reward")
plt.show()

# %% [markdown]
# ---
# ## Validate the model

# %%
MODEL_NAME = "ALL_CCY_MODEL_WEIGHTS_1_MIN_1_DAY.pth"

# %%
fx_env = FxTradingEnv(**ENV_VALIDATION_CONFIG)

# %%
fx_env.preprocess_data()

# %%
state_dict = torch.load(f"../trained_models/{MODEL_NAME}")

# %%
num_ccy = fx_env.action_space.shape[0]

# %%
trained_model = FXModel(
    obs_space=fx_env.observation_space,
    action_space=fx_env.action_space,
    num_outputs=num_ccy * 2,
    model_config={},
    name="FXModel",  # any name if fine
)

# %%
trained_model.load_state_dict(state_dict)
trained_model.eval()
# Out:
# FXModel(
#   (main_net): Sequential(
#     (0): Linear(in_features=35, out_features=256, bias=True)
#     (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (6): GELU(approximate='none')
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Linear(in_features=128, out_features=64, bias=True)
#     (9): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (10): GELU(approximate='none')
#     (11): Dropout(p=0.2, inplace=False)
#   )
#   (mean_net): Sequential(
#     (0): Linear(in_features=64, out_features=5, bias=True)
#     (1): Tanh()
#   )
#   (log_std_net): Sequential(
#     (0): Linear(in_features=64, out_features=5, bias=True)
#   )
#   (value_net): Sequential(
#     (0): Linear(in_features=64, out_features=32, bias=True)
#     (1): GELU(approximate='none')
#     (2): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
execution_times = []
portfolio_pos = []
total_rewards = []
all_actions = []

for _ in trange(100):

    state, info = fx_env.reset()

    start_time = pd.Timestamp.now()
    done = False

    current_portfolio = []
    total_reward = []
    this_time_actions = []

    while not done:

        torch_state = torch.from_numpy(state).type(torch.float32)

        with torch.no_grad():
            action, _ = trained_model(
                input_dict={"obs": torch_state}, state=[], seq_lens=None
            )

        action = action.detach().numpy()[:num_ccy]
        this_time_actions.append(action)

        state, reward, terminated, truncated, info = fx_env.step(action)
        done = terminated or truncated

        if not done:
            current_portfolio.append(deepcopy(info["portfolio"]))
            total_reward.append(reward)

    execution_times.append((pd.Timestamp.now() - start_time).total_seconds())
    total_rewards.append(deepcopy(total_reward))
    portfolio_pos.append(deepcopy(current_portfolio))
    all_actions.append(deepcopy(this_time_actions))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [01:36<00:00,  1.03it/s]

# %%
np.quantile(execution_times, [0.01, 0.5, 0.99])
# Out:
# array([0.64447714, 0.918911  , 1.24027224])

# %%
total_rewards = [np.array(x) / 100 for x in total_rewards]

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))

axs[0].hist([np.exp(sum(x)) - 1 for x in total_rewards], bins=50)
axs[0].set_xlabel("percentage")
axs[0].set_title("Total return")

axs[1].hist([np.mean(x) / np.std(x) for x in total_rewards], bins=50)
axs[1].set_xlabel("")
axs[1].set_title("Sharpe ratio")

fig.suptitle("Validation results")
plt.tight_layout()
plt.show()

# %% [markdown]
# More stable positions in trading, some positive returns

# %%
pd.DataFrame.from_dict(portfolio_pos[50]).plot()
plt.title("Portfolio positions")
plt.xlabel("Minute")
plt.ylabel("Units of respective ccy")
plt.show()

# %%
pd.DataFrame(all_actions[50], columns=TICKER_SET).plot()
plt.title("Actions per currrency pair")
plt.xlabel("Minute")
plt.ylabel("Predicted flow")
plt.show()
